# %% [markdown]
# # 基于确定性策略梯度的深度强化学习算法
# &emsp;&emsp;<font size=4>
#     在动作离散的强化学习任务中，通常可以遍历所有的动作来计算动作值函数$q(s, a)$，从而得到最优动作值函数$q_{*}(s, a)$ 。但在大规模连续动作空间中，遍历所有动作是不现实，且计算代价过大。针对解决连续动作空间问题，2016年TP Lillicrap等人提出深度确定性策略梯度算法（Deep Deterministic Policy Gradient，DDPG）算法。该算法基于深度神经网络表达确定性策略$\mu(s)$，采用确定性策略梯度来更新网络参数，能够有效应用于大规模或连续动作空间的强化学习任务中。
# </font><br>

# %% [markdown]
# ### 背景
# &emsp;&emsp;<font size=4>
#     <b>(1) PG法</b>
# </font><br>
# &emsp;&emsp;<font size=4>
#     构建策略概率分布函数$\pi\left(a \mid s, \boldsymbol{\theta}^{\pi}\right)$，在每个时刻，Agent根据该概率分布选择动作：
# \begin{equation}
#     a \sim \pi\left(a \mid s, \boldsymbol{\theta}^{\pi}\right) \label{bbb.1}\tag{bbb.1}
# \end{equation}
# 其中，$\boldsymbol{\theta}^{\pi}$是一个关于随机策略$\pi$的参数。
# </font><br>
# &emsp;&emsp;<font size=4>
#     由于PG算法既涉及到状态空间又涉及到动作空间，因此在大规模情况下，得到随机策略需要大量的样本。这样在采样过程中会耗费较多的计算资源，相对而言，该算法效率较为低下。
# </font><br>
# &emsp;&emsp;<font size=4>
#     <b>(2) DPG算法</b>
# </font><br>
# &emsp;&emsp;<font size=4>
#     构建确定性策略函数$\mu\left(s, \boldsymbol{\theta}^{\mu}\right)$，在每个时刻，Agent根据该策略函数获得确定的动作：
# \begin{equation}
#     a=\mu\left(s, \boldsymbol{\theta}^{\mu}\right)  \label{bbb.2}\tag{bbb.2}
# \end{equation}
# 其中，$\theta^{\mu}$表示这是一个关于确定性策略$\mu$的参数。
# </font><br>
# &emsp;&emsp;<font size=4>
#     由于DPG算法仅涉及状态空间，因此与PG算法相比，需要的样本数较少，尤其在大规模或连续动作空间任务中，算法效率会显著提升。
# </font><br>
# &emsp;&emsp;<font size=4>
#     <b>(2) DDPG法</b>
# </font><br>
# &emsp;&emsp;<font size=4>
#     深度策略梯度方法在每个迭代步都需要采样$N$个完整情节$\left\{\varpi_{i}\right\}_{i=1}^{N}$来作为训练样本，然后构造目标函数关于策略参数的梯度项以求解最优策略。然而在许多现实场景下的任务中，很难在线获得大量完整情节的样本数据。例如在真实场景下机器人的操控任务中，在线收集并利用大量的完整情节会产生十分昂贵的代价，并且连续动作的特性使得在线抽取批量情节的方式无法覆盖整个状态特征空间。这些问题会导致算法在求解最优策略时出现局部最优解。针对上述问题，可将传统强化学习中的行动者评论家框架拓展到深度策略梯度方法中。这类算法被统称为基于AC框架的深度策略梯度方法。其中最具代表性的是深度确定性策略梯度（DDPG）算法，该算法能够解决一系列连续动作空间中的控制问题。DDPG算法基于DPG法，使用AC算法框架，利用深度神经网络学习近似动作值函数$Q(s, a, \boldsymbol{w})$和确定性策略$\mu(s, \boldsymbol{\theta})$，其中$\boldsymbol{w}$和$\theta$分别为值网络和策略网络的权重。值网络用于评估当前状态动作对的Q值，评估完成后再向策略网络提供更新策略权重的梯度信息，对应AC框架中的评论家；策略网络用于进行选择策略，对应AC框架中的行动者。它主要涉及以下概念：
# </font><br>
# &emsp;&emsp;<font size=4>
#     （1） 行为策略$\beta$：一种探索性策略，通过引入随机噪声影响动作的选择；
# </font><br>
# &emsp;&emsp;<font size=4>
#     （2） 状态分布$\rho^{\beta}$ ：Agent根据行为策略$\beta$产生的状态分布；
# </font><br>
# &emsp;&emsp;<font size=4>
#     （3） 策略网络：或行动者网络：DDPG使用深度网络对确定性策略函数$\mu(s, \boldsymbol{\theta})$进行逼近，$\boldsymbol{\theta}$为网络参数，输入为当前的状态$s$，输出为确定性的动作值$a$。有时$\theta$也表示为$\boldsymbol{\theta}^{\mu}$；
# </font><br>
# &emsp;&emsp;<font size=4>
#     （4） 价值网络：或评论家网络，DDPG使用深度网络对近似动作值函数$Q(s, a, \boldsymbol{w})$进行逼近，$\boldsymbol{w}$为网络参数。有时$\boldsymbol{w}$也表示为$\boldsymbol{\theta}^{Q}$。
# </font><br>
# &emsp;&emsp;<font size=4>
#     相对于DPG法，DDPG法的主要改进如下：
# </font><br>
# &emsp;&emsp;<font size=4>
#     （1） 采用深度神经网络：构建策略网络和价值网络，分别用来学习近似性策略函数$\mu(s, \boldsymbol{\theta})$和近似动作值函数$Q(s, a, \boldsymbol{w})$，并使用Adam训练网络模型；
# </font><br>
# &emsp;&emsp;<font size=4>
#     （2） 引入经验回放机制：Agent与环境进行交互时产生的经验转移样本具有时序相关性，通过引入经验回放机制，减少值函数估计所产生的偏差，解决数据间相关性及非静态分布问题，使算法更加容易收敛；
# </font><br>
# &emsp;&emsp;<font size=4>
#     （3） 使用双网络架构：策略函数和价值函数均使用双网络架构，即分别设置预测网络和目标网络，使算法的学习过程更加稳定，收敛更快。
# </font><br>

# %% [markdown]
# ### 核心思想
# &emsp;&emsp;<font size=4>
#     DDPG的价值网络作为评论家，用于评估策略，学习Q函数，为策略网络提供梯度信息；策略网络作为行动者，利用评论家学习到的Q函数及梯度信息对策略进行改进；同时还引入了带噪声的探索机制和软更新方法。本节将介绍DDPG法的核心思想和主要技术。
# </font><br>
# &emsp;&emsp;<font size=4>
#     <b>双网络架构</b>
# </font><br>
# &emsp;&emsp;<font size=4>
#     从DQN中已知，仅利用单一网络进行学习会出现不稳定现象。因此，DDPG为价值网络和策略网络分别引入了目标网络：
# </font><br>
# &emsp;&emsp;<font size=4>
#     $\left\{\begin{array}{ll}\text { 预测价值网络 }:&Q(s, a, \boldsymbol{w}), \text { 更新 } \boldsymbol{w} \\ \text { 目标价值网络 }: &Q\left(s, a, \boldsymbol{w}^{\prime}\right), \text { 吏新 } \boldsymbol{w}^{\prime}\end{array}\right.$
# </font><br>
# &emsp;&emsp;<font size=4>
#     $\left\{\begin{array}{l1}\text { 预测策略网络 }: \mu(s, a, \theta), \text { 更新 } \boldsymbol{\theta} \\ \text { 目标策略网络 }: \quad \mu\left(s, a, \theta^{\prime}\right), \text { 更新 } \boldsymbol{\theta}^{\prime}\end{array}\right.$
# </font><br>
# &emsp;&emsp;<font size=4>
#     每次完成小批量经验转移样本的训练之后，就利用小批量梯度上升法（mini-batch BGA，MBGA）更新预测策略网络参数，利用MBGD法更新预测价值网络参数，然后通过软更新算法更新目标网络的参数。
# </font><br>
# &emsp;&emsp;<font size=4>
#     <b>策略网络-行动者</b>
# </font><br>
# &emsp;&emsp;<font size=4>
#     在DDPG算法中，优化目标被定义为累积折扣奖赏：
# </font><br>
# \begin{equation}
# J(\boldsymbol{\theta})=\mathbb{E}_{\boldsymbol{\theta}}\left[r_{0}+\gamma r_{1}+\gamma^{2} r_{2}+\ldots\right] \label{bbb.3}\tag{bbb.3}
# \end{equation}
# &emsp;&emsp;<font size=4>
#     然后采用SGD方法对优化目标关于策略参数求偏导数。Silver等人证明在确定性环境下，目标函数关于权重$\theta$的梯度等价于Q值函数关于$\theta$梯度的期望：
# </font><br>
# \begin{equation}
# \nabla_{\boldsymbol{\theta}} J(\boldsymbol{\theta})=\mathbb{E}_{s-\rho^{\beta}}\left[\nabla_{\boldsymbol{\theta}} Q(s, a, \boldsymbol{w})\right]  \label{bbb.4}\tag{bbb.4}
# \end{equation}
# &emsp;&emsp;<font size=4>
#     根据确定性策略$a=\mu(s, \theta)$可得：
# </font><br>
# \begin{equation}\nabla_{\theta} \hat{J}_{\beta}(\boldsymbol{\theta})=\mathbb{E}_{S_{i} \sim \rho^{\beta}}\left[\left.\nabla_{\theta} \mu\left(S_{t}, \boldsymbol{\theta}\right) \nabla_{a} Q\left(S_{t}, a, \boldsymbol{w}\right)\right|_{a=\mu\left(S_{t}, \theta\right)}\right] \label{bbb.5}\tag{bbb.5}
# \end{equation}
# &emsp;&emsp;<font size=4>
#     利用MBGA法，从经验池$\mathcal{D}$中随机采样获得$N$个小批量数据作为对期望值的采样估计：
# </font><br>
# \begin{equation}
# \left.\nabla_{\theta} \hat{J}_{\beta}(\boldsymbol{\theta}) \approx \frac{1}{N} \sum_{i} \nabla_{\theta} \mu\left(S_{i}, \boldsymbol{\theta}\right) \nabla_{a} Q\left(S_{i}, a, \boldsymbol{w}\right)\right|_{a=\mu\left(S_{i}, \boldsymbol{\theta}\right)} \label{bbb.6}\tag{bbb.6}
# \end{equation}
# &emsp;&emsp;<font size=4>
#     <b>价值网络-评论家</b>
# </font><br>
# &emsp;&emsp;<font size=4>
#     与DQN一样，DDPG利用基于TD误差的MSE作为损失函数，它们的区别在于目标值$y_{i}$:
# </font><br>
# \begin{equation}
# L(\boldsymbol{w})=\mathbb{E}\left[\left(r+\gamma Q^{\prime}\left(s^{\prime}, \mu^{\prime}\left(s^{\prime}, \boldsymbol{\theta}^{\prime}\right), \boldsymbol{w}^{\prime}\right)-Q(s, a, \boldsymbol{w})\right)^{2}\right] \label{bbb.7}\tag{bbb.7}
# \end{equation}
# &emsp;&emsp;<font size=4>
#     可以看出，目标值$y_{i}=r+\gamma Q^{\prime}\left(s^{\prime}, \mu^{\prime}\left(s^{\prime}, \boldsymbol{\theta}^{\prime}\right), \boldsymbol{w}^{\prime}\right)$的计算过程涉及目标策略网络 和目标价值网络 ，这能够让预测价值网络在学习时更加稳定，也更容易收敛。
# </font><br>
# &emsp;&emsp;<font size=4>
#     价值网络的目标是最小化损失函数，故采用MSGD法，从经验池$\mathcal{D}$中随机采样获得$N$个小批量数据作为对期望值的采样估计：
# </font><br>
# \begin{equation}
# \nabla_{w} L(\boldsymbol{w}) \approx \frac{1}{N} \sum_{i}^{N}\left(r+\gamma Q^{\prime}\left(s^{\prime}, \mu\left(s^{\prime}, \boldsymbol{\theta}^{\prime}\right), \boldsymbol{w}^{\prime}\right)-Q(s, a, \boldsymbol{w})\right) \nabla_{w} Q(s, a, \boldsymbol{w}) \label{bbb.8}\tag{bbb.8}
# \end{equation}
# &emsp;&emsp;<font size=4>
#     其中，$\theta^{\prime}$和$\boldsymbol{w}^{\prime}$分别表示目标策略网络$\mu^{\prime}$和目标值网络的权重$Q^{\prime}$。每次更新时，DDPG使用经验回放机制从样本池中抽取固定数量（如$N$个）的转移样本，并将由Q值函数关于动作的梯度信息从评论家网络传递到行动者网络。最后依据式（bbb.5）沿着提升Q值的方向更新策略网络的参数，以求解最优策略。
# </font><br>
# &emsp;&emsp;<font size=4>
#     <b>探索机制</b>
# </font><br>
# &emsp;&emsp;<font size=4>
#     在利用与探索问题中，DQN采用的是$\mathcal{E}$-贪婪策略，该策略在离散型动作空间任务中能够得到较好的效果，但是面对大规模或连续动作空间任务，$\mathcal{E}$-贪婪策略就无能为力了。根据AC框架和确定性策略的特性，DDPG通过对参数空间或动作空间添加噪声来增加探索机制：
# </font><br>
# <center>
# <table align="center" width="100%">
#     <tr>
#         <th><img src='./参数空间或动作空间中添加噪声.png' width='500px' height='200px'></th>
#     </tr>
#     <tr>
#         <td><font size=3><center> 图bbb.1&ensp;参数空间或动作空间中添加噪声</center></font></td>
#     </tr>
# </table>
# </center>
# &emsp;&emsp;<font size=4>
#   如在$t$时刻通过为动作空间添加噪声$\mathcal{N}$的方式来选择动作：
# </font><br>
# \begin{equation}
# A_{t}=\mu\left(S_{t}, \boldsymbol{\theta}\right)+\mathcal{N}  \label{bbb.9}\tag{bbb.9}
# \end{equation}
# &emsp;&emsp;<font size=4>
#     在添加噪声时，采用了Ornstein-Uhlenbeck过程（OU过程），OU过程是与强化学习任务类似的一种序列相关过程，利用该噪声，Agent能在一些物理环境中实现较好的探索。噪声的递推式如下：
# </font><br>
# \begin{equation}
# \mathcal{N}_{t} \leftarrow-\mathcal{N}_{t-1} \varphi+N(0, \sigma I)
# \end{equation}
# &emsp;&emsp;<font size=4>
#     但后续研究表明，相对OU过程，直接采用均值为0且互不相关的高斯噪声效果更好，且实现更简单。若采用期望为0，方差为1的高斯噪声，动作选择过程为：
# </font><br>
# \begin{equation}
# A_{t}=\mu\left(S_{t}, \boldsymbol{\theta}\right)+\mathcal{N}(0,1)
# \end{equation}
# &emsp;&emsp;<font size=4>
#     <b>软更新</b>
# </font><br>
# &emsp;&emsp;<font size=4>
#     DDPG目标网络参数的同步方式也与DQN不同。DQN采用硬更新方法，每隔固定步数才从预测网络中拷贝参数到目标网络中。DDPG采用软更新方法，每次预测网络参数更新后，目标网络参数都会在一定程度上靠近预测网络：
#  </font><br>
# \begin{equation}\left\{\begin{array}{l}
# \mathbf{w}^{\prime} \leftarrow \tau \mathbf{w}+(1-\tau) \mathbf{w}^{\prime} \\
# \boldsymbol{\theta}^{\prime} \leftarrow \tau \boldsymbol{\theta}+(1-\tau) \boldsymbol{\theta}^{\prime}
# \end{array}\right. \label{bbb.10}\tag{bbb.10}
# \end{equation}
# &emsp;&emsp;<font size=4>
#     其中，$\tau$是一个远小于1的超参数，通常设为0.001。
# </font><br>
# &emsp;&emsp;<font size=4>
#     采用软更新方法，目标值会一直缓慢地向当前估算值靠近，既保证了网络参数的及时更新，又保证了训练时预测网络梯度的相对稳定，使算法更容易收敛。其缺点是参数变化很小，学习过程较长。
#  </font><br>

# %% [markdown]
# ### DDPG算法
# &emsp;&emsp;<font size=4>
#     由bbb.1.2节已知，DDPG的目标是最大化策略目标函数$J_{\beta}(\boldsymbol{\theta})$，同时最小化价值网络的损失函数$L(\boldsymbol{w})$，该算法的流程图如图bbb.2所示：
# </font><br>
# <center>
# <table align="center" width="100%">
#     <tr>
#         <th><img src='./DDPG算法流程图.png' width='500px' height='200px'></th>
#     </tr>
#     <tr>
#         <td><font size=3><center>图bbb.2&ensp;DDPG算法流程图</center></font></td>
#     </tr>
# </table>
# </center>

# %% [markdown]
# 用于构建策略网络模型的DDPG法，如算法bbb.1所示：
# <hr style="height:1px;border:none;border-top:1px solid #555555;" />
# &emsp;&emsp;<font size=3.5><b>算法bbb.1</b> 用于构建策略网络模型的DDPG算法（Lillicrap al. 2016）</font><br>
# <hr>
# &emsp;&emsp;<font size=3.5>初始化：</font><br>
# &emsp;&emsp;&emsp;&emsp;<font size=3.5>
#     1.&emsp;初始化预测策略网络$\mu(s, \boldsymbol{\theta})$和预测价值网络$Q(s, a, \boldsymbol{w})$，网络参数分别为$\theta$和$\boldsymbol{w}$
# </font><br>
# &emsp;&emsp;&emsp;&emsp;<font size=3.5>
#     2.&emsp;初始化目标策略网络$\mu\left(s, \boldsymbol{\theta}^{\prime}\right)$和目标价值网络$Q\left(s, a, \boldsymbol{w}^{\prime}\right)$，网络参数为$\boldsymbol{\theta}^{\prime} \leftarrow \boldsymbol{\theta}, \quad \boldsymbol{w}^{\prime} \leftarrow \boldsymbol{w}$
# </font><br>
# &emsp;&emsp;&emsp;&emsp;<font size=3.5>
#     3.&emsp;经验池$\mathcal{D}$的容量为$N$
# </font><br>
# &emsp;&emsp;&emsp;&emsp;<font size=3.5>
#     4.&emsp;总迭代次数$M$，折扣因子$\gamma$，$\tau=0.0001$，随机小批量采样样本数量$n$
# </font><br>
# <hr>
# &emsp;&emsp;&emsp;&emsp;<font size=3.5>
#     5.&emsp;<b>for</b> $e$=1 <b>to</b> $M$ <b>do:</b>
# </font><br>
# &emsp;&emsp;&emsp;&emsp;<font size=3.5>
#     6.&emsp;&emsp;&emsp;初始化一个随机过程$\mathcal{N}$，用于动作的探索
# </font><br>
# &emsp;&emsp;&emsp;&emsp;<font size=3.5>
#     7.&emsp;&emsp;&emsp;初始化状态设置为$S_{0}$
# </font><br>
# &emsp;&emsp;&emsp;&emsp;<font size=3.5>
#     8.&emsp;&emsp;&emsp;<b>repeat</b>（情节中的每一时间步$t$）：
# </font><br>
# &emsp;&emsp;&emsp;&emsp;<font size=3.5>
#     9.&emsp;&emsp;&emsp;&emsp;&emsp;根据当前的预测策略网络和探索噪声来选择动作$A_{t}=\mu\left(S_{t}, \boldsymbol{\theta}\right)+\mathcal{N}_{t}$
# </font><br>
# &emsp;&emsp;&emsp;&emsp;<font size=3.5>
#     10.&emsp;&emsp;&emsp;&emsp;&emsp;执行动作$ A_{t}$，获得奖赏$R_{t+1}$和下一状态$S_{t+1}$
# </font><br>
# &emsp;&emsp;&emsp;&emsp;<font size=3.5>
#     11.&emsp;&emsp;&emsp;&emsp;&emsp;将经验转换$\left(S_{t}, A_{t}, R_{t+1}, S_{t+1}\right)$存储在经验池$\mathcal{D}$中
# </font><br>
# &emsp;&emsp;&emsp;&emsp;<font size=3.5>
#     12.&emsp;&emsp;&emsp;&emsp;&emsp;从经验池$\mathcal{D}$中随机采样小批量的$n$个经验转移样本$\left(S_{i}, A_{i}, R_{i+1}, S_{i+1}\right)$，计算目标值：
# </font><br>
# &emsp;&emsp;&emsp;&emsp;<font size=3.5>
#     13.&emsp;&emsp;&emsp;&emsp;&emsp;$y_{i}=R_{i+1}+\gamma Q\left(S_{i+1}, \mu\left(S_{i+1}, \boldsymbol{\theta}^{\prime}\right), \boldsymbol{w}^{\prime}\right)$
# </font><br>
# &emsp;&emsp;&emsp;&emsp;<font size=3.5>
#     14.&emsp;&emsp;&emsp;&emsp;&emsp;使用MBGD，根据最小化损失函数来更新价值网络（评论家网络）参数$\boldsymbol{w}$：
# </font><br>
# &emsp;&emsp;&emsp;&emsp;<font size=3.5>
#     &emsp;&emsp;&emsp;&emsp;&emsp;
#           $\nabla_{w} L(\boldsymbol{w}) \approx \frac{1}{N} \sum_{i}^{N}\left(y_{i}-Q\left(S_{i}, A_{i}, \boldsymbol{w}\right)\right) \nabla_{w} Q\left(S_{i}, A_{i}, \boldsymbol{w}\right)$
# </font><br>
# &emsp;&emsp;&emsp;&emsp;<font size=3.5>
#     15.&emsp;&emsp;&emsp;&emsp;&emsp;使用MBGA法，根据最大化目标函数来更新策略网络（行动者网络）参数$\theta$：
# </font><br>
# &emsp;&emsp;&emsp;&emsp;<font size=3.5>
#     &emsp;&emsp;&emsp;&emsp;&emsp;
#               $\left.\nabla_{\theta} \hat{J}_{\beta}(\boldsymbol{\theta}) \approx \frac{1}{N} \sum_{i} \nabla_{\theta} \mu\left(S_{i}, \boldsymbol{\theta}\right) \nabla_{a} Q\left(S_{i}, a, \boldsymbol{w}\right)\right|_{a=\mu\left(S_{i}, \boldsymbol{\theta}\right)}$
# </font><br>
# &emsp;&emsp;&emsp;&emsp;<font size=3.5>
#     16.&emsp;&emsp;&emsp;&emsp;&emsp;软更新目标网络：$\left\{\begin{array}{l}\boldsymbol{w}^{\prime} \leftarrow \tau \boldsymbol{w}+(1-\tau) \boldsymbol{w}^{\prime} \\ \boldsymbol{\theta}^{\prime} \leftarrow \tau \boldsymbol{\theta}+(1-\tau) \boldsymbol{\theta}^{\prime}\end{array}\right.$
# </font><br>
# &emsp;&emsp;&emsp;&emsp;<font size=3.5>
#     17.&emsp;&emsp;&emsp;<b>until</b> $t$为终止状态
# </font><br>
# <hr style="height:1px;border:none;border-top:1px solid #555555;" /><br>

# %%
import numpy as np
import torch
import gym
import os
import copy
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# ## USE CUDA

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Replay Buffer

# %%
class ReplayBuffer(object):
    def __init__(self, state_dim, action_dim, max_size=int(1e6)):
        self.max_size = max_size
        self.ptr = 0
        self.size = 0

        self.state = np.zeros((max_size, state_dim))
        self.action = np.zeros((max_size, action_dim))
        self.next_state = np.zeros((max_size, state_dim))
        self.reward = np.zeros((max_size, 1))
        self.not_done = np.zeros((max_size, 1))

        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    def add(self, state, action, next_state, reward, done):
        self.state[self.ptr] = state
        self.action[self.ptr] = action
        self.next_state[self.ptr] = next_state
        self.reward[self.ptr] = reward
        self.not_done[self.ptr] = 1. - done

        self.ptr = (self.ptr + 1) % self.max_size
        self.size = min(self.size + 1, self.max_size)

    def sample(self, batch_size):
        ind = np.random.randint(0, self.size, size=batch_size)

        return (
            torch.FloatTensor(self.state[ind]).to(self.device),
            torch.FloatTensor(self.action[ind]).to(self.device),
            torch.FloatTensor(self.next_state[ind]).to(self.device),
            torch.FloatTensor(self.reward[ind]).to(self.device),
            torch.FloatTensor(self.not_done[ind]).to(self.device)
        )

# %%
class Actor(nn.Module):
    def __init__(self, state_dim, action_dim, max_action):
        super(Actor, self).__init__()

        self.l1 = nn.Linear(state_dim, 400)
        self.l2 = nn.Linear(400, 300)
        self.l3 = nn.Linear(300, action_dim)

        self.max_action = max_action


    def forward(self, state):
        a = F.relu(self.l1(state))
        a = F.relu(self.l2(a))
        return self.max_action * torch.tanh(self.l3(a))


class Critic(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(Critic, self).__init__()

        self.l1 = nn.Linear(state_dim, 400)
        self.l2 = nn.Linear(400 + action_dim, 300)
        self.l3 = nn.Linear(300, 1)


    def forward(self, state, action):
        q = F.relu(self.l1(state))
        q = F.relu(self.l2(torch.cat([q, action], 1)))
        return self.l3(q)

# %%
actor1=Actor(17,6,1.0)
for ch in actor1.children():
    print(ch)
print("*********************")
critic1=Critic(17,6)
for ch in critic1.children():
    print(ch)
# Out:
# Linear(in_features=17, out_features=400, bias=True)
# Linear(in_features=400, out_features=300, bias=True)
# Linear(in_features=300, out_features=6, bias=True)
# Linear(in_features=17, out_features=400, bias=True)
# Linear(in_features=406, out_features=300, bias=True)
# Linear(in_features=300, out_features=1, bias=True)

# %% [markdown]
# ## DDPG Update

# %%
class DDPG(object):
    def __init__(self, state_dim, action_dim, max_action, discount=0.99, tau=0.001):
        self.actor = Actor(state_dim, action_dim, max_action).to(device)
        self.actor_target = copy.deepcopy(self.actor)
        self.actor_optimizer = torch.optim.Adam(self.actor.parameters(), lr=1e-4)

        self.critic = Critic(state_dim, action_dim).to(device)
        self.critic_target = copy.deepcopy(self.critic)
        self.critic_optimizer = torch.optim.Adam(self.critic.parameters(), weight_decay=1e-2)

        self.discount = discount
        self.tau = tau


    def select_action(self, state):
        state = torch.FloatTensor(state.reshape(1, -1)).to(device)
        return self.actor(state).cpu().data.numpy().flatten()


    def train(self, replay_buffer, batch_size=64):
        # Sample replay buffer 
        state, action, next_state, reward, not_done = replay_buffer.sample(batch_size)

        # Compute the target Q value
        target_Q = self.critic_target(next_state, self.actor_target(next_state))
        target_Q = reward + (not_done * self.discount * target_Q).detach()

        # Get current Q estimate
        current_Q = self.critic(state, action)

        # Compute critic loss
        critic_loss = F.mse_loss(current_Q, target_Q)

        # Optimize the critic
        self.critic_optimizer.zero_grad()
        critic_loss.backward()
        self.critic_optimizer.step()

        # Compute actor loss
        actor_loss = -self.critic(state, self.actor(state)).mean()
        
        # Optimize the actor 
        self.actor_optimizer.zero_grad()
        actor_loss.backward()
        self.actor_optimizer.step()

        # Update the frozen target models
        for param, target_param in zip(self.critic.parameters(), self.critic_target.parameters()):
            target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)

        for param, target_param in zip(self.actor.parameters(), self.actor_target.parameters()):
            target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)


    def save(self, filename):
        torch.save(self.critic.state_dict(), filename + "_critic")
        torch.save(self.critic_optimizer.state_dict(), filename + "_critic_optimizer")
        
        torch.save(self.actor.state_dict(), filename + "_actor")
        torch.save(self.actor_optimizer.state_dict(), filename + "_actor_optimizer")


    def load(self, filename):
        self.critic.load_state_dict(torch.load(filename + "_critic"))
        self.critic_optimizer.load_state_dict(torch.load(filename + "_critic_optimizer"))
        self.critic_target = copy.deepcopy(self.critic)

        self.actor.load_state_dict(torch.load(filename + "_actor"))
        self.actor_optimizer.load_state_dict(torch.load(filename + "_actor_optimizer"))
        self.actor_target = copy.deepcopy(self.actor)

# %%
# Runs policy for X episodes and returns average reward
# A fixed seed is used for the eval environment
def eval_policy(policy, env_name, seed, eval_episodes=10):
    eval_env = gym.make(env_name)
    eval_env.seed(seed + 100)

    avg_reward = 0.
    for _ in range(eval_episodes):
        state, done = eval_env.reset(), False
        while not done:
            action = policy.select_action(np.array(state))
            state, reward, done, _ = eval_env.step(action)
            avg_reward += reward

    avg_reward /= eval_episodes

    print("---------------------------------------")
    print(f"Evaluation over {eval_episodes} episodes: {avg_reward:.3f}")
    print("---------------------------------------")
    return avg_reward

# %%
policy="DDPG"
env_name="Walker2d-v2"          # OpenAI gym environment name
seed=0                        # Sets Gym, PyTorch and Numpy seeds
start_timesteps=25e3         # Time steps initial random policy is used
eval_freq=5e3               # How often (time steps) we evaluate
max_timesteps=1e6   # Max time steps to run environment
expl_noise=0.1                 # Std of Gaussian exploration noise
batch_size=256      # Batch size for both actor and critic
discount=0.99                 # Discount factor
tau=0.005                     # Target network update rate
policy_noise=0.2              # Noise added to target policy during critic update
noise_clip=0.5                # Range to clip target policy noise
policy_freq=2                 # Frequency of delayed policy updates
save_model="store_true"       # Save model and optimizer parameters
load_model=""                # Model load file name, "" doesn't load, "default" uses file_name

file_name = f"{policy}_{env_name}_{seed}"
print("---------------------------------------")
print(f"Policy: {policy}, Env: {env_name}, Seed: {seed}")
print("---------------------------------------")

if not os.path.exists("./results"):
    os.makedirs("./results")

if save_model and not os.path.exists("./models"):
    os.makedirs("./models")

env = gym.make(env_name)

# Set seeds
env.seed(seed)
torch.manual_seed(seed)
np.random.seed(seed)

state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0] 
max_action = float(env.action_space.high[0])

kwargs = {
    "state_dim": state_dim,
    "action_dim": action_dim,
    "max_action": max_action,
    "discount": discount,
    "tau": tau,
}


policy = DDPG(**kwargs)

if load_model != "":
    policy_file = file_name if load_model == "default" else load_model
    policy.load(f"./models/{policy_file}")

replay_buffer = ReplayBuffer(state_dim, action_dim)

# Evaluate untrained policy
evaluations = [eval_policy(policy, env_name, seed)]

state, done = env.reset(), False
episode_reward = 0
episode_timesteps = 0
episode_num = 0

for t in range(int(max_timesteps)):

    episode_timesteps += 1

    # Select action randomly or according to policy
    if t < start_timesteps:
        action = env.action_space.sample()
    else:
        action = (
            policy.select_action(np.array(state))
            + np.random.normal(0, max_action * expl_noise, size=action_dim)
        ).clip(-max_action, max_action)

    # Perform action
    next_state, reward, done, _ = env.step(action) 
    done_bool = float(done) if episode_timesteps < env._max_episode_steps else 0

    # Store data in replay buffer
    replay_buffer.add(state, action, next_state, reward, done_bool)

    state = next_state
    episode_reward += reward

    # Train agent after collecting sufficient data
    if t >= start_timesteps:
        policy.train(replay_buffer, batch_size)

    if done: 
        # +1 to account for 0 indexing. +0 on ep_timesteps since it will increment +1 even if done=True
        print(f"Total T: {t+1} Episode Num: {episode_num+1} Episode T: {episode_timesteps} Reward: {episode_reward:.3f}")
        # Reset environment
        state, done = env.reset(), False
        episode_reward = 0
        episode_timesteps = 0
        episode_num += 1 

    # Evaluate episode
    if (t + 1) % eval_freq == 0:
        evaluations.append(eval_policy(policy, env_name, seed))
        np.save(f"./results/{file_name}", evaluations)
    
    if save_model: 
        policy.save(f"./models/{file_name}")
# Out:
# ---------------------------------------
# Policy: DDPG, Env: Walker2d-v2, Seed: 0
# ---------------------------------------
# ---------------------------------------
# Evaluation over 10 episodes: 2.778
# ---------------------------------------
# Total T: 16 Episode Num: 1 Episode T: 16 Reward: -2.204
# Total T: 32 Episode Num: 2 Episode T: 16 Reward: 3.876
# Total T: 86 Episode Num: 3 Episode T: 54 Reward: 17.944
# Total T: 110 Episode Num: 4 Episode T: 24 Reward: -1.971
# Total T: 128 Episode Num: 5 Episode T: 18 Reward: -5.018
# Total T: 139 Episode Num: 6 Episode T: 11 Reward: -1.377
# Total T: 154 Episode Num: 7 Episode T: 15 Reward: -1.568
# Total T: 235 Episode Num: 8 Episode T: 81 Reward: 50.821
# Total T: 272 Episode Num: 9 Episode T: 37 Reward: 4.655
# Total T: 306 Episode Num: 10 Episode T: 34 Reward: 16.521
# Total T: 330 Episode Num: 11 Episode T: 24 Reward: 5.578
# Total T: 356 Episode Num: 12 Episode T: 26 Reward: 15.820
# Total T: 384 Episode Num: 13 Episode T: 28 Reward: 1.189
# Total T: 394 Episode Num: 14 Episode T: 10 Reward: -2.911
# Total T: 418 Episode Num: 15 Episode T: 24 Reward: -3.377
# Total T: 431 Episode Num: 16 Episode T: 13 Reward: -1.627
# Total T: 447 Episode Num: 17 Episode T: 16 Reward: 3.414
# Total T: 465 Episode Num: 18 Episode T: 18 Reward: -0.074
# Total T: 475 Episode Num: 19 Episode T: 10 Reward: -1.475
# Total T: 507 Episode Num: 20 Episode T: 32 Reward: 9.486
# Total T: 516 Episode Num: 21 Episode T: 9 Reward: -0.856
# Total T: 543 Episode Num: 22 Episode T: 27 Reward: -0.745
# Total T: 573 Episode Num: 23 Episode T: 30 Reward: 10.342
# Total T: 595 Episode Num: 24 Episode T: 22 Reward: -2.355
# Total T: 613 Episode Num: 25 Episode T: 18 Reward: 2.854
# Total T: 625 Episode Num: 26 Episode T: 12 Reward: -3.949
# Total T: 644 Episode Num: 27 Episode T: 19 Reward: 0.780
# Total T: 672 Episode Num: 28 Episode T: 28 Reward: -0.182
# Total T: 680 Episode Num: 29 Episode T: 8 Reward: -1.715
# Total T: 694 Episode Num: 30 Episode T: 14 Reward: 0.737
# Total T: 708 Episode Num: 31 Episode T: 14 Reward: 0.413
# Total T: 727 Episode Num: 32 Episode T: 19 Reward: -0.680
# Total T: 758 Episode Num: 33 Episode T: 31 Reward: 13.026
# Total T: 784 Episode Num: 34 Episode T: 26 Reward: 9.127
# Total T: 806 Episode Num: 35 Episode T: 22 Reward: 0.295
# Total T: 821 Episode Num: 36 Episode T: 15 Reward: 5.344
# Total T: 845 Episode Num: 37 Episode T: 24 Reward: -2.347
# Total T: 859 Episode Num: 38 Episode T: 14 Reward: 3.361
# Total T: 899 Episode Num: 39 Episode T: 40 Reward: 6.792
# Total T: 910 Episode Num: 40 Episode T: 11 Reward: -1.538
# Total T: 929 Episode Num: 41 Episode T: 19 Reward: 4.922
# Total T: 967 Episode Num: 42 Episode T: 38 Reward: 3.458
# Total T: 1005 Episode Num: 43 Episode T: 38 Reward: 10.097
# Total T: 1017 Episode Num: 44 Episode T: 12 Reward: 1.518
# Total T: 1047 Episode Num: 45 Episode T: 30 Reward: 11.710
# Total T: 1071 Episode Num: 46 Episode T: 24 Reward: 3.684
# Total T: 1094 Episode Num: 47 Episode T: 23 Reward: 3.997
# Total T: 1104 Episode Num: 48 Episode T: 10 Reward: -2.339
# Total T: 1136 Episode Num: 49 Episode T: 32 Reward: -1.815
# Total T: 1151 Episode Num: 50 Episode T: 15 Reward: 4.510
# Total T: 1175 Episode Num: 51 Episode T: 24 Reward: 1.469
# Total T: 1216 Episode Num: 52 Episode T: 41 Reward: 17.888
# Total T: 1231 Episode Num: 53 Episode T: 15 Reward: -1.837
# Total T: 1246 Episode Num: 54 Episode T: 15 Reward: -0.374
# Total T: 1267 Episode Num: 55 Episode T: 21 Reward: 1.036
# Total T: 1281 Episode Num: 56 Episode T: 14 Reward: 2.262
# Total T: 1349 Episode Num: 57 Episode T: 68 Reward: 18.371
# Total T: 1366 Episode Num: 58 Episode T: 17 Reward: -4.036
# Total T: 1382 Episode Num: 59 Episode T: 16 Reward: 3.801
# Total T: 1405 Episode Num: 60 Episode T: 23 Reward: 4.868
# Total T: 1425 Episode Num: 61 Episode T: 20 Reward: 6.923
# Total T: 1440 Episode Num: 62 Episode T: 15 Reward: 1.568
# Total T: 1448 Episode Num: 63 Episode T: 8 Reward: -1.722
# Total T: 1479 Episode Num: 64 Episode T: 31 Reward: -4.507
# Total T: 1503 Episode Num: 65 Episode T: 24 Reward: -1.130
# Total T: 1537 Episode Num: 66 Episode T: 34 Reward: 7.393
# Total T: 1560 Episode Num: 67 Episode T: 23 Reward: -3.313
# Total T: 1581 Episode Num: 68 Episode T: 21 Reward: -3.171
# Total T: 1599 Episode Num: 69 Episode T: 18 Reward: 4.192
# Total T: 1609 Episode Num: 70 Episode T: 10 Reward: -3.332
# Total T: 1629 Episode Num: 71 Episode T: 20 Reward: 4.236
# Total T: 1642 Episode Num: 72 Episode T: 13 Reward: -0.668
# Total T: 1673 Episode Num: 73 Episode T: 31 Reward: -5.779
# Total T: 1685 Episode Num: 74 Episode T: 12 Reward: -1.405
# Total T: 1711 Episode Num: 75 Episode T: 26 Reward: 9.589
# Total T: 1720 Episode Num: 76 Episode T: 9 Reward: -0.329
# Total T: 1756 Episode Num: 77 Episode T: 36 Reward: 9.219
# Total T: 1770 Episode Num: 78 Episode T: 14 Reward: 4.481
# Total T: 1789 Episode Num: 79 Episode T: 19 Reward: 1.194
# Total T: 1816 Episode Num: 80 Episode T: 27 Reward: 6.272
# Total T: 1831 Episode Num: 81 Episode T: 15 Reward: -0.337
# Total T: 1843 Episode Num: 82 Episode T: 12 Reward: 0.246
# Total T: 1883 Episode Num: 83 Episode T: 40 Reward: 3.949
# Total T: 1899 Episode Num: 84 Episode T: 16 Reward: -0.654
# Total T: 1916 Episode Num: 85 Episode T: 17 Reward: 8.801
# Total T: 1932 Episode Num: 86 Episode T: 16 Reward: -2.757
# Total T: 1960 Episode Num: 87 Episode T: 28 Reward: -0.147
# Total T: 1983 Episode Num: 88 Episode T: 23 Reward: 1.634
# Total T: 1999 Episode Num: 89 Episode T: 16 Reward: 5.444
# Total T: 2018 Episode Num: 90 Episode T: 19 Reward: 3.421
# Total T: 2028 Episode Num: 91 Episode T: 10 Reward: -2.003
# Total T: 2047 Episode Num: 92 Episode T: 19 Reward: -7.715
# Total T: 2067 Episode Num: 93 Episode T: 20 Reward: 0.112
# Total T: 2085 Episode Num: 94 Episode T: 18 Reward: 0.402
# Total T: 2108 Episode Num: 95 Episode T: 23 Reward: 0.985
# Total T: 2132 Episode Num: 96 Episode T: 24 Reward: 0.773
# Total T: 2149 Episode Num: 97 Episode T: 17 Reward: 0.896
# Total T: 2169 Episode Num: 98 Episode T: 20 Reward: 6.341
# Total T: 2195 Episode Num: 99 Episode T: 26 Reward: -1.395
# Total T: 2206 Episode Num: 100 Episode T: 11 Reward: -2.839
# Total T: 2234 Episode Num: 101 Episode T: 28 Reward: 1.063
# Total T: 2253 Episode Num: 102 Episode T: 19 Reward: 3.470
# Total T: 2275 Episode Num: 103 Episode T: 22 Reward: -9.916
# Total T: 2299 Episode Num: 104 Episode T: 24 Reward: -0.888
# Total T: 2312 Episode Num: 105 Episode T: 13 Reward: -2.071
# Total T: 2335 Episode Num: 106 Episode T: 23 Reward: 5.160
# Total T: 2354 Episode Num: 107 Episode T: 19 Reward: 6.043
# Total T: 2367 Episode Num: 108 Episode T: 13 Reward: -3.486
# Total T: 2388 Episode Num: 109 Episode T: 21 Reward: -0.526
# Total T: 2414 Episode Num: 110 Episode T: 26 Reward: -6.948
# Total T: 2429 Episode Num: 111 Episode T: 15 Reward: -4.187
# Total T: 2447 Episode Num: 112 Episode T: 18 Reward: 2.899
# Total T: 2466 Episode Num: 113 Episode T: 19 Reward: 2.905
# Total T: 2484 Episode Num: 114 Episode T: 18 Reward: 6.244
# Total T: 2500 Episode Num: 115 Episode T: 16 Reward: -0.296
# Total T: 2523 Episode Num: 116 Episode T: 23 Reward: -3.410
# Total T: 2537 Episode Num: 117 Episode T: 14 Reward: -4.667
# Total T: 2554 Episode Num: 118 Episode T: 17 Reward: 5.618
# Total T: 2570 Episode Num: 119 Episode T: 16 Reward: -2.902
# Total T: 2594 Episode Num: 120 Episode T: 24 Reward: -0.576
# Total T: 2605 Episode Num: 121 Episode T: 11 Reward: 1.146
# Total T: 2624 Episode Num: 122 Episode T: 19 Reward: -2.001
# Total T: 2638 Episode Num: 123 Episode T: 14 Reward: -1.019
# Total T: 2652 Episode Num: 124 Episode T: 14 Reward: 2.174
# Total T: 2671 Episode Num: 125 Episode T: 19 Reward: -2.472
# Total T: 2680 Episode Num: 126 Episode T: 9 Reward: -1.722
# Total T: 2695 Episode Num: 127 Episode T: 15 Reward: 1.950
# Total T: 2709 Episode Num: 128 Episode T: 14 Reward: -4.153
# Total T: 2737 Episode Num: 129 Episode T: 28 Reward: -2.155
# Total T: 2755 Episode Num: 130 Episode T: 18 Reward: 4.047
# Total T: 2766 Episode Num: 131 Episode T: 11 Reward: 0.638
# Total T: 2784 Episode Num: 132 Episode T: 18 Reward: 0.985
# Total T: 2796 Episode Num: 133 Episode T: 12 Reward: 1.626
# Total T: 2814 Episode Num: 134 Episode T: 18 Reward: 1.595
# Total T: 2836 Episode Num: 135 Episode T: 22 Reward: -0.748
# Total T: 2862 Episode Num: 136 Episode T: 26 Reward: -3.663
# Total T: 2877 Episode Num: 137 Episode T: 15 Reward: -0.665
# Total T: 2893 Episode Num: 138 Episode T: 16 Reward: -1.319
# Total T: 2911 Episode Num: 139 Episode T: 18 Reward: -4.334
# Total T: 2920 Episode Num: 140 Episode T: 9 Reward: -2.231
# Total T: 2957 Episode Num: 141 Episode T: 37 Reward: 1.916
# Total T: 2977 Episode Num: 142 Episode T: 20 Reward: -7.539
# Total T: 3015 Episode Num: 143 Episode T: 38 Reward: 11.741
# Total T: 3054 Episode Num: 144 Episode T: 39 Reward: -0.730
# Total T: 3071 Episode Num: 145 Episode T: 17 Reward: -2.328
# Total T: 3093 Episode Num: 146 Episode T: 22 Reward: 0.613
# Total T: 3107 Episode Num: 147 Episode T: 14 Reward: 1.201
# Total T: 3127 Episode Num: 148 Episode T: 20 Reward: 4.688
# Total T: 3141 Episode Num: 149 Episode T: 14 Reward: 0.432
# Total T: 3157 Episode Num: 150 Episode T: 16 Reward: -2.430
# Total T: 3168 Episode Num: 151 Episode T: 11 Reward: -3.701
# Total T: 3190 Episode Num: 152 Episode T: 22 Reward: 7.893
# Total T: 3206 Episode Num: 153 Episode T: 16 Reward: -0.248
# Total T: 3235 Episode Num: 154 Episode T: 29 Reward: -6.261
# Total T: 3258 Episode Num: 155 Episode T: 23 Reward: 3.304
# Total T: 3275 Episode Num: 156 Episode T: 17 Reward: 0.388
# Total T: 3319 Episode Num: 157 Episode T: 44 Reward: 11.156
# Total T: 3330 Episode Num: 158 Episode T: 11 Reward: -3.360
# Total T: 3348 Episode Num: 159 Episode T: 18 Reward: 3.251
# Total T: 3357 Episode Num: 160 Episode T: 9 Reward: -2.788
# Total T: 3367 Episode Num: 161 Episode T: 10 Reward: -0.863
# Total T: 3376 Episode Num: 162 Episode T: 9 Reward: -3.763
# Total T: 3396 Episode Num: 163 Episode T: 20 Reward: -2.009
# Total T: 3418 Episode Num: 164 Episode T: 22 Reward: 4.203
# Total T: 3434 Episode Num: 165 Episode T: 16 Reward: 4.141
# Total T: 3448 Episode Num: 166 Episode T: 14 Reward: -4.555
# Total T: 3461 Episode Num: 167 Episode T: 13 Reward: 0.323
# Total T: 3475 Episode Num: 168 Episode T: 14 Reward: -1.452
# Total T: 3485 Episode Num: 169 Episode T: 10 Reward: -1.048
# Total T: 3506 Episode Num: 170 Episode T: 21 Reward: 5.524
# Total T: 3537 Episode Num: 171 Episode T: 31 Reward: 2.586
# Total T: 3549 Episode Num: 172 Episode T: 12 Reward: -2.177
# Total T: 3574 Episode Num: 173 Episode T: 25 Reward: 5.300
# Total T: 3601 Episode Num: 174 Episode T: 27 Reward: -2.627
# Total T: 3632 Episode Num: 175 Episode T: 31 Reward: 6.138
# Total T: 3651 Episode Num: 176 Episode T: 19 Reward: 7.065
# Total T: 3665 Episode Num: 177 Episode T: 14 Reward: 3.824
# Total T: 3686 Episode Num: 178 Episode T: 21 Reward: 1.015
# Total T: 3708 Episode Num: 179 Episode T: 22 Reward: 10.356
# Total T: 3731 Episode Num: 180 Episode T: 23 Reward: -4.045
# Total T: 3744 Episode Num: 181 Episode T: 13 Reward: 0.104
# Total T: 3759 Episode Num: 182 Episode T: 15 Reward: 5.036
# Total T: 3771 Episode Num: 183 Episode T: 12 Reward: -2.429
# Total T: 3788 Episode Num: 184 Episode T: 17 Reward: 5.982
# Total T: 3807 Episode Num: 185 Episode T: 19 Reward: 2.299
# Total T: 3833 Episode Num: 186 Episode T: 26 Reward: -3.702
# Total T: 3853 Episode Num: 187 Episode T: 20 Reward: -4.767
# Total T: 3870 Episode Num: 188 Episode T: 17 Reward: 6.515
# Total T: 3884 Episode Num: 189 Episode T: 14 Reward: -4.694
# Total T: 3908 Episode Num: 190 Episode T: 24 Reward: 7.389
# Total T: 3932 Episode Num: 191 Episode T: 24 Reward: -3.086
# Total T: 3963 Episode Num: 192 Episode T: 31 Reward: 11.456
# Total T: 3984 Episode Num: 193 Episode T: 21 Reward: -2.824
# Total T: 4009 Episode Num: 194 Episode T: 25 Reward: -0.673
# Total T: 4041 Episode Num: 195 Episode T: 32 Reward: 3.470
# Total T: 4055 Episode Num: 196 Episode T: 14 Reward: -1.139
# Total T: 4068 Episode Num: 197 Episode T: 13 Reward: -0.945
# Total T: 4086 Episode Num: 198 Episode T: 18 Reward: -1.726
# Total T: 4103 Episode Num: 199 Episode T: 17 Reward: -3.293
# Total T: 4125 Episode Num: 200 Episode T: 22 Reward: -6.354
# Total T: 4138 Episode Num: 201 Episode T: 13 Reward: -0.818
# Total T: 4182 Episode Num: 202 Episode T: 44 Reward: 7.333
# Total T: 4196 Episode Num: 203 Episode T: 14 Reward: 0.382
# Total T: 4219 Episode Num: 204 Episode T: 23 Reward: 8.932
# Total T: 4232 Episode Num: 205 Episode T: 13 Reward: 2.402
# Total T: 4254 Episode Num: 206 Episode T: 22 Reward: 7.052
# Total T: 4273 Episode Num: 207 Episode T: 19 Reward: -3.721
# Total T: 4289 Episode Num: 208 Episode T: 16 Reward: 1.360
# Total T: 4312 Episode Num: 209 Episode T: 23 Reward: 8.697
# Total T: 4349 Episode Num: 210 Episode T: 37 Reward: 4.453
# Total T: 4373 Episode Num: 211 Episode T: 24 Reward: 1.223
# Total T: 4400 Episode Num: 212 Episode T: 27 Reward: 8.306
# Total T: 4425 Episode Num: 213 Episode T: 25 Reward: -0.748
# Total T: 4452 Episode Num: 214 Episode T: 27 Reward: -7.530
# Total T: 4472 Episode Num: 215 Episode T: 20 Reward: 8.186
# Total T: 4491 Episode Num: 216 Episode T: 19 Reward: 0.235
# Total T: 4506 Episode Num: 217 Episode T: 15 Reward: 2.334
# Total T: 4528 Episode Num: 218 Episode T: 22 Reward: 5.228
# Total T: 4556 Episode Num: 219 Episode T: 28 Reward: 9.360
# Total T: 4570 Episode Num: 220 Episode T: 14 Reward: 3.651
# Total T: 4588 Episode Num: 221 Episode T: 18 Reward: 6.909
# Total T: 4606 Episode Num: 222 Episode T: 18 Reward: -0.070
# Total T: 4625 Episode Num: 223 Episode T: 19 Reward: 1.844
# Total T: 4650 Episode Num: 224 Episode T: 25 Reward: 10.855
# Total T: 4669 Episode Num: 225 Episode T: 19 Reward: 1.667
# Total T: 4694 Episode Num: 226 Episode T: 25 Reward: 9.005
# Total T: 4712 Episode Num: 227 Episode T: 18 Reward: 5.158
# Total T: 4728 Episode Num: 228 Episode T: 16 Reward: -1.070
# Total T: 4752 Episode Num: 229 Episode T: 24 Reward: -1.343
# Total T: 4766 Episode Num: 230 Episode T: 14 Reward: -1.783
# Total T: 4799 Episode Num: 231 Episode T: 33 Reward: 4.387
# Total T: 4838 Episode Num: 232 Episode T: 39 Reward: 25.375
# Total T: 4852 Episode Num: 233 Episode T: 14 Reward: -0.203
# Total T: 4870 Episode Num: 234 Episode T: 18 Reward: 5.915
# Total T: 4906 Episode Num: 235 Episode T: 36 Reward: 10.870
# Total T: 4922 Episode Num: 236 Episode T: 16 Reward: 1.864
# Total T: 4952 Episode Num: 237 Episode T: 30 Reward: 10.953
# Total T: 4975 Episode Num: 238 Episode T: 23 Reward: 4.569
# ---------------------------------------
# Evaluation over 10 episodes: 2.778
# ---------------------------------------
# Total T: 5001 Episode Num: 239 Episode T: 26 Reward: 4.024
# Total T: 5021 Episode Num: 240 Episode T: 20 Reward: 5.178
# Total T: 5035 Episode Num: 241 Episode T: 14 Reward: -1.101
# Total T: 5045 Episode Num: 242 Episode T: 10 Reward: 0.914
# Total T: 5061 Episode Num: 243 Episode T: 16 Reward: 1.762
# Total T: 5074 Episode Num: 244 Episode T: 13 Reward: -1.431
# Total T: 5094 Episode Num: 245 Episode T: 20 Reward: -1.379
# Total T: 5107 Episode Num: 246 Episode T: 13 Reward: 3.135
# Total T: 5118 Episode Num: 247 Episode T: 11 Reward: -0.058
# Total T: 5134 Episode Num: 248 Episode T: 16 Reward: 4.638
# Total T: 5181 Episode Num: 249 Episode T: 47 Reward: 7.082
# Total T: 5198 Episode Num: 250 Episode T: 17 Reward: 2.933
# Total T: 5208 Episode Num: 251 Episode T: 10 Reward: -2.651
# Total T: 5221 Episode Num: 252 Episode T: 13 Reward: -4.950
# Total T: 5240 Episode Num: 253 Episode T: 19 Reward: -3.375
# Total T: 5271 Episode Num: 254 Episode T: 31 Reward: 15.092
# Total T: 5307 Episode Num: 255 Episode T: 36 Reward: 7.896
# Total T: 5325 Episode Num: 256 Episode T: 18 Reward: 2.526
# Total T: 5334 Episode Num: 257 Episode T: 9 Reward: -2.176
# Total T: 5347 Episode Num: 258 Episode T: 13 Reward: -2.447
# Total T: 5357 Episode Num: 259 Episode T: 10 Reward: -1.397
# Total T: 5383 Episode Num: 260 Episode T: 26 Reward: 10.192
# Total T: 5394 Episode Num: 261 Episode T: 11 Reward: -2.439
# Total T: 5410 Episode Num: 262 Episode T: 16 Reward: 1.622
# Total T: 5419 Episode Num: 263 Episode T: 9 Reward: -0.097
# Total T: 5442 Episode Num: 264 Episode T: 23 Reward: -0.963
# Total T: 5460 Episode Num: 265 Episode T: 18 Reward: -2.724
# Total T: 5490 Episode Num: 266 Episode T: 30 Reward: 19.246
# Total T: 5512 Episode Num: 267 Episode T: 22 Reward: -3.353
# Total T: 5524 Episode Num: 268 Episode T: 12 Reward: -2.469
# Total T: 5547 Episode Num: 269 Episode T: 23 Reward: 3.384
# Total T: 5569 Episode Num: 270 Episode T: 22 Reward: -3.463
# Total T: 5588 Episode Num: 271 Episode T: 19 Reward: 5.927
# Total T: 5614 Episode Num: 272 Episode T: 26 Reward: 0.150
# Total T: 5645 Episode Num: 273 Episode T: 31 Reward: 1.089
# Total T: 5667 Episode Num: 274 Episode T: 22 Reward: 6.997
# Total T: 5700 Episode Num: 275 Episode T: 33 Reward: -0.460
# Total T: 5717 Episode Num: 276 Episode T: 17 Reward: 1.359
# Total T: 5732 Episode Num: 277 Episode T: 15 Reward: -1.247
# Total T: 5749 Episode Num: 278 Episode T: 17 Reward: 7.487
# Total T: 5757 Episode Num: 279 Episode T: 8 Reward: -4.449
# Total T: 5775 Episode Num: 280 Episode T: 18 Reward: -5.570
# Total T: 5793 Episode Num: 281 Episode T: 18 Reward: 1.096
# Total T: 5815 Episode Num: 282 Episode T: 22 Reward: 3.788
# Total T: 5843 Episode Num: 283 Episode T: 28 Reward: 5.568
# Total T: 5853 Episode Num: 284 Episode T: 10 Reward: -1.379
# Total T: 5877 Episode Num: 285 Episode T: 24 Reward: 7.184
# Total T: 5911 Episode Num: 286 Episode T: 34 Reward: 2.713
# Total T: 5924 Episode Num: 287 Episode T: 13 Reward: -0.829
# Total T: 5943 Episode Num: 288 Episode T: 19 Reward: -4.762
# Total T: 5956 Episode Num: 289 Episode T: 13 Reward: 3.783
# Total T: 5984 Episode Num: 290 Episode T: 28 Reward: 0.875
# Total T: 6004 Episode Num: 291 Episode T: 20 Reward: -6.211
# Total T: 6020 Episode Num: 292 Episode T: 16 Reward: 2.624
# Total T: 6038 Episode Num: 293 Episode T: 18 Reward: -13.402
# Total T: 6051 Episode Num: 294 Episode T: 13 Reward: 0.188
# Total T: 6067 Episode Num: 295 Episode T: 16 Reward: 5.040
# Total T: 6078 Episode Num: 296 Episode T: 11 Reward: -0.263
# Total T: 6100 Episode Num: 297 Episode T: 22 Reward: 4.841
# Total T: 6114 Episode Num: 298 Episode T: 14 Reward: 3.620
# Total T: 6127 Episode Num: 299 Episode T: 13 Reward: -6.049
# Total T: 6142 Episode Num: 300 Episode T: 15 Reward: -1.098
# Total T: 6168 Episode Num: 301 Episode T: 26 Reward: 10.343
# Total T: 6183 Episode Num: 302 Episode T: 15 Reward: 2.883
# Total T: 6196 Episode Num: 303 Episode T: 13 Reward: -1.734
# Total T: 6215 Episode Num: 304 Episode T: 19 Reward: 5.449
# Total T: 6239 Episode Num: 305 Episode T: 24 Reward: 8.943
# Total T: 6258 Episode Num: 306 Episode T: 19 Reward: 1.232
# Total T: 6278 Episode Num: 307 Episode T: 20 Reward: 7.142
# Total T: 6305 Episode Num: 308 Episode T: 27 Reward: -0.431
# Total T: 6326 Episode Num: 309 Episode T: 21 Reward: -0.789
# Total T: 6348 Episode Num: 310 Episode T: 22 Reward: 0.129
# Total T: 6368 Episode Num: 311 Episode T: 20 Reward: 5.091
# Total T: 6385 Episode Num: 312 Episode T: 17 Reward: 2.957
# Total T: 6393 Episode Num: 313 Episode T: 8 Reward: -0.969
# Total T: 6413 Episode Num: 314 Episode T: 20 Reward: -1.082
# Total T: 6441 Episode Num: 315 Episode T: 28 Reward: -3.169
# Total T: 6462 Episode Num: 316 Episode T: 21 Reward: 6.946
# Total T: 6479 Episode Num: 317 Episode T: 17 Reward: 1.654
# Total T: 6495 Episode Num: 318 Episode T: 16 Reward: 1.065
# Total T: 6547 Episode Num: 319 Episode T: 52 Reward: -0.938
# Total T: 6562 Episode Num: 320 Episode T: 15 Reward: 3.107
# Total T: 6591 Episode Num: 321 Episode T: 29 Reward: -0.809
# Total T: 6604 Episode Num: 322 Episode T: 13 Reward: 0.279
# Total T: 6623 Episode Num: 323 Episode T: 19 Reward: -2.782
# Total T: 6657 Episode Num: 324 Episode T: 34 Reward: 15.606
# Total T: 6671 Episode Num: 325 Episode T: 14 Reward: -0.832
# Total T: 6684 Episode Num: 326 Episode T: 13 Reward: 1.484
# Total T: 6696 Episode Num: 327 Episode T: 12 Reward: 1.066
# Total T: 6717 Episode Num: 328 Episode T: 21 Reward: -1.522
# Total T: 6729 Episode Num: 329 Episode T: 12 Reward: -1.464
# Total T: 6742 Episode Num: 330 Episode T: 13 Reward: -0.294
# Total T: 6753 Episode Num: 331 Episode T: 11 Reward: -1.190
# Total T: 6768 Episode Num: 332 Episode T: 15 Reward: 0.433
# Total T: 6801 Episode Num: 333 Episode T: 33 Reward: 4.240
# Total T: 6830 Episode Num: 334 Episode T: 29 Reward: 1.163
# Total T: 6860 Episode Num: 335 Episode T: 30 Reward: -3.326
# Total T: 6887 Episode Num: 336 Episode T: 27 Reward: -7.004
# Total T: 6904 Episode Num: 337 Episode T: 17 Reward: 0.081
# Total T: 6917 Episode Num: 338 Episode T: 13 Reward: 3.878
# Total T: 6935 Episode Num: 339 Episode T: 18 Reward: 0.217
# Total T: 6951 Episode Num: 340 Episode T: 16 Reward: 2.738
# Total T: 6962 Episode Num: 341 Episode T: 11 Reward: -1.482
# Total T: 6978 Episode Num: 342 Episode T: 16 Reward: -7.186
# Total T: 7009 Episode Num: 343 Episode T: 31 Reward: 12.454
# Total T: 7019 Episode Num: 344 Episode T: 10 Reward: 1.430
# Total T: 7033 Episode Num: 345 Episode T: 14 Reward: 2.088
# Total T: 7045 Episode Num: 346 Episode T: 12 Reward: 2.200
# Total T: 7062 Episode Num: 347 Episode T: 17 Reward: -0.608
# Total T: 7071 Episode Num: 348 Episode T: 9 Reward: -3.315
# Total T: 7104 Episode Num: 349 Episode T: 33 Reward: 1.631
# Total T: 7123 Episode Num: 350 Episode T: 19 Reward: 9.239
# Total T: 7139 Episode Num: 351 Episode T: 16 Reward: -3.745
# Total T: 7163 Episode Num: 352 Episode T: 24 Reward: 4.257
# Total T: 7178 Episode Num: 353 Episode T: 15 Reward: 1.829
# Total T: 7202 Episode Num: 354 Episode T: 24 Reward: 0.407
# Total T: 7214 Episode Num: 355 Episode T: 12 Reward: -3.480
# Total T: 7233 Episode Num: 356 Episode T: 19 Reward: 2.273
# Total T: 7248 Episode Num: 357 Episode T: 15 Reward: 1.062
# Total T: 7262 Episode Num: 358 Episode T: 14 Reward: -0.917
# Total T: 7287 Episode Num: 359 Episode T: 25 Reward: 7.795
# Total T: 7304 Episode Num: 360 Episode T: 17 Reward: -1.000
# Total T: 7319 Episode Num: 361 Episode T: 15 Reward: 0.039
# Total T: 7343 Episode Num: 362 Episode T: 24 Reward: 1.044
# Total T: 7361 Episode Num: 363 Episode T: 18 Reward: -1.518
# Total T: 7372 Episode Num: 364 Episode T: 11 Reward: -2.145
# Total T: 7406 Episode Num: 365 Episode T: 34 Reward: 6.999
# Total T: 7428 Episode Num: 366 Episode T: 22 Reward: -3.873
# Total T: 7471 Episode Num: 367 Episode T: 43 Reward: 7.671
# Total T: 7490 Episode Num: 368 Episode T: 19 Reward: -5.108
# Total T: 7502 Episode Num: 369 Episode T: 12 Reward: -0.522
# Total T: 7519 Episode Num: 370 Episode T: 17 Reward: 5.210
# Total T: 7537 Episode Num: 371 Episode T: 18 Reward: -2.438
# Total T: 7546 Episode Num: 372 Episode T: 9 Reward: -0.114
# Total T: 7573 Episode Num: 373 Episode T: 27 Reward: -0.256
# Total T: 7586 Episode Num: 374 Episode T: 13 Reward: 0.538
# Total T: 7612 Episode Num: 375 Episode T: 26 Reward: 4.607
# Total T: 7631 Episode Num: 376 Episode T: 19 Reward: 4.367
# Total T: 7643 Episode Num: 377 Episode T: 12 Reward: -2.593
# Total T: 7658 Episode Num: 378 Episode T: 15 Reward: -4.218
# Total T: 7672 Episode Num: 379 Episode T: 14 Reward: 2.255
# Total T: 7700 Episode Num: 380 Episode T: 28 Reward: 13.542
# Total T: 7720 Episode Num: 381 Episode T: 20 Reward: -4.495
# Total T: 7749 Episode Num: 382 Episode T: 29 Reward: -8.617
# Total T: 7769 Episode Num: 383 Episode T: 20 Reward: -2.375
# Total T: 7793 Episode Num: 384 Episode T: 24 Reward: -1.976
# Total T: 7805 Episode Num: 385 Episode T: 12 Reward: 1.978
# Total T: 7836 Episode Num: 386 Episode T: 31 Reward: 5.916
# Total T: 7853 Episode Num: 387 Episode T: 17 Reward: 3.090
# Total T: 7870 Episode Num: 388 Episode T: 17 Reward: 5.867
# Total T: 7886 Episode Num: 389 Episode T: 16 Reward: -5.557
# Total T: 7897 Episode Num: 390 Episode T: 11 Reward: -9.092
# Total T: 7909 Episode Num: 391 Episode T: 12 Reward: 0.235
# Total T: 7924 Episode Num: 392 Episode T: 15 Reward: -0.089
# Total T: 7949 Episode Num: 393 Episode T: 25 Reward: 8.985
# Total T: 7971 Episode Num: 394 Episode T: 22 Reward: -2.556
# Total T: 7988 Episode Num: 395 Episode T: 17 Reward: 1.336
# Total T: 8023 Episode Num: 396 Episode T: 35 Reward: 11.381
# Total T: 8049 Episode Num: 397 Episode T: 26 Reward: 3.935
# Total T: 8063 Episode Num: 398 Episode T: 14 Reward: 2.648
# Total T: 8076 Episode Num: 399 Episode T: 13 Reward: 0.238
# Total T: 8095 Episode Num: 400 Episode T: 19 Reward: -1.675
# Total T: 8110 Episode Num: 401 Episode T: 15 Reward: 2.095
# Total T: 8120 Episode Num: 402 Episode T: 10 Reward: -1.393
# Total T: 8133 Episode Num: 403 Episode T: 13 Reward: -0.053
# Total T: 8149 Episode Num: 404 Episode T: 16 Reward: 2.581
# Total T: 8159 Episode Num: 405 Episode T: 10 Reward: -1.900
# Total T: 8175 Episode Num: 406 Episode T: 16 Reward: 2.732
# Total T: 8192 Episode Num: 407 Episode T: 17 Reward: -3.370
# Total T: 8218 Episode Num: 408 Episode T: 26 Reward: -3.041
# Total T: 8240 Episode Num: 409 Episode T: 22 Reward: 0.794
# Total T: 8253 Episode Num: 410 Episode T: 13 Reward: -0.934
# Total T: 8266 Episode Num: 411 Episode T: 13 Reward: 2.138
# Total T: 8283 Episode Num: 412 Episode T: 17 Reward: -1.460
# Total T: 8297 Episode Num: 413 Episode T: 14 Reward: 4.043
# Total T: 8314 Episode Num: 414 Episode T: 17 Reward: 3.204
# Total T: 8324 Episode Num: 415 Episode T: 10 Reward: -3.346
# Total T: 8338 Episode Num: 416 Episode T: 14 Reward: 1.032
# Total T: 8356 Episode Num: 417 Episode T: 18 Reward: 1.500
# Total T: 8379 Episode Num: 418 Episode T: 23 Reward: 2.296
# Total T: 8395 Episode Num: 419 Episode T: 16 Reward: -2.542
# Total T: 8427 Episode Num: 420 Episode T: 32 Reward: 7.447
# Total T: 8441 Episode Num: 421 Episode T: 14 Reward: 3.325
# Total T: 8457 Episode Num: 422 Episode T: 16 Reward: 2.715
# Total T: 8470 Episode Num: 423 Episode T: 13 Reward: -0.795
# Total T: 8488 Episode Num: 424 Episode T: 18 Reward: 0.932
# Total T: 8501 Episode Num: 425 Episode T: 13 Reward: -1.247
# Total T: 8516 Episode Num: 426 Episode T: 15 Reward: -4.530
# Total T: 8528 Episode Num: 427 Episode T: 12 Reward: -0.693
# Total T: 8549 Episode Num: 428 Episode T: 21 Reward: 1.912
# Total T: 8556 Episode Num: 429 Episode T: 7 Reward: -3.572
# Total T: 8567 Episode Num: 430 Episode T: 11 Reward: -0.460
# Total T: 8591 Episode Num: 431 Episode T: 24 Reward: 3.405
# Total T: 8613 Episode Num: 432 Episode T: 22 Reward: 3.256
# Total T: 8639 Episode Num: 433 Episode T: 26 Reward: 13.353
# Total T: 8672 Episode Num: 434 Episode T: 33 Reward: 4.822
# Total T: 8692 Episode Num: 435 Episode T: 20 Reward: 4.625
# Total T: 8719 Episode Num: 436 Episode T: 27 Reward: 2.612
# Total T: 8741 Episode Num: 437 Episode T: 22 Reward: -2.218
# Total T: 8754 Episode Num: 438 Episode T: 13 Reward: -1.205
# Total T: 8765 Episode Num: 439 Episode T: 11 Reward: -1.235
# Total T: 8795 Episode Num: 440 Episode T: 30 Reward: -1.846
# Total T: 8809 Episode Num: 441 Episode T: 14 Reward: -6.529
# Total T: 8826 Episode Num: 442 Episode T: 17 Reward: 3.752
# Total T: 8840 Episode Num: 443 Episode T: 14 Reward: -0.916
# Total T: 8851 Episode Num: 444 Episode T: 11 Reward: -2.097
# Total T: 8875 Episode Num: 445 Episode T: 24 Reward: 7.064
# Total T: 8887 Episode Num: 446 Episode T: 12 Reward: -0.486
# Total T: 8924 Episode Num: 447 Episode T: 37 Reward: 6.105
# Total T: 8939 Episode Num: 448 Episode T: 15 Reward: -1.433
# Total T: 8961 Episode Num: 449 Episode T: 22 Reward: -10.797
# Total T: 8986 Episode Num: 450 Episode T: 25 Reward: -1.926
# Total T: 9000 Episode Num: 451 Episode T: 14 Reward: -0.179
# Total T: 9012 Episode Num: 452 Episode T: 12 Reward: -1.038
# Total T: 9038 Episode Num: 453 Episode T: 26 Reward: -4.109
# Total T: 9075 Episode Num: 454 Episode T: 37 Reward: -0.727
# Total T: 9090 Episode Num: 455 Episode T: 15 Reward: -6.276
# Total T: 9108 Episode Num: 456 Episode T: 18 Reward: 9.415
# Total T: 9143 Episode Num: 457 Episode T: 35 Reward: 4.835
# Total T: 9160 Episode Num: 458 Episode T: 17 Reward: 6.024
# Total T: 9179 Episode Num: 459 Episode T: 19 Reward: -2.557
# Total T: 9201 Episode Num: 460 Episode T: 22 Reward: -0.487
# Total T: 9246 Episode Num: 461 Episode T: 45 Reward: 25.599
# Total T: 9263 Episode Num: 462 Episode T: 17 Reward: 3.858
# Total T: 9276 Episode Num: 463 Episode T: 13 Reward: 1.048
# Total T: 9304 Episode Num: 464 Episode T: 28 Reward: 2.388
# Total T: 9321 Episode Num: 465 Episode T: 17 Reward: 2.311
# Total T: 9334 Episode Num: 466 Episode T: 13 Reward: 0.843
# Total T: 9350 Episode Num: 467 Episode T: 16 Reward: 3.125
# Total T: 9364 Episode Num: 468 Episode T: 14 Reward: 1.504
# Total T: 9387 Episode Num: 469 Episode T: 23 Reward: -2.119
# Total T: 9402 Episode Num: 470 Episode T: 15 Reward: -2.917
# Total T: 9415 Episode Num: 471 Episode T: 13 Reward: -4.434
# Total T: 9440 Episode Num: 472 Episode T: 25 Reward: -4.190
# Total T: 9465 Episode Num: 473 Episode T: 25 Reward: 3.966
# Total T: 9479 Episode Num: 474 Episode T: 14 Reward: -6.838
# Total T: 9492 Episode Num: 475 Episode T: 13 Reward: -1.993
# Total T: 9510 Episode Num: 476 Episode T: 18 Reward: 6.379
# Total T: 9532 Episode Num: 477 Episode T: 22 Reward: 6.652
# Total T: 9563 Episode Num: 478 Episode T: 31 Reward: 4.738
# Total T: 9583 Episode Num: 479 Episode T: 20 Reward: 2.271
# Total T: 9610 Episode Num: 480 Episode T: 27 Reward: 8.669
# Total T: 9625 Episode Num: 481 Episode T: 15 Reward: 5.099
# Total T: 9635 Episode Num: 482 Episode T: 10 Reward: -2.401
# Total T: 9649 Episode Num: 483 Episode T: 14 Reward: 2.613
# Total T: 9665 Episode Num: 484 Episode T: 16 Reward: -0.843
# Total T: 9681 Episode Num: 485 Episode T: 16 Reward: -0.777
# Total T: 9698 Episode Num: 486 Episode T: 17 Reward: 0.769
# Total T: 9717 Episode Num: 487 Episode T: 19 Reward: -1.595
# Total T: 9732 Episode Num: 488 Episode T: 15 Reward: 3.169
# Total T: 9764 Episode Num: 489 Episode T: 32 Reward: 10.329
# Total T: 9781 Episode Num: 490 Episode T: 17 Reward: 1.757
# Total T: 9800 Episode Num: 491 Episode T: 19 Reward: -2.677
# Total T: 9822 Episode Num: 492 Episode T: 22 Reward: -1.667
# Total T: 9843 Episode Num: 493 Episode T: 21 Reward: -5.454
# Total T: 9855 Episode Num: 494 Episode T: 12 Reward: -4.197
# Total T: 9871 Episode Num: 495 Episode T: 16 Reward: -3.083
# Total T: 9885 Episode Num: 496 Episode T: 14 Reward: -7.886
# Total T: 9908 Episode Num: 497 Episode T: 23 Reward: -0.131
# Total T: 9919 Episode Num: 498 Episode T: 11 Reward: -3.321
# Total T: 9934 Episode Num: 499 Episode T: 15 Reward: -3.015
# Total T: 9953 Episode Num: 500 Episode T: 19 Reward: 4.109
# Total T: 9971 Episode Num: 501 Episode T: 18 Reward: -2.174
# ---------------------------------------
# Evaluation over 10 episodes: 2.778
# ---------------------------------------
# Total T: 10003 Episode Num: 502 Episode T: 32 Reward: 1.694
# Total T: 10014 Episode Num: 503 Episode T: 11 Reward: -1.698
# Total T: 10036 Episode Num: 504 Episode T: 22 Reward: 13.954
# Total T: 10062 Episode Num: 505 Episode T: 26 Reward: 1.660
# Total T: 10080 Episode Num: 506 Episode T: 18 Reward: 1.901
# Total T: 10093 Episode Num: 507 Episode T: 13 Reward: 3.328
# Total T: 10110 Episode Num: 508 Episode T: 17 Reward: 2.045
# Total T: 10122 Episode Num: 509 Episode T: 12 Reward: -1.563
# Total T: 10141 Episode Num: 510 Episode T: 19 Reward: 0.920
# Total T: 10164 Episode Num: 511 Episode T: 23 Reward: 10.266
# Total T: 10190 Episode Num: 512 Episode T: 26 Reward: 3.012
# Total T: 10206 Episode Num: 513 Episode T: 16 Reward: 1.117
# Total T: 10222 Episode Num: 514 Episode T: 16 Reward: 0.637
# Total T: 10242 Episode Num: 515 Episode T: 20 Reward: 5.862
# Total T: 10256 Episode Num: 516 Episode T: 14 Reward: -2.059
# Total T: 10291 Episode Num: 517 Episode T: 35 Reward: 0.248
# Total T: 10310 Episode Num: 518 Episode T: 19 Reward: 5.179
# Total T: 10329 Episode Num: 519 Episode T: 19 Reward: -5.889
# Total T: 10345 Episode Num: 520 Episode T: 16 Reward: 2.234
# Total T: 10364 Episode Num: 521 Episode T: 19 Reward: 5.301
# Total T: 10379 Episode Num: 522 Episode T: 15 Reward: -1.236
# Total T: 10403 Episode Num: 523 Episode T: 24 Reward: 5.120
# Total T: 10419 Episode Num: 524 Episode T: 16 Reward: 4.882
# Total T: 10432 Episode Num: 525 Episode T: 13 Reward: 1.418
# Total T: 10450 Episode Num: 526 Episode T: 18 Reward: 7.853
# Total T: 10474 Episode Num: 527 Episode T: 24 Reward: -0.383
# Total T: 10496 Episode Num: 528 Episode T: 22 Reward: -13.701
# Total T: 10509 Episode Num: 529 Episode T: 13 Reward: -5.006
# Total T: 10531 Episode Num: 530 Episode T: 22 Reward: 6.837
# Total T: 10559 Episode Num: 531 Episode T: 28 Reward: 9.317
# Total T: 10575 Episode Num: 532 Episode T: 16 Reward: 1.125
# Total T: 10592 Episode Num: 533 Episode T: 17 Reward: 4.335
# Total T: 10608 Episode Num: 534 Episode T: 16 Reward: 0.917
# Total T: 10624 Episode Num: 535 Episode T: 16 Reward: -2.419
# Total T: 10656 Episode Num: 536 Episode T: 32 Reward: -1.446
# Total T: 10668 Episode Num: 537 Episode T: 12 Reward: -2.502
# Total T: 10680 Episode Num: 538 Episode T: 12 Reward: 0.473
# Total T: 10695 Episode Num: 539 Episode T: 15 Reward: 0.438
# Total T: 10718 Episode Num: 540 Episode T: 23 Reward: 10.080
# Total T: 10742 Episode Num: 541 Episode T: 24 Reward: 5.553
# Total T: 10767 Episode Num: 542 Episode T: 25 Reward: 2.658
# Total T: 10784 Episode Num: 543 Episode T: 17 Reward: 3.636
# Total T: 10812 Episode Num: 544 Episode T: 28 Reward: 1.513
# Total T: 10827 Episode Num: 545 Episode T: 15 Reward: 4.529
# Total T: 10853 Episode Num: 546 Episode T: 26 Reward: 6.694
# Total T: 10888 Episode Num: 547 Episode T: 35 Reward: -4.049
# Total T: 10914 Episode Num: 548 Episode T: 26 Reward: -1.835
# Total T: 10928 Episode Num: 549 Episode T: 14 Reward: -5.186
# Total T: 10955 Episode Num: 550 Episode T: 27 Reward: 0.978
# Total T: 10983 Episode Num: 551 Episode T: 28 Reward: -1.729
# Total T: 10995 Episode Num: 552 Episode T: 12 Reward: -0.760
# Total T: 11019 Episode Num: 553 Episode T: 24 Reward: 6.993
# Total T: 11035 Episode Num: 554 Episode T: 16 Reward: 2.130
# Total T: 11055 Episode Num: 555 Episode T: 20 Reward: -1.940
# Total T: 11069 Episode Num: 556 Episode T: 14 Reward: 2.068
# Total T: 11091 Episode Num: 557 Episode T: 22 Reward: -1.896
# Total T: 11106 Episode Num: 558 Episode T: 15 Reward: 2.578
# Total T: 11134 Episode Num: 559 Episode T: 28 Reward: -1.724
# Total T: 11187 Episode Num: 560 Episode T: 53 Reward: 5.568
# Total T: 11201 Episode Num: 561 Episode T: 14 Reward: 2.212
# Total T: 11223 Episode Num: 562 Episode T: 22 Reward: -4.343
# Total T: 11260 Episode Num: 563 Episode T: 37 Reward: 12.025
# Total T: 11281 Episode Num: 564 Episode T: 21 Reward: 7.593
# Total T: 11302 Episode Num: 565 Episode T: 21 Reward: -7.765
# Total T: 11321 Episode Num: 566 Episode T: 19 Reward: -4.540
# Total T: 11353 Episode Num: 567 Episode T: 32 Reward: 8.846
# Total T: 11366 Episode Num: 568 Episode T: 13 Reward: 0.022
# Total T: 11381 Episode Num: 569 Episode T: 15 Reward: -4.678
# Total T: 11415 Episode Num: 570 Episode T: 34 Reward: 20.188
# Total T: 11430 Episode Num: 571 Episode T: 15 Reward: -1.628
# Total T: 11449 Episode Num: 572 Episode T: 19 Reward: 1.332
# Total T: 11480 Episode Num: 573 Episode T: 31 Reward: 17.731
# Total T: 11498 Episode Num: 574 Episode T: 18 Reward: 4.217
# Total T: 11507 Episode Num: 575 Episode T: 9 Reward: -3.058
# Total T: 11525 Episode Num: 576 Episode T: 18 Reward: -3.438
# Total T: 11552 Episode Num: 577 Episode T: 27 Reward: 6.910
# Total T: 11569 Episode Num: 578 Episode T: 17 Reward: -0.630
# Total T: 11610 Episode Num: 579 Episode T: 41 Reward: 14.366
# Total T: 11628 Episode Num: 580 Episode T: 18 Reward: -6.872
# Total T: 11648 Episode Num: 581 Episode T: 20 Reward: -1.025
# Total T: 11664 Episode Num: 582 Episode T: 16 Reward: 1.396
# Total T: 11682 Episode Num: 583 Episode T: 18 Reward: 2.866
# Total T: 11693 Episode Num: 584 Episode T: 11 Reward: 0.770
# Total T: 11704 Episode Num: 585 Episode T: 11 Reward: 0.061
# Total T: 11728 Episode Num: 586 Episode T: 24 Reward: -1.700
# Total T: 11750 Episode Num: 587 Episode T: 22 Reward: -4.826
# Total T: 11762 Episode Num: 588 Episode T: 12 Reward: 0.653
# Total T: 11809 Episode Num: 589 Episode T: 47 Reward: 17.252
# Total T: 11821 Episode Num: 590 Episode T: 12 Reward: -0.997
# Total T: 11830 Episode Num: 591 Episode T: 9 Reward: -0.430
# Total T: 11846 Episode Num: 592 Episode T: 16 Reward: -1.682
# Total T: 11866 Episode Num: 593 Episode T: 20 Reward: 1.718
# Total T: 11885 Episode Num: 594 Episode T: 19 Reward: 1.718
# Total T: 11909 Episode Num: 595 Episode T: 24 Reward: -2.490
# Total T: 11918 Episode Num: 596 Episode T: 9 Reward: 0.345
# Total T: 11935 Episode Num: 597 Episode T: 17 Reward: 4.056
# Total T: 11951 Episode Num: 598 Episode T: 16 Reward: 3.044
# Total T: 11963 Episode Num: 599 Episode T: 12 Reward: -2.976
# Total T: 11986 Episode Num: 600 Episode T: 23 Reward: 2.825
# Total T: 12005 Episode Num: 601 Episode T: 19 Reward: -5.470
# Total T: 12021 Episode Num: 602 Episode T: 16 Reward: 6.102
# Total T: 12034 Episode Num: 603 Episode T: 13 Reward: -0.750
# Total T: 12059 Episode Num: 604 Episode T: 25 Reward: 2.341
# Total T: 12076 Episode Num: 605 Episode T: 17 Reward: -3.021
# Total T: 12101 Episode Num: 606 Episode T: 25 Reward: -4.769
# Total T: 12116 Episode Num: 607 Episode T: 15 Reward: 0.167
# Total T: 12127 Episode Num: 608 Episode T: 11 Reward: -4.328
# Total T: 12144 Episode Num: 609 Episode T: 17 Reward: 5.215
# Total T: 12158 Episode Num: 610 Episode T: 14 Reward: -5.108
# Total T: 12179 Episode Num: 611 Episode T: 21 Reward: 5.647
# Total T: 12194 Episode Num: 612 Episode T: 15 Reward: -1.899
# Total T: 12212 Episode Num: 613 Episode T: 18 Reward: -0.781
# Total T: 12240 Episode Num: 614 Episode T: 28 Reward: 10.299
# Total T: 12261 Episode Num: 615 Episode T: 21 Reward: -1.727
# Total T: 12281 Episode Num: 616 Episode T: 20 Reward: 2.863
# Total T: 12293 Episode Num: 617 Episode T: 12 Reward: -0.699
# Total T: 12303 Episode Num: 618 Episode T: 10 Reward: -4.695
# Total T: 12325 Episode Num: 619 Episode T: 22 Reward: -3.700
# Total T: 12337 Episode Num: 620 Episode T: 12 Reward: 1.089
# Total T: 12349 Episode Num: 621 Episode T: 12 Reward: -1.562
# Total T: 12361 Episode Num: 622 Episode T: 12 Reward: 1.984
# Total T: 12388 Episode Num: 623 Episode T: 27 Reward: -0.009
# Total T: 12408 Episode Num: 624 Episode T: 20 Reward: -6.519
# Total T: 12443 Episode Num: 625 Episode T: 35 Reward: 14.133
# Total T: 12467 Episode Num: 626 Episode T: 24 Reward: -6.924
# Total T: 12488 Episode Num: 627 Episode T: 21 Reward: 2.632
# Total T: 12505 Episode Num: 628 Episode T: 17 Reward: 4.175
# Total T: 12551 Episode Num: 629 Episode T: 46 Reward: 9.651
# Total T: 12583 Episode Num: 630 Episode T: 32 Reward: 9.380
# Total T: 12596 Episode Num: 631 Episode T: 13 Reward: 3.013
# Total T: 12612 Episode Num: 632 Episode T: 16 Reward: 2.581
# Total T: 12630 Episode Num: 633 Episode T: 18 Reward: 2.062
# Total T: 12640 Episode Num: 634 Episode T: 10 Reward: -4.787
# Total T: 12657 Episode Num: 635 Episode T: 17 Reward: 4.100
# Total T: 12669 Episode Num: 636 Episode T: 12 Reward: 1.306
# Total T: 12689 Episode Num: 637 Episode T: 20 Reward: -6.428
# Total T: 12727 Episode Num: 638 Episode T: 38 Reward: -3.960
# Total T: 12747 Episode Num: 639 Episode T: 20 Reward: -9.526
# Total T: 12759 Episode Num: 640 Episode T: 12 Reward: -4.187
# Total T: 12777 Episode Num: 641 Episode T: 18 Reward: 2.302
# Total T: 12787 Episode Num: 642 Episode T: 10 Reward: -3.975
# Total T: 12808 Episode Num: 643 Episode T: 21 Reward: 0.490
# Total T: 12822 Episode Num: 644 Episode T: 14 Reward: -1.199
# Total T: 12853 Episode Num: 645 Episode T: 31 Reward: -4.070
# Total T: 12881 Episode Num: 646 Episode T: 28 Reward: 1.564
# Total T: 12893 Episode Num: 647 Episode T: 12 Reward: -1.362
# Total T: 12903 Episode Num: 648 Episode T: 10 Reward: -0.471
# Total T: 12935 Episode Num: 649 Episode T: 32 Reward: 6.343
# Total T: 12955 Episode Num: 650 Episode T: 20 Reward: 4.266
# Total T: 12986 Episode Num: 651 Episode T: 31 Reward: 0.836
# Total T: 13012 Episode Num: 652 Episode T: 26 Reward: 5.817
# Total T: 13026 Episode Num: 653 Episode T: 14 Reward: -4.986
# Total T: 13051 Episode Num: 654 Episode T: 25 Reward: 11.413
# Total T: 13072 Episode Num: 655 Episode T: 21 Reward: 2.705
# Total T: 13103 Episode Num: 656 Episode T: 31 Reward: 1.974
# Total T: 13127 Episode Num: 657 Episode T: 24 Reward: -1.227
# Total T: 13153 Episode Num: 658 Episode T: 26 Reward: 8.563
# Total T: 13172 Episode Num: 659 Episode T: 19 Reward: 5.578
# Total T: 13202 Episode Num: 660 Episode T: 30 Reward: 14.540
# Total T: 13233 Episode Num: 661 Episode T: 31 Reward: 12.922
# Total T: 13249 Episode Num: 662 Episode T: 16 Reward: 0.855
# Total T: 13282 Episode Num: 663 Episode T: 33 Reward: 3.484
# Total T: 13295 Episode Num: 664 Episode T: 13 Reward: -1.729
# Total T: 13312 Episode Num: 665 Episode T: 17 Reward: 3.665
# Total T: 13337 Episode Num: 666 Episode T: 25 Reward: -5.138
# Total T: 13365 Episode Num: 667 Episode T: 28 Reward: 3.108
# Total T: 13394 Episode Num: 668 Episode T: 29 Reward: 5.651
# Total T: 13414 Episode Num: 669 Episode T: 20 Reward: 0.191
# Total T: 13441 Episode Num: 670 Episode T: 27 Reward: 4.428
# Total T: 13459 Episode Num: 671 Episode T: 18 Reward: 2.872
# Total T: 13475 Episode Num: 672 Episode T: 16 Reward: -3.530
# Total T: 13496 Episode Num: 673 Episode T: 21 Reward: 8.262
# Total T: 13515 Episode Num: 674 Episode T: 19 Reward: -0.184
# Total T: 13531 Episode Num: 675 Episode T: 16 Reward: 4.659
# Total T: 13559 Episode Num: 676 Episode T: 28 Reward: 0.527
# Total T: 13588 Episode Num: 677 Episode T: 29 Reward: -7.798
# Total T: 13612 Episode Num: 678 Episode T: 24 Reward: 7.870
# Total T: 13635 Episode Num: 679 Episode T: 23 Reward: 11.485
# Total T: 13657 Episode Num: 680 Episode T: 22 Reward: -4.649
# Total T: 13675 Episode Num: 681 Episode T: 18 Reward: -1.860
# Total T: 13691 Episode Num: 682 Episode T: 16 Reward: -6.932
# Total T: 13713 Episode Num: 683 Episode T: 22 Reward: 2.599
# Total T: 13741 Episode Num: 684 Episode T: 28 Reward: -1.059
# Total T: 13760 Episode Num: 685 Episode T: 19 Reward: -5.090
# Total T: 13776 Episode Num: 686 Episode T: 16 Reward: -1.873
# Total T: 13800 Episode Num: 687 Episode T: 24 Reward: -3.784
# Total T: 13812 Episode Num: 688 Episode T: 12 Reward: 1.487
# Total T: 13823 Episode Num: 689 Episode T: 11 Reward: -0.879
# Total T: 13848 Episode Num: 690 Episode T: 25 Reward: 1.816
# Total T: 13862 Episode Num: 691 Episode T: 14 Reward: 3.605
# Total T: 13881 Episode Num: 692 Episode T: 19 Reward: 1.233
# Total T: 13894 Episode Num: 693 Episode T: 13 Reward: -0.412
# Total T: 13918 Episode Num: 694 Episode T: 24 Reward: -5.346
# Total T: 13932 Episode Num: 695 Episode T: 14 Reward: 3.544
# Total T: 13948 Episode Num: 696 Episode T: 16 Reward: 3.810
# Total T: 13961 Episode Num: 697 Episode T: 13 Reward: 0.225
# Total T: 13983 Episode Num: 698 Episode T: 22 Reward: 5.579
# Total T: 14002 Episode Num: 699 Episode T: 19 Reward: 1.149
# Total T: 14020 Episode Num: 700 Episode T: 18 Reward: 1.331
# Total T: 14033 Episode Num: 701 Episode T: 13 Reward: 3.006
# Total T: 14057 Episode Num: 702 Episode T: 24 Reward: 0.091
# Total T: 14074 Episode Num: 703 Episode T: 17 Reward: -0.380
# Total T: 14106 Episode Num: 704 Episode T: 32 Reward: 0.415
# Total T: 14123 Episode Num: 705 Episode T: 17 Reward: -0.896
# Total T: 14137 Episode Num: 706 Episode T: 14 Reward: 4.938
# Total T: 14162 Episode Num: 707 Episode T: 25 Reward: 4.206
# Total T: 14174 Episode Num: 708 Episode T: 12 Reward: -2.987
# Total T: 14194 Episode Num: 709 Episode T: 20 Reward: -3.920
# Total T: 14209 Episode Num: 710 Episode T: 15 Reward: 2.401
# Total T: 14236 Episode Num: 711 Episode T: 27 Reward: -1.199
# Total T: 14248 Episode Num: 712 Episode T: 12 Reward: -1.194
# Total T: 14264 Episode Num: 713 Episode T: 16 Reward: 1.144
# Total T: 14281 Episode Num: 714 Episode T: 17 Reward: 5.844
# Total T: 14299 Episode Num: 715 Episode T: 18 Reward: -5.716
# Total T: 14322 Episode Num: 716 Episode T: 23 Reward: -2.268
# Total T: 14336 Episode Num: 717 Episode T: 14 Reward: 0.751
# Total T: 14360 Episode Num: 718 Episode T: 24 Reward: 0.388
# Total T: 14389 Episode Num: 719 Episode T: 29 Reward: -6.244
# Total T: 14409 Episode Num: 720 Episode T: 20 Reward: 0.904
# Total T: 14422 Episode Num: 721 Episode T: 13 Reward: 1.101
# Total T: 14454 Episode Num: 722 Episode T: 32 Reward: 9.426
# Total T: 14470 Episode Num: 723 Episode T: 16 Reward: -2.138
# Total T: 14489 Episode Num: 724 Episode T: 19 Reward: 9.605
# Total T: 14540 Episode Num: 725 Episode T: 51 Reward: 14.415
# Total T: 14550 Episode Num: 726 Episode T: 10 Reward: -3.071
# Total T: 14566 Episode Num: 727 Episode T: 16 Reward: -3.671
# Total T: 14582 Episode Num: 728 Episode T: 16 Reward: 2.994
# Total T: 14596 Episode Num: 729 Episode T: 14 Reward: 1.156
# Total T: 14605 Episode Num: 730 Episode T: 9 Reward: -2.153
# Total T: 14619 Episode Num: 731 Episode T: 14 Reward: -1.011
# Total T: 14633 Episode Num: 732 Episode T: 14 Reward: -2.408
# Total T: 14643 Episode Num: 733 Episode T: 10 Reward: -0.813
# Total T: 14679 Episode Num: 734 Episode T: 36 Reward: 10.940
# Total T: 14732 Episode Num: 735 Episode T: 53 Reward: 14.608
# Total T: 14774 Episode Num: 736 Episode T: 42 Reward: 13.125
# Total T: 14802 Episode Num: 737 Episode T: 28 Reward: -2.228
# Total T: 14826 Episode Num: 738 Episode T: 24 Reward: 7.346
# Total T: 14837 Episode Num: 739 Episode T: 11 Reward: 0.791
# Total T: 14884 Episode Num: 740 Episode T: 47 Reward: 26.658
# Total T: 14913 Episode Num: 741 Episode T: 29 Reward: 4.397
# Total T: 14928 Episode Num: 742 Episode T: 15 Reward: 4.863
# Total T: 14940 Episode Num: 743 Episode T: 12 Reward: -3.856
# Total T: 14952 Episode Num: 744 Episode T: 12 Reward: 1.867
# Total T: 14973 Episode Num: 745 Episode T: 21 Reward: -2.506
# ---------------------------------------
# Evaluation over 10 episodes: 2.778
# ---------------------------------------
# Total T: 15009 Episode Num: 746 Episode T: 36 Reward: 13.748
# Total T: 15030 Episode Num: 747 Episode T: 21 Reward: -4.227
# Total T: 15043 Episode Num: 748 Episode T: 13 Reward: 2.563
# Total T: 15058 Episode Num: 749 Episode T: 15 Reward: 2.235
# Total T: 15068 Episode Num: 750 Episode T: 10 Reward: -3.115
# Total T: 15089 Episode Num: 751 Episode T: 21 Reward: -6.363
# Total T: 15109 Episode Num: 752 Episode T: 20 Reward: 8.733
# Total T: 15126 Episode Num: 753 Episode T: 17 Reward: -0.886
# Total T: 15138 Episode Num: 754 Episode T: 12 Reward: -0.128
# Total T: 15160 Episode Num: 755 Episode T: 22 Reward: -4.553
# Total T: 15179 Episode Num: 756 Episode T: 19 Reward: 0.243
# Total T: 15208 Episode Num: 757 Episode T: 29 Reward: 0.565
# Total T: 15226 Episode Num: 758 Episode T: 18 Reward: -4.021
# Total T: 15237 Episode Num: 759 Episode T: 11 Reward: -4.185
# Total T: 15251 Episode Num: 760 Episode T: 14 Reward: -4.413
# Total T: 15276 Episode Num: 761 Episode T: 25 Reward: 12.279
# Total T: 15313 Episode Num: 762 Episode T: 37 Reward: 11.123
# Total T: 15334 Episode Num: 763 Episode T: 21 Reward: 1.371
# Total T: 15354 Episode Num: 764 Episode T: 20 Reward: -6.912
# Total T: 15373 Episode Num: 765 Episode T: 19 Reward: -2.525
# Total T: 15388 Episode Num: 766 Episode T: 15 Reward: 3.800
# Total T: 15399 Episode Num: 767 Episode T: 11 Reward: -0.805
# Total T: 15415 Episode Num: 768 Episode T: 16 Reward: -1.270
# Total T: 15446 Episode Num: 769 Episode T: 31 Reward: 16.941
# Total T: 15464 Episode Num: 770 Episode T: 18 Reward: 1.223
# Total T: 15478 Episode Num: 771 Episode T: 14 Reward: 2.807
# Total T: 15497 Episode Num: 772 Episode T: 19 Reward: -7.215
# Total T: 15518 Episode Num: 773 Episode T: 21 Reward: 5.107
# Total T: 15549 Episode Num: 774 Episode T: 31 Reward: 9.074
# Total T: 15564 Episode Num: 775 Episode T: 15 Reward: 1.789
# Total T: 15589 Episode Num: 776 Episode T: 25 Reward: -4.915
# Total T: 15614 Episode Num: 777 Episode T: 25 Reward: 5.532
# Total T: 15632 Episode Num: 778 Episode T: 18 Reward: -10.242
# Total T: 15650 Episode Num: 779 Episode T: 18 Reward: -7.978
# Total T: 15677 Episode Num: 780 Episode T: 27 Reward: 1.699
# Total T: 15703 Episode Num: 781 Episode T: 26 Reward: -2.499
# Total T: 15714 Episode Num: 782 Episode T: 11 Reward: 1.476
# Total T: 15730 Episode Num: 783 Episode T: 16 Reward: -6.209
# Total T: 15740 Episode Num: 784 Episode T: 10 Reward: -1.494
# Total T: 15753 Episode Num: 785 Episode T: 13 Reward: 0.080
# Total T: 15771 Episode Num: 786 Episode T: 18 Reward: -3.504
# Total T: 15788 Episode Num: 787 Episode T: 17 Reward: 3.978
# Total T: 15808 Episode Num: 788 Episode T: 20 Reward: 1.922
# Total T: 15850 Episode Num: 789 Episode T: 42 Reward: 18.440
# Total T: 15862 Episode Num: 790 Episode T: 12 Reward: 1.524
# Total T: 15872 Episode Num: 791 Episode T: 10 Reward: 0.156
# Total T: 15893 Episode Num: 792 Episode T: 21 Reward: -0.661
# Total T: 15908 Episode Num: 793 Episode T: 15 Reward: 0.298
# Total T: 15918 Episode Num: 794 Episode T: 10 Reward: 0.197
# ...
# Total T: 891432 Episode Num: 3925 Episode T: 276 Reward: 809.633
# Total T: 891538 Episode Num: 3926 Episode T: 106 Reward: 302.929
# Total T: 892538 Episode Num: 3927 Episode T: 1000 Reward: 3869.530
# Total T: 892797 Episode Num: 3928 Episode T: 259 Reward: 825.606
# Total T: 893005 Episode Num: 3929 Episode T: 208 Reward: 630.660
# Total T: 893319 Episode Num: 3930 Episode T: 314 Reward: 893.799
# Total T: 894319 Episode Num: 3931 Episode T: 1000 Reward: 3835.648
# ---------------------------------------
# Evaluation over 10 episodes: 3493.846
# ---------------------------------------
# Total T: 895319 Episode Num: 3932 Episode T: 1000 Reward: 3845.819
# Total T: 896319 Episode Num: 3933 Episode T: 1000 Reward: 3857.831
# Total T: 897319 Episode Num: 3934 Episode T: 1000 Reward: 3934.248
# Total T: 898319 Episode Num: 3935 Episode T: 1000 Reward: 3888.448
# Total T: 899319 Episode Num: 3936 Episode T: 1000 Reward: 4033.712
# Total T: 899876 Episode Num: 3937 Episode T: 557 Reward: 2025.671
# ---------------------------------------
# Evaluation over 10 episodes: 1674.979
# ---------------------------------------
# Total T: 900203 Episode Num: 3938 Episode T: 327 Reward: 915.809
# Total T: 900996 Episode Num: 3939 Episode T: 793 Reward: 3019.619
# Total T: 901788 Episode Num: 3940 Episode T: 792 Reward: 2643.831
# Total T: 902788 Episode Num: 3941 Episode T: 1000 Reward: 3901.829
# Total T: 903138 Episode Num: 3942 Episode T: 350 Reward: 1153.027
# Total T: 904069 Episode Num: 3943 Episode T: 931 Reward: 3670.042
# Total T: 904549 Episode Num: 3944 Episode T: 480 Reward: 1737.103
# ---------------------------------------
# Evaluation over 10 episodes: 3210.604
# ---------------------------------------
# Total T: 905063 Episode Num: 3945 Episode T: 514 Reward: 1638.950
# Total T: 905131 Episode Num: 3946 Episode T: 68 Reward: 141.706
# Total T: 905381 Episode Num: 3947 Episode T: 250 Reward: 693.300
# Total T: 905689 Episode Num: 3948 Episode T: 308 Reward: 962.888
# Total T: 906545 Episode Num: 3949 Episode T: 856 Reward: 2988.849
# Total T: 906930 Episode Num: 3950 Episode T: 385 Reward: 1046.343
# Total T: 907836 Episode Num: 3951 Episode T: 906 Reward: 3407.005
# Total T: 908836 Episode Num: 3952 Episode T: 1000 Reward: 3584.829
# Total T: 909836 Episode Num: 3953 Episode T: 1000 Reward: 4033.466
# ---------------------------------------
# Evaluation over 10 episodes: 1901.654
# ---------------------------------------
# Total T: 910702 Episode Num: 3954 Episode T: 866 Reward: 3124.796
# Total T: 911355 Episode Num: 3955 Episode T: 653 Reward: 2333.425
# Total T: 912141 Episode Num: 3956 Episode T: 786 Reward: 2627.131
# Total T: 912752 Episode Num: 3957 Episode T: 611 Reward: 2459.533
# Total T: 912859 Episode Num: 3958 Episode T: 107 Reward: 258.340
# Total T: 913406 Episode Num: 3959 Episode T: 547 Reward: 2073.332
# Total T: 914242 Episode Num: 3960 Episode T: 836 Reward: 3192.104
# ---------------------------------------
# Evaluation over 10 episodes: 583.653
# ---------------------------------------
# Total T: 915147 Episode Num: 3961 Episode T: 905 Reward: 3195.430
# Total T: 915607 Episode Num: 3962 Episode T: 460 Reward: 1710.066
# Total T: 915767 Episode Num: 3963 Episode T: 160 Reward: 437.122
# Total T: 916438 Episode Num: 3964 Episode T: 671 Reward: 2540.032
# Total T: 917039 Episode Num: 3965 Episode T: 601 Reward: 2207.391
# Total T: 917281 Episode Num: 3966 Episode T: 242 Reward: 851.251
# Total T: 918237 Episode Num: 3967 Episode T: 956 Reward: 3857.827
# Total T: 918338 Episode Num: 3968 Episode T: 101 Reward: 196.984
# Total T: 919329 Episode Num: 3969 Episode T: 991 Reward: 3449.478
# Total T: 919609 Episode Num: 3970 Episode T: 280 Reward: 1163.454
# ---------------------------------------
# Evaluation over 10 episodes: 1882.094
# ---------------------------------------
# Total T: 920609 Episode Num: 3971 Episode T: 1000 Reward: 3877.765
# Total T: 921134 Episode Num: 3972 Episode T: 525 Reward: 1563.781
# Total T: 922134 Episode Num: 3973 Episode T: 1000 Reward: 3838.128
# Total T: 923134 Episode Num: 3974 Episode T: 1000 Reward: 4056.894
# Total T: 924134 Episode Num: 3975 Episode T: 1000 Reward: 3794.566
# Total T: 924741 Episode Num: 3976 Episode T: 607 Reward: 2233.893
# ---------------------------------------
# Evaluation over 10 episodes: 2578.289
# ---------------------------------------
# Total T: 925346 Episode Num: 3977 Episode T: 605 Reward: 2504.805
# Total T: 926346 Episode Num: 3978 Episode T: 1000 Reward: 4073.187
# Total T: 926686 Episode Num: 3979 Episode T: 340 Reward: 1329.336
# Total T: 926843 Episode Num: 3980 Episode T: 157 Reward: 276.524
# Total T: 926940 Episode Num: 3981 Episode T: 97 Reward: 258.877
# Total T: 927940 Episode Num: 3982 Episode T: 1000 Reward: 3753.888
# Total T: 928057 Episode Num: 3983 Episode T: 117 Reward: 270.322
# Total T: 929057 Episode Num: 3984 Episode T: 1000 Reward: 3816.370
# ---------------------------------------
# Evaluation over 10 episodes: 2398.975
# ---------------------------------------
# Total T: 930057 Episode Num: 3985 Episode T: 1000 Reward: 3892.181
# Total T: 930898 Episode Num: 3986 Episode T: 841 Reward: 2801.940
# Total T: 931260 Episode Num: 3987 Episode T: 362 Reward: 1118.777
# Total T: 932260 Episode Num: 3988 Episode T: 1000 Reward: 4123.791
# Total T: 932480 Episode Num: 3989 Episode T: 220 Reward: 541.246
# Total T: 933337 Episode Num: 3990 Episode T: 857 Reward: 3333.253
# Total T: 933828 Episode Num: 3991 Episode T: 491 Reward: 1817.935
# Total T: 934828 Episode Num: 3992 Episode T: 1000 Reward: 3820.864
# ---------------------------------------
# Evaluation over 10 episodes: 3218.997
# ---------------------------------------
# Total T: 935828 Episode Num: 3993 Episode T: 1000 Reward: 4046.902
# Total T: 935984 Episode Num: 3994 Episode T: 156 Reward: 315.537
# Total T: 936984 Episode Num: 3995 Episode T: 1000 Reward: 3866.594
# Total T: 937984 Episode Num: 3996 Episode T: 1000 Reward: 3967.515
# Total T: 938399 Episode Num: 3997 Episode T: 415 Reward: 1123.535
# Total T: 939399 Episode Num: 3998 Episode T: 1000 Reward: 3897.375
# Total T: 939613 Episode Num: 3999 Episode T: 214 Reward: 744.341
# ---------------------------------------
# Evaluation over 10 episodes: 1579.383
# ---------------------------------------
# Total T: 940613 Episode Num: 4000 Episode T: 1000 Reward: 4187.674
# Total T: 941613 Episode Num: 4001 Episode T: 1000 Reward: 3924.423
# Total T: 942352 Episode Num: 4002 Episode T: 739 Reward: 3061.496
# Total T: 943221 Episode Num: 4003 Episode T: 869 Reward: 3593.485
# Total T: 943478 Episode Num: 4004 Episode T: 257 Reward: 774.648
# Total T: 944004 Episode Num: 4005 Episode T: 526 Reward: 1889.029
# Total T: 944716 Episode Num: 4006 Episode T: 712 Reward: 2510.862
# ---------------------------------------
# Evaluation over 10 episodes: 3212.845
# ---------------------------------------
# Total T: 945716 Episode Num: 4007 Episode T: 1000 Reward: 3926.527
# Total T: 945821 Episode Num: 4008 Episode T: 105 Reward: 259.330
# Total T: 946515 Episode Num: 4009 Episode T: 694 Reward: 2820.028
# Total T: 946595 Episode Num: 4010 Episode T: 80 Reward: 169.880
# Total T: 947595 Episode Num: 4011 Episode T: 1000 Reward: 3986.005
# Total T: 947842 Episode Num: 4012 Episode T: 247 Reward: 743.497
# Total T: 948514 Episode Num: 4013 Episode T: 672 Reward: 2296.426
# Total T: 949080 Episode Num: 4014 Episode T: 566 Reward: 1914.878
# Total T: 949459 Episode Num: 4015 Episode T: 379 Reward: 1248.495
# Total T: 949638 Episode Num: 4016 Episode T: 179 Reward: 502.180
# ---------------------------------------
# Evaluation over 10 episodes: 3551.341
# ---------------------------------------
# Total T: 950031 Episode Num: 4017 Episode T: 393 Reward: 1341.471
# Total T: 950231 Episode Num: 4018 Episode T: 200 Reward: 592.707
# Total T: 951041 Episode Num: 4019 Episode T: 810 Reward: 3147.291
# Total T: 951356 Episode Num: 4020 Episode T: 315 Reward: 1040.488
# Total T: 951671 Episode Num: 4021 Episode T: 315 Reward: 240.214
# Total T: 952126 Episode Num: 4022 Episode T: 455 Reward: 1879.418
# Total T: 952363 Episode Num: 4023 Episode T: 237 Reward: 708.023
# Total T: 952679 Episode Num: 4024 Episode T: 316 Reward: 1193.998
# Total T: 952786 Episode Num: 4025 Episode T: 107 Reward: 339.179
# Total T: 952853 Episode Num: 4026 Episode T: 67 Reward: 173.532
# Total T: 952927 Episode Num: 4027 Episode T: 74 Reward: 186.858
# Total T: 952998 Episode Num: 4028 Episode T: 71 Reward: 176.975
# Total T: 953074 Episode Num: 4029 Episode T: 76 Reward: 210.767
# Total T: 953212 Episode Num: 4030 Episode T: 138 Reward: 171.315
# Total T: 953349 Episode Num: 4031 Episode T: 137 Reward: 388.577
# Total T: 954088 Episode Num: 4032 Episode T: 739 Reward: 2978.695
# Total T: 954761 Episode Num: 4033 Episode T: 673 Reward: 2885.897
# ---------------------------------------
# Evaluation over 10 episodes: 1363.950
# ---------------------------------------
# Total T: 955285 Episode Num: 4034 Episode T: 524 Reward: 2111.075
# Total T: 956050 Episode Num: 4035 Episode T: 765 Reward: 3213.140
# Total T: 956143 Episode Num: 4036 Episode T: 93 Reward: 129.438
# Total T: 956400 Episode Num: 4037 Episode T: 257 Reward: 815.397
# Total T: 957231 Episode Num: 4038 Episode T: 831 Reward: 3335.886
# Total T: 957323 Episode Num: 4039 Episode T: 92 Reward: 225.695
# Total T: 957970 Episode Num: 4040 Episode T: 647 Reward: 2748.248
# Total T: 958138 Episode Num: 4041 Episode T: 168 Reward: 385.188
# Total T: 959010 Episode Num: 4042 Episode T: 872 Reward: 3614.319
# Total T: 959142 Episode Num: 4043 Episode T: 132 Reward: 206.735
# Total T: 959746 Episode Num: 4044 Episode T: 604 Reward: 2420.228
# ---------------------------------------
# Evaluation over 10 episodes: 1205.722
# ---------------------------------------
# Total T: 960192 Episode Num: 4045 Episode T: 446 Reward: 1648.353
# Total T: 960343 Episode Num: 4046 Episode T: 151 Reward: 332.905
# Total T: 960973 Episode Num: 4047 Episode T: 630 Reward: 2385.523
# Total T: 961284 Episode Num: 4048 Episode T: 311 Reward: 922.721
# Total T: 961423 Episode Num: 4049 Episode T: 139 Reward: 226.864
# Total T: 962154 Episode Num: 4050 Episode T: 731 Reward: 2910.538
# Total T: 963154 Episode Num: 4051 Episode T: 1000 Reward: 4116.391
# Total T: 964154 Episode Num: 4052 Episode T: 1000 Reward: 3889.661
# Total T: 964316 Episode Num: 4053 Episode T: 162 Reward: 317.386
# Total T: 964640 Episode Num: 4054 Episode T: 324 Reward: 1283.686
# ---------------------------------------
# Evaluation over 10 episodes: 3280.222
# ---------------------------------------
# Total T: 965640 Episode Num: 4055 Episode T: 1000 Reward: 4241.275
# Total T: 966239 Episode Num: 4056 Episode T: 599 Reward: 2354.942
# Total T: 966790 Episode Num: 4057 Episode T: 551 Reward: 2108.325
# Total T: 966895 Episode Num: 4058 Episode T: 105 Reward: 255.322
# Total T: 967528 Episode Num: 4059 Episode T: 633 Reward: 2258.260
# Total T: 967672 Episode Num: 4060 Episode T: 144 Reward: 252.825
# Total T: 968606 Episode Num: 4061 Episode T: 934 Reward: 3597.687
# Total T: 969606 Episode Num: 4062 Episode T: 1000 Reward: 4002.656
# Total T: 969792 Episode Num: 4063 Episode T: 186 Reward: 433.605
# Total T: 969940 Episode Num: 4064 Episode T: 148 Reward: 267.295
# ---------------------------------------
# Evaluation over 10 episodes: 2796.452
# ---------------------------------------
# Total T: 970093 Episode Num: 4065 Episode T: 153 Reward: 304.315
# Total T: 970490 Episode Num: 4066 Episode T: 397 Reward: 1458.838
# Total T: 970590 Episode Num: 4067 Episode T: 100 Reward: 253.114
# Total T: 971427 Episode Num: 4068 Episode T: 837 Reward: 2966.119
# Total T: 971640 Episode Num: 4069 Episode T: 213 Reward: 783.596
# Total T: 972640 Episode Num: 4070 Episode T: 1000 Reward: 4082.652
# Total T: 973235 Episode Num: 4071 Episode T: 595 Reward: 2541.211
# Total T: 973520 Episode Num: 4072 Episode T: 285 Reward: 997.129
# Total T: 973986 Episode Num: 4073 Episode T: 466 Reward: 1592.400
# Total T: 974645 Episode Num: 4074 Episode T: 659 Reward: 2642.586
# ---------------------------------------
# Evaluation over 10 episodes: 1133.766
# ---------------------------------------
# Total T: 975094 Episode Num: 4075 Episode T: 449 Reward: 1588.009
# Total T: 975819 Episode Num: 4076 Episode T: 725 Reward: 2881.579
# Total T: 976819 Episode Num: 4077 Episode T: 1000 Reward: 3904.513
# Total T: 977672 Episode Num: 4078 Episode T: 853 Reward: 3590.305
# Total T: 977788 Episode Num: 4079 Episode T: 116 Reward: 291.189
# Total T: 978520 Episode Num: 4080 Episode T: 732 Reward: 3113.933
# Total T: 979205 Episode Num: 4081 Episode T: 685 Reward: 2680.290
# Total T: 979816 Episode Num: 4082 Episode T: 611 Reward: 2432.189
# ---------------------------------------
# Evaluation over 10 episodes: 2143.779
# ---------------------------------------
# Total T: 980234 Episode Num: 4083 Episode T: 418 Reward: 1657.756
# Total T: 980846 Episode Num: 4084 Episode T: 612 Reward: 2454.379
# Total T: 981692 Episode Num: 4085 Episode T: 846 Reward: 3516.924
# Total T: 982165 Episode Num: 4086 Episode T: 473 Reward: 1900.407
# Total T: 982521 Episode Num: 4087 Episode T: 356 Reward: 1406.207
# Total T: 982734 Episode Num: 4088 Episode T: 213 Reward: 778.036
# Total T: 983118 Episode Num: 4089 Episode T: 384 Reward: 1585.133
# Total T: 983324 Episode Num: 4090 Episode T: 206 Reward: 753.525
# Total T: 984324 Episode Num: 4091 Episode T: 1000 Reward: 4096.363
# Total T: 984447 Episode Num: 4092 Episode T: 123 Reward: 327.503
# Total T: 984660 Episode Num: 4093 Episode T: 213 Reward: 584.838
# Total T: 984962 Episode Num: 4094 Episode T: 302 Reward: 793.609
# ---------------------------------------
# Evaluation over 10 episodes: 2555.217
# ---------------------------------------
# Total T: 985214 Episode Num: 4095 Episode T: 252 Reward: 899.151
# Total T: 985296 Episode Num: 4096 Episode T: 82 Reward: 201.863
# Total T: 985769 Episode Num: 4097 Episode T: 473 Reward: 1981.259
# Total T: 986278 Episode Num: 4098 Episode T: 509 Reward: 2118.807
# Total T: 986614 Episode Num: 4099 Episode T: 336 Reward: 1269.044
# Total T: 986797 Episode Num: 4100 Episode T: 183 Reward: 664.964
# Total T: 987135 Episode Num: 4101 Episode T: 338 Reward: 1418.122
# Total T: 987572 Episode Num: 4102 Episode T: 437 Reward: 1874.642
# Total T: 987679 Episode Num: 4103 Episode T: 107 Reward: 317.579
# Total T: 988487 Episode Num: 4104 Episode T: 808 Reward: 3325.283
# Total T: 989211 Episode Num: 4105 Episode T: 724 Reward: 2694.960
# Total T: 989571 Episode Num: 4106 Episode T: 360 Reward: 1475.892
# ---------------------------------------
# Evaluation over 10 episodes: 3078.833
# ---------------------------------------
# Total T: 990117 Episode Num: 4107 Episode T: 546 Reward: 2190.039
# Total T: 991046 Episode Num: 4108 Episode T: 929 Reward: 3854.085
# Total T: 991189 Episode Num: 4109 Episode T: 143 Reward: 443.220
# Total T: 991913 Episode Num: 4110 Episode T: 724 Reward: 3093.951
# Total T: 992118 Episode Num: 4111 Episode T: 205 Reward: 766.902
# Total T: 992364 Episode Num: 4112 Episode T: 246 Reward: 1004.842
# Total T: 992944 Episode Num: 4113 Episode T: 580 Reward: 2386.456
# Total T: 993944 Episode Num: 4114 Episode T: 1000 Reward: 3998.120
# Total T: 994521 Episode Num: 4115 Episode T: 577 Reward: 2470.231
# Total T: 994766 Episode Num: 4116 Episode T: 245 Reward: 969.791
# Total T: 994876 Episode Num: 4117 Episode T: 110 Reward: 404.188
# ---------------------------------------
# Evaluation over 10 episodes: 1938.045
# ---------------------------------------
# Total T: 995779 Episode Num: 4118 Episode T: 903 Reward: 3808.887
# Total T: 996779 Episode Num: 4119 Episode T: 1000 Reward: 4123.356
# Total T: 997576 Episode Num: 4120 Episode T: 797 Reward: 3290.000
# Total T: 997940 Episode Num: 4121 Episode T: 364 Reward: 1492.603
# Total T: 998201 Episode Num: 4122 Episode T: 261 Reward: 933.259
# Total T: 998268 Episode Num: 4123 Episode T: 67 Reward: 194.313
# Total T: 998387 Episode Num: 4124 Episode T: 119 Reward: 306.728
# Total T: 998507 Episode Num: 4125 Episode T: 120 Reward: 412.965
# Total T: 999507 Episode Num: 4126 Episode T: 1000 Reward: 3937.014
# Total T: 999559 Episode Num: 4127 Episode T: 52 Reward: 76.386
# ---------------------------------------
# Evaluation over 10 episodes: 1760.339
# ---------------------------------------
