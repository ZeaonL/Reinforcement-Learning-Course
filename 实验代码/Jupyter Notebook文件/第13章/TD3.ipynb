# %% [markdown]
# ## 双延迟-确定性策略梯度（Twin Delayed Deterministic policy gradient，TD3）算法

# %% [markdown]
# &emsp;&emsp;<font size=4>
#     在DDPG算法基础上，TD3算法的主要目的在于解决AC框架中，由函数逼近引入的偏差和方差问题。一方面，由于方差会引起过高估计，为解决过高估计问题，TD3将截断式双Q学习（clipped Double Q-Learning）应用于AC框架；另一方面，高方差会引起误差累积，为解决误差累积问题，TD3分别采用延迟策略更新和添加噪声平滑目标策略两种技巧。
# </font><br>

# %% [markdown]
# ### 过高估计问题解决方案

# %% [markdown]
# &emsp;&emsp;<font size=4>
#     从策略梯度方法已知，基于PG的强化学习存在过高估计问题，但由于DDPG评论家的目标值不是取最优动作值函数的，所以不存在最大化操作。此时，将Double DQN思想直接用于DDPG的评论家，构造如下目标函数：
# </font><br>
# \begin{equation}
# y=r+\gamma Q\left(s^{\prime}, \mu\left(s^{\prime}, \boldsymbol{\theta}\right), \boldsymbol{w}^{\prime}\right)  \label{bbb.11}\tag{bbb.11}
# \end{equation}
# &emsp;&emsp;<font size=4>
#     实际上，这样的处理效果并不好，这是因为在连续动作空间中，策略变化缓慢，行动者更新较为平缓，使得预测$Q$值与目标$Q$值相差不大，无法避免过高估计问题。
# </font><br>
# &emsp;&emsp;<font size=4>
#     考虑将Double Q-Learning思想应用于DDPG，采用两个独立的评论家$Q_{w_{1}}$、$Q_{w_{2}}$和两个独立的行动者$\mu_{\theta_{1}}$、$\mu_{\theta_{2}}$，以50%的概率利用$Q_{1}$产生动作，然后更新$Q_{2}$估计值，而另外50%的概率正好相反。构建更新所需的两个目标值分别为：
# </font><br>
# \begin{equation}
# \left\{\begin{array}{l}
# y_{1}=r+\gamma Q\left(s^{\prime}, \mu\left(s^{\prime}, \boldsymbol{\theta}_{1}\right), \boldsymbol{w}_{2}^{\prime}\right) \\
# y_{2}=r+\gamma Q\left(s^{\prime}, \mu\left(s^{\prime}, \boldsymbol{\theta}_{2}\right), \boldsymbol{w}_{1}^{\prime}\right)
# \end{array}\right.  \label{bbb.12}\tag{bbb.12}
# \end{equation}
# &emsp;&emsp;<font size=4>
#     但由于样本均来自于同一经验池，不能保证样本数据完全独立，所以两个行动者的样本具有一定相关性，在一定的情况下，甚至会加剧高估问题。针对此种情形，秉持“宁可低估，也不要高估”的想法，对Double Q-Learning进行修改，构建基于Clipped Double Q-learning方法的目标值：
# </font><br>
# \begin{equation}
# y=r+\gamma \min _{i=1,2} Q\left(s^{\prime}, \mu\left(s^{\prime}, \theta_{1}\right), w_{i}^{\prime}\right) \label{bbb.13}\tag{bbb.13}
# \end{equation}
# &emsp;&emsp;<font size=4>
#     如式（bbb.13）所示，目标值只使用了一个行动者网络$\mu_{\theta_{1}}$，取两个评论家网络$Q_{w_{1}}$和$Q_{w_{2}}$的最小值来作为值函数估计值。
# </font><br>
# &emsp;&emsp;<font size=4>
#     在更新评论家网络$Q_{w_{1}}$和$Q_{w_{2}}$时，均采用式（bbb.13）目标值y，共用如下损失函数：
# </font><br>
# \begin{equation}
# L\left(\boldsymbol{w}_{i}\right)=\mathbb{E}_{s, a, r, s^{\prime} \sim \mathcal{D}}\left[y-Q\left(s, a, \boldsymbol{w}_{i}\right)\right]^{2}    \label{bbb.14}\tag{bbb.14}
# \end{equation}
# &emsp;&emsp;<font size=4>
#     该算法相比于原算法的区别仅在于多了一个和原评论家$Q_{w_{1}}$同步更新的辅助评论家$Q_{w_{2}}$，在更新目标值y时取最小值。不过这一修改仍然会让人疑惑，$Q_{w_{1}}$和$Q_{w_{2}}$只有初始参数不同，后面的更新都一样，这样形成的两个类似的评论家能否有效消除TD误差带来的偏置估计。
# </font><br>

# %% [markdown]
# ### 累积误差问题解决方案

# %% [markdown]
# &emsp;&emsp;<font size=4>
#     在函数逼近问题中，TD(0)算法的过高估计问题会进一步加剧，每次更新都会产生一定量的TD误差$\delta(s, a)$：
# </font><br>
# \begin{equation}
# Q(s, a, \boldsymbol{w})=r+\gamma \mathbb{E}\left[Q\left(s^{\prime}, a^{\prime}, \boldsymbol{w}\right)\right]-\delta(s, a) \label{bbb.15}\tag{bbb.15}
# \end{equation}
# &emsp;&emsp;<font size=4>
#     经过多次迭代更新后，误差会被累积：
# </font><br>
# \begin{equation}
# \begin{aligned}
# Q\left(S_{t}, A_{t}, \boldsymbol{w}\right) &=R_{t+1}+\gamma \mathbb{E}\left[Q\left(S_{t+1}, A_{t+1}, \boldsymbol{w}\right)\right]-\delta_{t+1} \\
# &=R_{t+1}+\gamma \mathbb{E}\left[R_{t+2}+\gamma \mathbb{E}\left[Q\left(S_{t+2}, A_{t+2}, \boldsymbol{w}\right)\right]-\delta_{t+2}\right]-\delta_{t+1} \\
# & \cdots \cdots \\
# &=\mathbb{E}_{S_{i} \sim \rho^{\beta}, A_{i} \sim \mu}\left[\sum^{\mathrm{T}-1} \gamma^{i-t}\left(R_{i+1}-\delta_{i+1}\right)\right]
# \end{aligned}  \label{bbb.16}\tag{bbb.16}
# \end{equation}
# &emsp;&emsp;<font size=4>
#     由此可见，估计的方差与未来奖励、未来TD误差的方差成正比。当折扣因子$\gamma$较大时，每次更新都可以引起方差的快速提升，所以通常TD3设置较小的折扣系数$\gamma$。
# </font><br>

# %% [markdown]
# ### 延迟的策略更新

# %% [markdown]
# &emsp;&emsp;<font size=4>
#     TD3目标网络的更新方式与DDPG相同，都采用软更新，尽管软更新比硬更新更有利于算法的稳定性，但AC算法依然会失败，其原因通常在于行动者和评论家的更新是相互作用的结果：评论家提供的值函数估计值不准确，就会使行动者将策略往错误方向改进；行动者产生了较差的策略，就会进一步加剧评论家误差累积问题，两者不断作用产生恶性循环。
# </font><br>
# &emsp;&emsp;<font size=4>
#     为解决以上问题，TD3考虑对策略进行延时更新，减少行动者的更新频率，尽可能等待评论家训练收敛后再进行更新操作。延时更新操作可以有效减少累积误差，从而降低方差；同时，也能减少不必要的重复更新操作，一定程度上提升效率。在实际应用时，TD3采取的操作是每隔评论家更新$d$次后，再对行动者进行更新。
# </font><br>

# %% [markdown]
# ### 目标策略平滑操作

# %% [markdown]
# &emsp;&emsp;<font size=4>
#     上节中通过延时更新策略来减小误差累积，接下来考虑误差本身。首先，误差的根源是值函数逼近所产生的偏差，在机器学习中，消除估计偏差的常用方法就是对参数更新进行正则化，同样的，这一思想也可以应用在强化学习中。
# </font><br>
# &emsp;&emsp;<font size=4>
#     一个很自然的想法是，相似的动作应该拥有相似的价值，动作空间中目标动作周围的一小片区域的价值若能足够平滑，就可以有效减少误差的产生。TD3的具体做法是，为目标动作添加截断噪声：
# </font><br>
# \begin{equation}
# \begin{array}{l}
# \tilde{a} \leftarrow \mu\left(s^{\prime}, \boldsymbol{\theta}^{\prime}\right)+\varepsilon \\
# \boldsymbol{\varepsilon} \sim \operatorname{clip}(N(0, \sigma),-c, c)
# \end{array}   \label{bbb.17}\tag{bbb.17}
# \end{equation}
# &emsp;&emsp;<font size=4>
#     该噪声处理也是一种正则化方式。通过这种平滑操作，可以增加算法的泛化能力，缓解过拟合问题，减少价值被过高估计的一些不良状态对策略学习的干扰。
# </font><br>

# %% [markdown]
# ## TD3算法

# %% [markdown]
# &emsp;&emsp;<font size=4>
#     TD3算法，如算法bbb.2所示：
# </font><br>

# %% [markdown]
# <hr style="height:1px;border:none;border-top:1px solid #555555;" />
# &emsp;&emsp;<font size=3.5><b>算法bbb.2</b> TD3算法（Lillicrap al. 2016）</font><br>
# <hr>
# &emsp;&emsp;<font size=3.5>初始化：</font><br>
# &emsp;&emsp;&emsp;&emsp;<font size=3.5>
#     1.&emsp;初始化预测价值网络$Q_{w_{1}}$和$Q_{w_{2}}$，网络参数分别为$\boldsymbol{w}_{1}$和$\boldsymbol{w}_{2}$
# </font><br>
# &emsp;&emsp;&emsp;&emsp;<font size=3.5>
#     2.&emsp;初始化目标价值网络$Q_{\boldsymbol{w}_{1}^{\prime}}$和$Q_{\boldsymbol{w}_{2}^{\prime}}$，网络参数分别为$\boldsymbol{w}_{1}^{\prime}$和$\boldsymbol{w}_{2}^{\prime}$
# </font><br>
# &emsp;&emsp;&emsp;&emsp;<font size=3.5>
#     3.&emsp;初始化预测策略网络$\mu_{\theta}$和目标策略网络$\mu_{\theta^{\prime}}$，网络参数分别为$\theta$和$\theta^{\prime}$
# </font><br>
# &emsp;&emsp;&emsp;&emsp;<font size=3.5>
#     4.&emsp;同步参数$w_{1}^{\prime} \leftarrow w_{1}$，$w_{2}^{\prime} \leftarrow w_{2}$，$\theta^{\prime} \leftarrow \theta$
# </font><br>
# &emsp;&emsp;&emsp;&emsp;<font size=3.5>
#     5.&emsp;经验池$\mathcal{D}$的容量为$N$
# </font><br>
# &emsp;&emsp;&emsp;&emsp;<font size=3.5>
#     6.&emsp;总迭代次数$M$，折扣因子$\gamma$，$\tau=0.0001$，随机小批量采样样本数量$n$
# </font><br>
# <hr>
# &emsp;&emsp;&emsp;&emsp;<font size=3.5>
#     7.&emsp;<b>for</b> $e$=1 <b>to</b> $M$ <b>do:</b>
# </font><br>
# &emsp;&emsp;&emsp;&emsp;<font size=3.5>
#     8.&emsp;&emsp;&emsp;初始化状态设置为$S_{0}$
# </font><br>
# &emsp;&emsp;&emsp;&emsp;<font size=3.5>
#     9.&emsp;&emsp;&emsp;<b>repeat</b>（情节中的每一时间步$t=0,1,2, \ldots$）：
# </font><br>
# &emsp;&emsp;&emsp;&emsp;<font size=3.5>
#     10.&emsp;&emsp;&emsp;&emsp;&emsp;根据当前的预测策略网络和探索噪声来选择动作根据当前的预测策略网络和探索噪声来选择动作$A_{t}=\mu\left(S_{t}, \boldsymbol{\theta}\right)+\varepsilon_{t}$,
# </font><br>
# &emsp;&emsp;&emsp;&emsp;<font size=3.5>
#     &emsp;&emsp;&emsp;&emsp;&emsp;其中$\varepsilon_{t} \sim \mathcal{N}_{t}(0, \sigma)$
# </font><br>
# &emsp;&emsp;&emsp;&emsp;<font size=3.5>
#     11.&emsp;&emsp;&emsp;&emsp;&emsp;执行动作$ A_{t}$，获得奖赏$R_{t+1}$和下一状态$S_{t+1}$
# </font><br>
# &emsp;&emsp;&emsp;&emsp;<font size=3.5>
#     12.&emsp;&emsp;&emsp;&emsp;&emsp;将经验转换$\left(S_{t}, A_{t}, R_{t+1}, S_{t+1}\right)$存储在经验池$\mathcal{D}$中
# </font><br>
# &emsp;&emsp;&emsp;&emsp;<font size=3.5>
#     13.&emsp;&emsp;&emsp;&emsp;&emsp;从经验池$\mathcal{D}$中随机采样小批量的$n$个经验转移样本$\left(S_{i}, A_{i}, R_{i+1}, S_{i+1}\right)$，计算：
# </font><br>
# &emsp;&emsp;&emsp;&emsp;<font size=3.5>
#     &emsp;&emsp;&emsp;&emsp;&emsp;（1）扰动后的动作$\tilde{a}_{i+1} \leftarrow \mu\left(S_{i+1}, \boldsymbol{\theta}^{\prime}\right)+\varepsilon_{i}$，其中$\varepsilon_{i} \sim \operatorname{clip}\left(\mathcal{N}_{t}(0, \tilde{\sigma}),-c, c\right)$
# </font><br>
# &emsp;&emsp;&emsp;&emsp;<font size=3.5>
#     &emsp;&emsp;&emsp;&emsp;&emsp;（2）更新目标$y_{i}=R_{i+1}+\gamma \min _{i=1,2} Q\left(S_{i+1}, \tilde{a}_{i+1}, \boldsymbol{w}_{i}^{\prime}\right)$
# </font><br>
# &emsp;&emsp;&emsp;&emsp;<font size=3.5>
#     14.&emsp;&emsp;&emsp;&emsp;&emsp;使用MBGD，根据最小化损失函数来更新价值网络（评论家网络）参数$\boldsymbol{w}$：
# </font><br>
# \begin{equation}
# \nabla_{w} L(\boldsymbol{w}) \approx \frac{1}{N} \sum_{i}^{N}\left(y_{i}-Q\left(S_{i}, A_{i}, \boldsymbol{w}\right)\right) \nabla_{w} Q\left(S_{i}, A_{i}, \boldsymbol{w}\right)
# \end{equation}
# &emsp;&emsp;&emsp;&emsp;<font size=3.5>
#     15.&emsp;&emsp;&emsp;&emsp;&emsp;<b>if</b> $t$ mod $d$ <b>then</b>
# </font><br>
# &emsp;&emsp;&emsp;&emsp;<font size=3.5>
#     16.&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;使用MBGA法，根据最大化目标函数来更新策略网络（行动者网络）参数$\theta$：
# </font><br>
# \begin{equation}
# \left.\nabla_{\theta} \hat{J}_{\beta}(\boldsymbol{\theta}) \approx \frac{1}{N} \sum_{i} \nabla_{\theta} \mu\left(S_{i}, \boldsymbol{\theta}\right) \nabla_{a} Q\left(S_{i}, a, \boldsymbol{w}\right)\right|_{a=\mu\left(S_{i}, \boldsymbol{\theta}\right)}
# \end{equation}
# &emsp;&emsp;&emsp;&emsp;<font size=3.5>
#     17.&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;软更新目标网络：$\left\{\begin{array}{l}\boldsymbol{w}^{\prime} \leftarrow \tau \boldsymbol{w}+(1-\tau) \boldsymbol{w}^{\prime} \\ \boldsymbol{\theta}^{\prime} \leftarrow \tau \boldsymbol{\theta}+(1-\tau) \boldsymbol{\theta}^{\prime}\end{array}\right.$
# </font><br>
# &emsp;&emsp;&emsp;&emsp;<font size=3.5>
#     18.&emsp;&emsp;&emsp;<b>until</b> $t=\mathrm{T}-1$
# </font><br>
# <hr style="height:1px;border:none;border-top:1px solid #555555;" /><br>

# %%
import numpy as np
import torch
import gym
import os
import copy
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# ## USE CUDA

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Replay Buffer

# %%
class ReplayBuffer(object):
    def __init__(self, state_dim, action_dim, max_size=int(1e6)):
        self.max_size = max_size
        self.ptr = 0
        self.size = 0

        self.state = np.zeros((max_size, state_dim))
        self.action = np.zeros((max_size, action_dim))
        self.next_state = np.zeros((max_size, state_dim))
        self.reward = np.zeros((max_size, 1))
        self.not_done = np.zeros((max_size, 1))

        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    def add(self, state, action, next_state, reward, done):
        self.state[self.ptr] = state
        self.action[self.ptr] = action
        self.next_state[self.ptr] = next_state
        self.reward[self.ptr] = reward
        self.not_done[self.ptr] = 1. - done

        self.ptr = (self.ptr + 1) % self.max_size
        self.size = min(self.size + 1, self.max_size)

    def sample(self, batch_size):
        ind = np.random.randint(0, self.size, size=batch_size)

        return (
            torch.FloatTensor(self.state[ind]).to(self.device),
            torch.FloatTensor(self.action[ind]).to(self.device),
            torch.FloatTensor(self.next_state[ind]).to(self.device),
            torch.FloatTensor(self.reward[ind]).to(self.device),
            torch.FloatTensor(self.not_done[ind]).to(self.device)
        )

# %%
class Actor(nn.Module):
    def __init__(self, state_dim, action_dim, max_action):
        super(Actor, self).__init__()

        self.l1 = nn.Linear(state_dim, 256)
        self.l2 = nn.Linear(256, 256)
        self.l3 = nn.Linear(256, action_dim)

        self.max_action = max_action


    def forward(self, state):
        a = F.relu(self.l1(state))
        a = F.relu(self.l2(a))
        return self.max_action * torch.tanh(self.l3(a))


class Critic(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(Critic, self).__init__()

        # Q1 architecture
        self.l1 = nn.Linear(state_dim + action_dim, 256)
        self.l2 = nn.Linear(256, 256)
        self.l3 = nn.Linear(256, 1)

        # Q2 architecture
        self.l4 = nn.Linear(state_dim + action_dim, 256)
        self.l5 = nn.Linear(256, 256)
        self.l6 = nn.Linear(256, 1)


    def forward(self, state, action):
        sa = torch.cat([state, action], 1)

        q1 = F.relu(self.l1(sa))
        q1 = F.relu(self.l2(q1))
        q1 = self.l3(q1)

        q2 = F.relu(self.l4(sa))
        q2 = F.relu(self.l5(q2))
        q2 = self.l6(q2)
        return q1, q2


    def Q1(self, state, action):
        sa = torch.cat([state, action], 1)

        q1 = F.relu(self.l1(sa))
        q1 = F.relu(self.l2(q1))
        q1 = self.l3(q1)
        return q1

# %%
actor1=Actor(17,6,1.0)
for ch in actor1.children():
    print(ch)
print("*********************")
critic1=Critic(17,6)
for ch in critic1.children():
    print(ch)
# Out:
# Linear(in_features=17, out_features=256, bias=True)
# Linear(in_features=256, out_features=256, bias=True)
# Linear(in_features=256, out_features=6, bias=True)
# *********************
# Linear(in_features=23, out_features=256, bias=True)
# Linear(in_features=256, out_features=256, bias=True)
# Linear(in_features=256, out_features=1, bias=True)
# Linear(in_features=23, out_features=256, bias=True)
# Linear(in_features=256, out_features=256, bias=True)
# Linear(in_features=256, out_features=1, bias=True)

# %%
class TD3(object):
    def __init__(
        self,
        state_dim,
        action_dim,
        max_action,
        discount=0.99,
        tau=0.005,
        policy_noise=0.2,
        noise_clip=0.5,
        policy_freq=2
    ):

        self.actor = Actor(state_dim, action_dim, max_action).to(device)
        self.actor_target = copy.deepcopy(self.actor)
        self.actor_optimizer = torch.optim.Adam(self.actor.parameters(), lr=3e-4)

        self.critic = Critic(state_dim, action_dim).to(device)
        self.critic_target = copy.deepcopy(self.critic)
        self.critic_optimizer = torch.optim.Adam(self.critic.parameters(), lr=3e-4)

        self.max_action = max_action
        self.discount = discount
        self.tau = tau
        self.policy_noise = policy_noise
        self.noise_clip = noise_clip
        self.policy_freq = policy_freq

        self.total_it = 0


    def select_action(self, state):
        state = torch.FloatTensor(state.reshape(1, -1)).to(device)
        return self.actor(state).cpu().data.numpy().flatten()


    def train(self, replay_buffer, batch_size=100):
        self.total_it += 1

        # Sample replay buffer 
        state, action, next_state, reward, not_done = replay_buffer.sample(batch_size)

        with torch.no_grad():
            # Select action according to policy and add clipped noise
            noise = (
                torch.randn_like(action) * self.policy_noise
            ).clamp(-self.noise_clip, self.noise_clip)

            next_action = (
                self.actor_target(next_state) + noise
            ).clamp(-self.max_action, self.max_action)

            # Compute the target Q value
            target_Q1, target_Q2 = self.critic_target(next_state, next_action)
            target_Q = torch.min(target_Q1, target_Q2)
            target_Q = reward + not_done * self.discount * target_Q

        # Get current Q estimates
        current_Q1, current_Q2 = self.critic(state, action)

        # Compute critic loss
        critic_loss = F.mse_loss(current_Q1, target_Q) + F.mse_loss(current_Q2, target_Q)

        # Optimize the critic
        self.critic_optimizer.zero_grad()
        critic_loss.backward()
        self.critic_optimizer.step()

        # Delayed policy updates
        if self.total_it % self.policy_freq == 0:

            # Compute actor losse
            actor_loss = -self.critic.Q1(state, self.actor(state)).mean()

            # Optimize the actor 
            self.actor_optimizer.zero_grad()
            actor_loss.backward()
            self.actor_optimizer.step()

            # Update the frozen target models
            for param, target_param in zip(self.critic.parameters(), self.critic_target.parameters()):
                target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)

            for param, target_param in zip(self.actor.parameters(), self.actor_target.parameters()):
                target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)


    def save(self, filename):
        torch.save(self.critic.state_dict(), filename + "_critic")
        torch.save(self.critic_optimizer.state_dict(), filename + "_critic_optimizer")

        torch.save(self.actor.state_dict(), filename + "_actor")
        torch.save(self.actor_optimizer.state_dict(), filename + "_actor_optimizer")


    def load(self, filename):
        self.critic.load_state_dict(torch.load(filename + "_critic"))
        self.critic_optimizer.load_state_dict(torch.load(filename + "_critic_optimizer"))
        self.critic_target = copy.deepcopy(self.critic)

        self.actor.load_state_dict(torch.load(filename + "_actor"))
        self.actor_optimizer.load_state_dict(torch.load(filename + "_actor_optimizer"))
        self.actor_target = copy.deepcopy(self.actor)

# %%
# Runs policy for X episodes and returns average reward
# A fixed seed is used for the eval environment
def eval_policy(policy, env_name, seed, eval_episodes=10):
    eval_env = gym.make(env_name)
    eval_env.seed(seed + 100)

    avg_reward = 0.
    for _ in range(eval_episodes):
        state, done = eval_env.reset(), False
        while not done:
            action = policy.select_action(np.array(state))
            state, reward, done, _ = eval_env.step(action)
            avg_reward += reward

    avg_reward /= eval_episodes

    print("---------------------------------------")
    print(f"Evaluation over {eval_episodes} episodes: {avg_reward:.3f}")
    print("---------------------------------------")
    return avg_reward

# %%
policy="TD3"
env_name="Walker2d-v2"          # OpenAI gym environment name
seed=0                        # Sets Gym, PyTorch and Numpy seeds
start_timesteps=25e3         # Time steps initial random policy is used
eval_freq=5e3               # How often (time steps) we evaluate
max_timesteps=1e6   # Max time steps to run environment
expl_noise=0.1                 # Std of Gaussian exploration noise
batch_size=256      # Batch size for both actor and critic
discount=0.99                 # Discount factor
tau=0.005                     # Target network update rate
policy_noise=0.2              # Noise added to target policy during critic update
noise_clip=0.5                # Range to clip target policy noise
policy_freq=2                 # Frequency of delayed policy updates
save_model="store_true"       # Save model and optimizer parameters
load_model=""                # Model load file name, "" doesn't load, "default" uses file_name

file_name = f"{policy}_{env_name}_{seed}"
print("---------------------------------------")
print(f"Policy: {policy}, Env: {env_name}, Seed: {seed}")
print("---------------------------------------")

if not os.path.exists("./results"):
    os.makedirs("./results")

if save_model and not os.path.exists("./models"):
    os.makedirs("./models")

env = gym.make(env_name)

# Set seeds
env.seed(seed)
torch.manual_seed(seed)
np.random.seed(seed)

state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0] 
max_action = float(env.action_space.high[0])

kwargs = {
    "state_dim": state_dim,
    "action_dim": action_dim,
    "max_action": max_action,
    "discount": discount,
    "tau": tau,
    "policy_noise": policy_noise * max_action,
    "noise_clip": noise_clip * max_action,
    "policy_freq": policy_freq
}


policy = TD3(**kwargs)

if load_model != "":
    policy_file = file_name if load_model == "default" else load_model
    policy.load(f"./models/{policy_file}")

replay_buffer = ReplayBuffer(state_dim, action_dim)

# Evaluate untrained policy
evaluations = [eval_policy(policy, env_name, seed)]

state, done = env.reset(), False
episode_reward = 0
episode_timesteps = 0
episode_num = 0

for t in range(int(max_timesteps)):

    episode_timesteps += 1

    # Select action randomly or according to policy
    if t < start_timesteps:
        action = env.action_space.sample()
    else:
        action = (
            policy.select_action(np.array(state))
            + np.random.normal(0, max_action * expl_noise, size=action_dim)
        ).clip(-max_action, max_action)

    # Perform action
    next_state, reward, done, _ = env.step(action) 
    done_bool = float(done) if episode_timesteps < env._max_episode_steps else 0

    # Store data in replay buffer
    replay_buffer.add(state, action, next_state, reward, done_bool)

    state = next_state
    episode_reward += reward

    # Train agent after collecting sufficient data
    if t >= start_timesteps:
        policy.train(replay_buffer, batch_size)

    if done: 
        # +1 to account for 0 indexing. +0 on ep_timesteps since it will increment +1 even if done=True
        print(f"Total T: {t+1} Episode Num: {episode_num+1} Episode T: {episode_timesteps} Reward: {episode_reward:.3f}")
        # Reset environment
        state, done = env.reset(), False
        episode_reward = 0
        episode_timesteps = 0
        episode_num += 1 

    # Evaluate episode
    if (t + 1) % eval_freq == 0:
        evaluations.append(eval_policy(policy, env_name, seed))
        np.save(f"./results/{file_name}", evaluations)
    
    if save_model: 
        policy.save(f"./models/{file_name}")
# Out:
# ---------------------------------------
# Policy: TD3, Env: Walker2d-v2, Seed: 0
# ---------------------------------------
# ---------------------------------------
# Evaluation over 10 episodes: 7.883
# ---------------------------------------
# Total T: 18 Episode Num: 1 Episode T: 18 Reward: 0.863
# Total T: 33 Episode Num: 2 Episode T: 15 Reward: 0.775
# Total T: 48 Episode Num: 3 Episode T: 15 Reward: -8.107
# Total T: 68 Episode Num: 4 Episode T: 20 Reward: 2.861
# Total T: 81 Episode Num: 5 Episode T: 13 Reward: -1.973
# Total T: 98 Episode Num: 6 Episode T: 17 Reward: 1.578
# Total T: 109 Episode Num: 7 Episode T: 11 Reward: -2.600
# Total T: 122 Episode Num: 8 Episode T: 13 Reward: 2.055
# Total T: 155 Episode Num: 9 Episode T: 33 Reward: 11.694
# Total T: 184 Episode Num: 10 Episode T: 29 Reward: 7.228
# Total T: 196 Episode Num: 11 Episode T: 12 Reward: -3.649
# Total T: 216 Episode Num: 12 Episode T: 20 Reward: 2.729
# Total T: 238 Episode Num: 13 Episode T: 22 Reward: -1.251
# Total T: 269 Episode Num: 14 Episode T: 31 Reward: 9.275
# Total T: 288 Episode Num: 15 Episode T: 19 Reward: 6.097
# Total T: 305 Episode Num: 16 Episode T: 17 Reward: -5.518
# Total T: 329 Episode Num: 17 Episode T: 24 Reward: 8.189
# Total T: 367 Episode Num: 18 Episode T: 38 Reward: 0.976
# Total T: 382 Episode Num: 19 Episode T: 15 Reward: 1.281
# Total T: 417 Episode Num: 20 Episode T: 35 Reward: 6.139
# Total T: 456 Episode Num: 21 Episode T: 39 Reward: 19.000
# Total T: 479 Episode Num: 22 Episode T: 23 Reward: 0.157
# Total T: 491 Episode Num: 23 Episode T: 12 Reward: -0.540
# Total T: 516 Episode Num: 24 Episode T: 25 Reward: 0.563
# Total T: 539 Episode Num: 25 Episode T: 23 Reward: 1.222
# Total T: 550 Episode Num: 26 Episode T: 11 Reward: -3.295
# Total T: 559 Episode Num: 27 Episode T: 9 Reward: -3.784
# Total T: 586 Episode Num: 28 Episode T: 27 Reward: 10.984
# Total T: 607 Episode Num: 29 Episode T: 21 Reward: 3.135
# Total T: 619 Episode Num: 30 Episode T: 12 Reward: 1.144
# Total T: 631 Episode Num: 31 Episode T: 12 Reward: -3.823
# Total T: 643 Episode Num: 32 Episode T: 12 Reward: -0.033
# Total T: 673 Episode Num: 33 Episode T: 30 Reward: 5.553
# Total T: 682 Episode Num: 34 Episode T: 9 Reward: -1.719
# Total T: 704 Episode Num: 35 Episode T: 22 Reward: 9.199
# Total T: 737 Episode Num: 36 Episode T: 33 Reward: 2.702
# Total T: 754 Episode Num: 37 Episode T: 17 Reward: 3.999
# Total T: 792 Episode Num: 38 Episode T: 38 Reward: 0.771
# Total T: 807 Episode Num: 39 Episode T: 15 Reward: 5.313
# Total T: 829 Episode Num: 40 Episode T: 22 Reward: 2.186
# Total T: 854 Episode Num: 41 Episode T: 25 Reward: -3.227
# Total T: 884 Episode Num: 42 Episode T: 30 Reward: 0.440
# Total T: 906 Episode Num: 43 Episode T: 22 Reward: -2.800
# Total T: 929 Episode Num: 44 Episode T: 23 Reward: -4.454
# Total T: 950 Episode Num: 45 Episode T: 21 Reward: -2.789
# Total T: 958 Episode Num: 46 Episode T: 8 Reward: -3.490
# Total T: 984 Episode Num: 47 Episode T: 26 Reward: 8.496
# Total T: 1002 Episode Num: 48 Episode T: 18 Reward: 1.899
# Total T: 1015 Episode Num: 49 Episode T: 13 Reward: -1.737
# Total T: 1037 Episode Num: 50 Episode T: 22 Reward: -2.126
# Total T: 1065 Episode Num: 51 Episode T: 28 Reward: 8.643
# Total T: 1087 Episode Num: 52 Episode T: 22 Reward: 2.631
# Total T: 1100 Episode Num: 53 Episode T: 13 Reward: -1.406
# Total T: 1119 Episode Num: 54 Episode T: 19 Reward: 2.054
# Total T: 1133 Episode Num: 55 Episode T: 14 Reward: -0.471
# Total T: 1156 Episode Num: 56 Episode T: 23 Reward: 8.720
# Total T: 1174 Episode Num: 57 Episode T: 18 Reward: -8.295
# Total T: 1197 Episode Num: 58 Episode T: 23 Reward: 6.615
# Total T: 1214 Episode Num: 59 Episode T: 17 Reward: -3.745
# Total T: 1238 Episode Num: 60 Episode T: 24 Reward: 13.108
# Total T: 1251 Episode Num: 61 Episode T: 13 Reward: -2.201
# Total T: 1275 Episode Num: 62 Episode T: 24 Reward: 2.446
# Total T: 1290 Episode Num: 63 Episode T: 15 Reward: 1.916
# Total T: 1312 Episode Num: 64 Episode T: 22 Reward: 1.008
# Total T: 1333 Episode Num: 65 Episode T: 21 Reward: 5.663
# Total T: 1354 Episode Num: 66 Episode T: 21 Reward: 4.204
# Total T: 1367 Episode Num: 67 Episode T: 13 Reward: 1.123
# Total T: 1387 Episode Num: 68 Episode T: 20 Reward: 8.645
# Total T: 1398 Episode Num: 69 Episode T: 11 Reward: 0.057
# Total T: 1409 Episode Num: 70 Episode T: 11 Reward: 1.966
# Total T: 1430 Episode Num: 71 Episode T: 21 Reward: 7.100
# Total T: 1455 Episode Num: 72 Episode T: 25 Reward: 1.490
# Total T: 1478 Episode Num: 73 Episode T: 23 Reward: -3.383
# Total T: 1523 Episode Num: 74 Episode T: 45 Reward: 1.618
# Total T: 1550 Episode Num: 75 Episode T: 27 Reward: 10.565
# Total T: 1583 Episode Num: 76 Episode T: 33 Reward: 1.880
# Total T: 1599 Episode Num: 77 Episode T: 16 Reward: 2.260
# Total T: 1616 Episode Num: 78 Episode T: 17 Reward: -0.146
# Total T: 1631 Episode Num: 79 Episode T: 15 Reward: 3.904
# Total T: 1665 Episode Num: 80 Episode T: 34 Reward: 3.024
# Total T: 1687 Episode Num: 81 Episode T: 22 Reward: -0.814
# Total T: 1711 Episode Num: 82 Episode T: 24 Reward: 5.635
# Total T: 1737 Episode Num: 83 Episode T: 26 Reward: 5.854
# Total T: 1751 Episode Num: 84 Episode T: 14 Reward: 0.677
# Total T: 1770 Episode Num: 85 Episode T: 19 Reward: -1.833
# Total T: 1785 Episode Num: 86 Episode T: 15 Reward: 3.096
# Total T: 1812 Episode Num: 87 Episode T: 27 Reward: -0.217
# Total T: 1824 Episode Num: 88 Episode T: 12 Reward: -2.919
# Total T: 1841 Episode Num: 89 Episode T: 17 Reward: 4.918
# Total T: 1852 Episode Num: 90 Episode T: 11 Reward: 0.490
# Total T: 1880 Episode Num: 91 Episode T: 28 Reward: -7.103
# Total T: 1892 Episode Num: 92 Episode T: 12 Reward: -0.349
# Total T: 1913 Episode Num: 93 Episode T: 21 Reward: 2.888
# Total T: 1933 Episode Num: 94 Episode T: 20 Reward: 4.784
# Total T: 1954 Episode Num: 95 Episode T: 21 Reward: 5.549
# Total T: 1964 Episode Num: 96 Episode T: 10 Reward: -2.171
# Total T: 1978 Episode Num: 97 Episode T: 14 Reward: 0.915
# Total T: 1998 Episode Num: 98 Episode T: 20 Reward: 7.827
# Total T: 2009 Episode Num: 99 Episode T: 11 Reward: -1.964
# Total T: 2027 Episode Num: 100 Episode T: 18 Reward: -0.628
# Total T: 2066 Episode Num: 101 Episode T: 39 Reward: 22.394
# Total T: 2081 Episode Num: 102 Episode T: 15 Reward: -2.470
# Total T: 2094 Episode Num: 103 Episode T: 13 Reward: 2.721
# Total T: 2108 Episode Num: 104 Episode T: 14 Reward: -2.170
# Total T: 2123 Episode Num: 105 Episode T: 15 Reward: 0.347
# Total T: 2152 Episode Num: 106 Episode T: 29 Reward: 3.656
# Total T: 2170 Episode Num: 107 Episode T: 18 Reward: 2.253
# Total T: 2212 Episode Num: 108 Episode T: 42 Reward: -2.959
# Total T: 2230 Episode Num: 109 Episode T: 18 Reward: 4.990
# Total T: 2249 Episode Num: 110 Episode T: 19 Reward: 2.867
# Total T: 2261 Episode Num: 111 Episode T: 12 Reward: -6.871
# Total T: 2296 Episode Num: 112 Episode T: 35 Reward: 7.152
# Total T: 2311 Episode Num: 113 Episode T: 15 Reward: 2.688
# Total T: 2346 Episode Num: 114 Episode T: 35 Reward: 24.482
# Total T: 2376 Episode Num: 115 Episode T: 30 Reward: 7.227
# Total T: 2404 Episode Num: 116 Episode T: 28 Reward: 0.227
# Total T: 2421 Episode Num: 117 Episode T: 17 Reward: 0.446
# Total T: 2436 Episode Num: 118 Episode T: 15 Reward: -0.375
# Total T: 2458 Episode Num: 119 Episode T: 22 Reward: -5.649
# Total T: 2466 Episode Num: 120 Episode T: 8 Reward: -3.882
# Total T: 2483 Episode Num: 121 Episode T: 17 Reward: 3.182
# Total T: 2502 Episode Num: 122 Episode T: 19 Reward: 0.589
# Total T: 2517 Episode Num: 123 Episode T: 15 Reward: -0.735
# Total T: 2538 Episode Num: 124 Episode T: 21 Reward: -6.268
# Total T: 2547 Episode Num: 125 Episode T: 9 Reward: -1.502
# Total T: 2575 Episode Num: 126 Episode T: 28 Reward: 0.544
# Total T: 2590 Episode Num: 127 Episode T: 15 Reward: -0.998
# Total T: 2609 Episode Num: 128 Episode T: 19 Reward: 1.260
# Total T: 2627 Episode Num: 129 Episode T: 18 Reward: -3.238
# Total T: 2638 Episode Num: 130 Episode T: 11 Reward: -0.904
# Total T: 2660 Episode Num: 131 Episode T: 22 Reward: 0.055
# Total T: 2703 Episode Num: 132 Episode T: 43 Reward: 25.655
# Total T: 2738 Episode Num: 133 Episode T: 35 Reward: 14.265
# Total T: 2765 Episode Num: 134 Episode T: 27 Reward: 11.164
# Total T: 2783 Episode Num: 135 Episode T: 18 Reward: 3.809
# Total T: 2795 Episode Num: 136 Episode T: 12 Reward: 0.394
# Total T: 2822 Episode Num: 137 Episode T: 27 Reward: 2.139
# Total T: 2835 Episode Num: 138 Episode T: 13 Reward: -1.898
# Total T: 2850 Episode Num: 139 Episode T: 15 Reward: 2.723
# Total T: 2864 Episode Num: 140 Episode T: 14 Reward: -3.958
# Total T: 2878 Episode Num: 141 Episode T: 14 Reward: 1.810
# Total T: 2893 Episode Num: 142 Episode T: 15 Reward: -0.519
# Total T: 2917 Episode Num: 143 Episode T: 24 Reward: 4.097
# Total T: 2946 Episode Num: 144 Episode T: 29 Reward: 14.824
# Total T: 2960 Episode Num: 145 Episode T: 14 Reward: 4.699
# Total T: 2989 Episode Num: 146 Episode T: 29 Reward: 2.584
# Total T: 3027 Episode Num: 147 Episode T: 38 Reward: 1.286
# Total T: 3045 Episode Num: 148 Episode T: 18 Reward: 1.103
# Total T: 3101 Episode Num: 149 Episode T: 56 Reward: 32.155
# Total T: 3109 Episode Num: 150 Episode T: 8 Reward: -2.982
# Total T: 3129 Episode Num: 151 Episode T: 20 Reward: -1.912
# Total T: 3157 Episode Num: 152 Episode T: 28 Reward: 8.522
# Total T: 3172 Episode Num: 153 Episode T: 15 Reward: -3.467
# Total T: 3194 Episode Num: 154 Episode T: 22 Reward: -0.799
# Total T: 3223 Episode Num: 155 Episode T: 29 Reward: 9.442
# Total T: 3242 Episode Num: 156 Episode T: 19 Reward: -4.292
# Total T: 3280 Episode Num: 157 Episode T: 38 Reward: 4.045
# Total T: 3307 Episode Num: 158 Episode T: 27 Reward: -3.464
# Total T: 3319 Episode Num: 159 Episode T: 12 Reward: -1.571
# Total T: 3339 Episode Num: 160 Episode T: 20 Reward: -2.701
# Total T: 3366 Episode Num: 161 Episode T: 27 Reward: 5.876
# Total T: 3403 Episode Num: 162 Episode T: 37 Reward: 16.896
# Total T: 3420 Episode Num: 163 Episode T: 17 Reward: -1.163
# Total T: 3437 Episode Num: 164 Episode T: 17 Reward: 2.338
# Total T: 3457 Episode Num: 165 Episode T: 20 Reward: 11.242
# Total T: 3482 Episode Num: 166 Episode T: 25 Reward: 13.976
# Total T: 3507 Episode Num: 167 Episode T: 25 Reward: 0.943
# Total T: 3526 Episode Num: 168 Episode T: 19 Reward: 7.632
# Total T: 3538 Episode Num: 169 Episode T: 12 Reward: -1.918
# Total T: 3555 Episode Num: 170 Episode T: 17 Reward: 5.036
# Total T: 3572 Episode Num: 171 Episode T: 17 Reward: -0.961
# Total T: 3591 Episode Num: 172 Episode T: 19 Reward: 3.107
# Total T: 3604 Episode Num: 173 Episode T: 13 Reward: 1.385
# Total T: 3630 Episode Num: 174 Episode T: 26 Reward: 6.467
# Total T: 3651 Episode Num: 175 Episode T: 21 Reward: 4.207
# Total T: 3665 Episode Num: 176 Episode T: 14 Reward: 2.018
# Total T: 3698 Episode Num: 177 Episode T: 33 Reward: 5.208
# Total T: 3715 Episode Num: 178 Episode T: 17 Reward: -0.557
# Total T: 3725 Episode Num: 179 Episode T: 10 Reward: -3.525
# Total T: 3746 Episode Num: 180 Episode T: 21 Reward: 0.857
# Total T: 3758 Episode Num: 181 Episode T: 12 Reward: -2.026
# Total T: 3769 Episode Num: 182 Episode T: 11 Reward: -0.272
# Total T: 3793 Episode Num: 183 Episode T: 24 Reward: -0.922
# Total T: 3814 Episode Num: 184 Episode T: 21 Reward: 0.026
# Total T: 3840 Episode Num: 185 Episode T: 26 Reward: 9.610
# Total T: 3856 Episode Num: 186 Episode T: 16 Reward: 5.372
# Total T: 3883 Episode Num: 187 Episode T: 27 Reward: 10.270
# Total T: 3893 Episode Num: 188 Episode T: 10 Reward: 1.101
# Total T: 3913 Episode Num: 189 Episode T: 20 Reward: -9.953
# Total T: 3931 Episode Num: 190 Episode T: 18 Reward: -4.953
# Total T: 3951 Episode Num: 191 Episode T: 20 Reward: -1.279
# Total T: 3964 Episode Num: 192 Episode T: 13 Reward: -0.367
# Total T: 3982 Episode Num: 193 Episode T: 18 Reward: 5.836
# Total T: 3996 Episode Num: 194 Episode T: 14 Reward: -0.921
# Total T: 4007 Episode Num: 195 Episode T: 11 Reward: 0.502
# Total T: 4017 Episode Num: 196 Episode T: 10 Reward: -4.088
# Total T: 4030 Episode Num: 197 Episode T: 13 Reward: 2.141
# Total T: 4061 Episode Num: 198 Episode T: 31 Reward: 14.202
# Total T: 4074 Episode Num: 199 Episode T: 13 Reward: -1.234
# Total T: 4093 Episode Num: 200 Episode T: 19 Reward: -0.625
# Total T: 4103 Episode Num: 201 Episode T: 10 Reward: -1.408
# Total T: 4112 Episode Num: 202 Episode T: 9 Reward: -7.324
# Total T: 4142 Episode Num: 203 Episode T: 30 Reward: 15.968
# Total T: 4165 Episode Num: 204 Episode T: 23 Reward: 5.614
# Total T: 4176 Episode Num: 205 Episode T: 11 Reward: 2.118
# Total T: 4210 Episode Num: 206 Episode T: 34 Reward: 6.114
# Total T: 4243 Episode Num: 207 Episode T: 33 Reward: -0.988
# Total T: 4258 Episode Num: 208 Episode T: 15 Reward: -0.364
# Total T: 4268 Episode Num: 209 Episode T: 10 Reward: -5.270
# Total T: 4276 Episode Num: 210 Episode T: 8 Reward: -2.031
# Total T: 4307 Episode Num: 211 Episode T: 31 Reward: 2.642
# Total T: 4331 Episode Num: 212 Episode T: 24 Reward: 7.310
# Total T: 4361 Episode Num: 213 Episode T: 30 Reward: 0.524
# Total T: 4373 Episode Num: 214 Episode T: 12 Reward: 1.911
# Total T: 4396 Episode Num: 215 Episode T: 23 Reward: 6.993
# Total T: 4409 Episode Num: 216 Episode T: 13 Reward: 0.571
# Total T: 4428 Episode Num: 217 Episode T: 19 Reward: -3.523
# Total T: 4444 Episode Num: 218 Episode T: 16 Reward: 1.435
# Total T: 4458 Episode Num: 219 Episode T: 14 Reward: -1.025
# Total T: 4475 Episode Num: 220 Episode T: 17 Reward: 6.421
# Total T: 4506 Episode Num: 221 Episode T: 31 Reward: 11.054
# Total T: 4534 Episode Num: 222 Episode T: 28 Reward: -3.306
# Total T: 4559 Episode Num: 223 Episode T: 25 Reward: -1.578
# Total T: 4586 Episode Num: 224 Episode T: 27 Reward: 8.295
# Total T: 4602 Episode Num: 225 Episode T: 16 Reward: -4.276
# Total T: 4623 Episode Num: 226 Episode T: 21 Reward: 0.443
# Total T: 4639 Episode Num: 227 Episode T: 16 Reward: -4.135
# Total T: 4657 Episode Num: 228 Episode T: 18 Reward: -3.857
# Total T: 4671 Episode Num: 229 Episode T: 14 Reward: -2.884
# Total T: 4686 Episode Num: 230 Episode T: 15 Reward: 1.743
# Total T: 4699 Episode Num: 231 Episode T: 13 Reward: 0.301
# Total T: 4718 Episode Num: 232 Episode T: 19 Reward: 4.327
# Total T: 4741 Episode Num: 233 Episode T: 23 Reward: 0.876
# Total T: 4761 Episode Num: 234 Episode T: 20 Reward: -5.783
# Total T: 4772 Episode Num: 235 Episode T: 11 Reward: 1.786
# Total T: 4791 Episode Num: 236 Episode T: 19 Reward: 4.919
# Total T: 4825 Episode Num: 237 Episode T: 34 Reward: 7.851
# Total T: 4845 Episode Num: 238 Episode T: 20 Reward: -0.906
# Total T: 4870 Episode Num: 239 Episode T: 25 Reward: -4.257
# Total T: 4895 Episode Num: 240 Episode T: 25 Reward: 5.679
# Total T: 4906 Episode Num: 241 Episode T: 11 Reward: -3.409
# Total T: 4920 Episode Num: 242 Episode T: 14 Reward: -0.654
# Total T: 4937 Episode Num: 243 Episode T: 17 Reward: 2.382
# Total T: 4954 Episode Num: 244 Episode T: 17 Reward: 3.631
# Total T: 4971 Episode Num: 245 Episode T: 17 Reward: 10.519
# Total T: 4997 Episode Num: 246 Episode T: 26 Reward: 4.784
# ---------------------------------------
# Evaluation over 10 episodes: 7.883
# ---------------------------------------
# Total T: 5019 Episode Num: 247 Episode T: 22 Reward: 5.216
# Total T: 5035 Episode Num: 248 Episode T: 16 Reward: -1.056
# Total T: 5046 Episode Num: 249 Episode T: 11 Reward: -0.470
# Total T: 5062 Episode Num: 250 Episode T: 16 Reward: 2.055
# Total T: 5095 Episode Num: 251 Episode T: 33 Reward: 5.481
# Total T: 5110 Episode Num: 252 Episode T: 15 Reward: 2.112
# Total T: 5120 Episode Num: 253 Episode T: 10 Reward: -2.452
# Total T: 5136 Episode Num: 254 Episode T: 16 Reward: 3.752
# Total T: 5153 Episode Num: 255 Episode T: 17 Reward: -2.979
# Total T: 5190 Episode Num: 256 Episode T: 37 Reward: 15.900
# Total T: 5206 Episode Num: 257 Episode T: 16 Reward: -3.154
# Total T: 5236 Episode Num: 258 Episode T: 30 Reward: 10.761
# Total T: 5248 Episode Num: 259 Episode T: 12 Reward: 1.400
# Total T: 5272 Episode Num: 260 Episode T: 24 Reward: 2.017
# Total T: 5299 Episode Num: 261 Episode T: 27 Reward: 2.368
# Total T: 5323 Episode Num: 262 Episode T: 24 Reward: -0.916
# Total T: 5347 Episode Num: 263 Episode T: 24 Reward: 5.015
# Total T: 5360 Episode Num: 264 Episode T: 13 Reward: -0.425
# Total T: 5368 Episode Num: 265 Episode T: 8 Reward: -4.086
# Total T: 5376 Episode Num: 266 Episode T: 8 Reward: -3.338
# Total T: 5401 Episode Num: 267 Episode T: 25 Reward: -2.960
# Total T: 5412 Episode Num: 268 Episode T: 11 Reward: -4.750
# Total T: 5424 Episode Num: 269 Episode T: 12 Reward: 2.296
# Total T: 5443 Episode Num: 270 Episode T: 19 Reward: -2.426
# Total T: 5473 Episode Num: 271 Episode T: 30 Reward: 7.586
# Total T: 5496 Episode Num: 272 Episode T: 23 Reward: -2.426
# Total T: 5509 Episode Num: 273 Episode T: 13 Reward: -2.690
# Total T: 5532 Episode Num: 274 Episode T: 23 Reward: 6.427
# Total T: 5547 Episode Num: 275 Episode T: 15 Reward: 2.531
# Total T: 5565 Episode Num: 276 Episode T: 18 Reward: 7.607
# Total T: 5602 Episode Num: 277 Episode T: 37 Reward: 6.321
# Total T: 5627 Episode Num: 278 Episode T: 25 Reward: 10.907
# Total T: 5640 Episode Num: 279 Episode T: 13 Reward: -1.665
# Total T: 5665 Episode Num: 280 Episode T: 25 Reward: 8.104
# Total T: 5675 Episode Num: 281 Episode T: 10 Reward: -0.196
# Total T: 5686 Episode Num: 282 Episode T: 11 Reward: -2.271
# Total T: 5719 Episode Num: 283 Episode T: 33 Reward: 8.561
# Total T: 5728 Episode Num: 284 Episode T: 9 Reward: -2.376
# Total T: 5759 Episode Num: 285 Episode T: 31 Reward: -1.148
# Total T: 5779 Episode Num: 286 Episode T: 20 Reward: -6.399
# Total T: 5809 Episode Num: 287 Episode T: 30 Reward: -3.334
# Total T: 5831 Episode Num: 288 Episode T: 22 Reward: 0.140
# Total T: 5851 Episode Num: 289 Episode T: 20 Reward: -0.119
# Total T: 5863 Episode Num: 290 Episode T: 12 Reward: 0.794
# Total T: 5879 Episode Num: 291 Episode T: 16 Reward: -0.785
# Total T: 5894 Episode Num: 292 Episode T: 15 Reward: -0.445
# Total T: 5910 Episode Num: 293 Episode T: 16 Reward: -2.775
# Total T: 5927 Episode Num: 294 Episode T: 17 Reward: -1.569
# Total T: 5940 Episode Num: 295 Episode T: 13 Reward: 0.658
# Total T: 5959 Episode Num: 296 Episode T: 19 Reward: -3.872
# Total T: 5974 Episode Num: 297 Episode T: 15 Reward: -0.583
# Total T: 5996 Episode Num: 298 Episode T: 22 Reward: 3.087
# Total T: 6016 Episode Num: 299 Episode T: 20 Reward: -1.893
# Total T: 6036 Episode Num: 300 Episode T: 20 Reward: 7.517
# Total T: 6066 Episode Num: 301 Episode T: 30 Reward: 7.656
# Total T: 6094 Episode Num: 302 Episode T: 28 Reward: -5.040
# Total T: 6119 Episode Num: 303 Episode T: 25 Reward: -11.095
# Total T: 6155 Episode Num: 304 Episode T: 36 Reward: -4.884
# Total T: 6170 Episode Num: 305 Episode T: 15 Reward: 0.990
# Total T: 6194 Episode Num: 306 Episode T: 24 Reward: 7.607
# Total T: 6210 Episode Num: 307 Episode T: 16 Reward: 1.505
# Total T: 6236 Episode Num: 308 Episode T: 26 Reward: 5.429
# Total T: 6252 Episode Num: 309 Episode T: 16 Reward: -0.940
# Total T: 6277 Episode Num: 310 Episode T: 25 Reward: 14.016
# Total T: 6292 Episode Num: 311 Episode T: 15 Reward: -0.291
# Total T: 6334 Episode Num: 312 Episode T: 42 Reward: 9.598
# Total T: 6352 Episode Num: 313 Episode T: 18 Reward: 2.206
# Total T: 6372 Episode Num: 314 Episode T: 20 Reward: -2.441
# Total T: 6403 Episode Num: 315 Episode T: 31 Reward: 18.225
# Total T: 6419 Episode Num: 316 Episode T: 16 Reward: 4.516
# Total T: 6431 Episode Num: 317 Episode T: 12 Reward: -1.612
# Total T: 6446 Episode Num: 318 Episode T: 15 Reward: -2.389
# Total T: 6470 Episode Num: 319 Episode T: 24 Reward: 9.042
# Total T: 6491 Episode Num: 320 Episode T: 21 Reward: 8.295
# Total T: 6531 Episode Num: 321 Episode T: 40 Reward: 20.587
# Total T: 6550 Episode Num: 322 Episode T: 19 Reward: 1.817
# Total T: 6581 Episode Num: 323 Episode T: 31 Reward: 1.689
# Total T: 6629 Episode Num: 324 Episode T: 48 Reward: 9.167
# Total T: 6656 Episode Num: 325 Episode T: 27 Reward: -0.167
# Total T: 6671 Episode Num: 326 Episode T: 15 Reward: 0.729
# Total T: 6688 Episode Num: 327 Episode T: 17 Reward: 2.937
# Total T: 6698 Episode Num: 328 Episode T: 10 Reward: -0.846
# Total T: 6717 Episode Num: 329 Episode T: 19 Reward: -1.994
# Total T: 6745 Episode Num: 330 Episode T: 28 Reward: 7.286
# Total T: 6778 Episode Num: 331 Episode T: 33 Reward: 8.081
# Total T: 6791 Episode Num: 332 Episode T: 13 Reward: -0.565
# Total T: 6828 Episode Num: 333 Episode T: 37 Reward: 18.328
# Total T: 6847 Episode Num: 334 Episode T: 19 Reward: 6.546
# Total T: 6861 Episode Num: 335 Episode T: 14 Reward: -1.608
# Total T: 6877 Episode Num: 336 Episode T: 16 Reward: 2.981
# Total T: 6888 Episode Num: 337 Episode T: 11 Reward: 1.841
# Total T: 6920 Episode Num: 338 Episode T: 32 Reward: 9.142
# Total T: 6962 Episode Num: 339 Episode T: 42 Reward: 14.365
# Total T: 6979 Episode Num: 340 Episode T: 17 Reward: 5.856
# Total T: 7003 Episode Num: 341 Episode T: 24 Reward: 3.807
# Total T: 7022 Episode Num: 342 Episode T: 19 Reward: 7.126
# Total T: 7040 Episode Num: 343 Episode T: 18 Reward: 5.639
# Total T: 7061 Episode Num: 344 Episode T: 21 Reward: 10.221
# Total T: 7123 Episode Num: 345 Episode T: 62 Reward: 6.118
# Total T: 7155 Episode Num: 346 Episode T: 32 Reward: 2.985
# Total T: 7168 Episode Num: 347 Episode T: 13 Reward: 0.871
# Total T: 7181 Episode Num: 348 Episode T: 13 Reward: -1.314
# Total T: 7195 Episode Num: 349 Episode T: 14 Reward: -3.153
# Total T: 7215 Episode Num: 350 Episode T: 20 Reward: 6.564
# Total T: 7232 Episode Num: 351 Episode T: 17 Reward: 1.540
# Total T: 7253 Episode Num: 352 Episode T: 21 Reward: -8.228
# Total T: 7285 Episode Num: 353 Episode T: 32 Reward: 3.724
# Total T: 7295 Episode Num: 354 Episode T: 10 Reward: 0.560
# Total T: 7320 Episode Num: 355 Episode T: 25 Reward: -0.973
# Total T: 7331 Episode Num: 356 Episode T: 11 Reward: -3.378
# Total T: 7346 Episode Num: 357 Episode T: 15 Reward: 5.516
# Total T: 7365 Episode Num: 358 Episode T: 19 Reward: 2.882
# Total T: 7384 Episode Num: 359 Episode T: 19 Reward: 7.689
# Total T: 7408 Episode Num: 360 Episode T: 24 Reward: -0.690
# Total T: 7437 Episode Num: 361 Episode T: 29 Reward: 5.771
# Total T: 7454 Episode Num: 362 Episode T: 17 Reward: 2.568
# Total T: 7466 Episode Num: 363 Episode T: 12 Reward: -0.843
# Total T: 7489 Episode Num: 364 Episode T: 23 Reward: 4.845
# Total T: 7505 Episode Num: 365 Episode T: 16 Reward: 0.950
# Total T: 7556 Episode Num: 366 Episode T: 51 Reward: 21.989
# Total T: 7571 Episode Num: 367 Episode T: 15 Reward: -0.862
# Total T: 7607 Episode Num: 368 Episode T: 36 Reward: 0.967
# Total T: 7626 Episode Num: 369 Episode T: 19 Reward: 0.928
# Total T: 7663 Episode Num: 370 Episode T: 37 Reward: 10.707
# Total T: 7682 Episode Num: 371 Episode T: 19 Reward: 6.658
# Total T: 7695 Episode Num: 372 Episode T: 13 Reward: -0.777
# Total T: 7712 Episode Num: 373 Episode T: 17 Reward: 0.757
# Total T: 7721 Episode Num: 374 Episode T: 9 Reward: -1.733
# Total T: 7736 Episode Num: 375 Episode T: 15 Reward: 2.728
# Total T: 7754 Episode Num: 376 Episode T: 18 Reward: -3.370
# Total T: 7773 Episode Num: 377 Episode T: 19 Reward: 1.025
# Total T: 7788 Episode Num: 378 Episode T: 15 Reward: 6.287
# Total T: 7819 Episode Num: 379 Episode T: 31 Reward: 3.932
# Total T: 7831 Episode Num: 380 Episode T: 12 Reward: 3.944
# Total T: 7845 Episode Num: 381 Episode T: 14 Reward: 0.144
# Total T: 7864 Episode Num: 382 Episode T: 19 Reward: -1.084
# Total T: 7882 Episode Num: 383 Episode T: 18 Reward: -2.198
# Total T: 7896 Episode Num: 384 Episode T: 14 Reward: -0.555
# Total T: 7919 Episode Num: 385 Episode T: 23 Reward: -0.421
# Total T: 7934 Episode Num: 386 Episode T: 15 Reward: 3.544
# Total T: 7948 Episode Num: 387 Episode T: 14 Reward: 5.375
# Total T: 7963 Episode Num: 388 Episode T: 15 Reward: 2.467
# Total T: 7985 Episode Num: 389 Episode T: 22 Reward: 3.193
# Total T: 7993 Episode Num: 390 Episode T: 8 Reward: -2.984
# Total T: 8005 Episode Num: 391 Episode T: 12 Reward: -3.153
# Total T: 8045 Episode Num: 392 Episode T: 40 Reward: 11.487
# Total T: 8077 Episode Num: 393 Episode T: 32 Reward: -0.360
# Total T: 8104 Episode Num: 394 Episode T: 27 Reward: 2.892
# Total T: 8147 Episode Num: 395 Episode T: 43 Reward: 22.489
# Total T: 8168 Episode Num: 396 Episode T: 21 Reward: 4.242
# Total T: 8193 Episode Num: 397 Episode T: 25 Reward: 3.239
# Total T: 8208 Episode Num: 398 Episode T: 15 Reward: 4.185
# Total T: 8221 Episode Num: 399 Episode T: 13 Reward: 0.705
# Total T: 8243 Episode Num: 400 Episode T: 22 Reward: -14.330
# Total T: 8264 Episode Num: 401 Episode T: 21 Reward: 2.720
# Total T: 8275 Episode Num: 402 Episode T: 11 Reward: 1.697
# Total T: 8292 Episode Num: 403 Episode T: 17 Reward: -1.988
# Total T: 8304 Episode Num: 404 Episode T: 12 Reward: -3.331
# Total T: 8325 Episode Num: 405 Episode T: 21 Reward: 0.311
# Total T: 8336 Episode Num: 406 Episode T: 11 Reward: 0.827
# Total T: 8355 Episode Num: 407 Episode T: 19 Reward: 2.090
# Total T: 8389 Episode Num: 408 Episode T: 34 Reward: 6.996
# Total T: 8399 Episode Num: 409 Episode T: 10 Reward: -4.370
# Total T: 8409 Episode Num: 410 Episode T: 10 Reward: -1.071
# Total T: 8429 Episode Num: 411 Episode T: 20 Reward: -0.301
# Total T: 8438 Episode Num: 412 Episode T: 9 Reward: -2.543
# Total T: 8464 Episode Num: 413 Episode T: 26 Reward: -1.274
# Total T: 8488 Episode Num: 414 Episode T: 24 Reward: 0.827
# Total T: 8506 Episode Num: 415 Episode T: 18 Reward: 6.232
# Total T: 8520 Episode Num: 416 Episode T: 14 Reward: -4.514
# Total T: 8533 Episode Num: 417 Episode T: 13 Reward: -4.098
# Total T: 8549 Episode Num: 418 Episode T: 16 Reward: -4.070
# Total T: 8560 Episode Num: 419 Episode T: 11 Reward: -3.072
# Total T: 8595 Episode Num: 420 Episode T: 35 Reward: 2.889
# Total T: 8612 Episode Num: 421 Episode T: 17 Reward: -0.215
# Total T: 8639 Episode Num: 422 Episode T: 27 Reward: -2.735
# Total T: 8664 Episode Num: 423 Episode T: 25 Reward: 9.905
# Total T: 8685 Episode Num: 424 Episode T: 21 Reward: 9.672
# Total T: 8698 Episode Num: 425 Episode T: 13 Reward: -0.227
# Total T: 8711 Episode Num: 426 Episode T: 13 Reward: 0.171
# Total T: 8734 Episode Num: 427 Episode T: 23 Reward: -4.664
# Total T: 8777 Episode Num: 428 Episode T: 43 Reward: 10.907
# Total T: 8792 Episode Num: 429 Episode T: 15 Reward: -1.877
# Total T: 8805 Episode Num: 430 Episode T: 13 Reward: 1.071
# Total T: 8844 Episode Num: 431 Episode T: 39 Reward: 5.077
# Total T: 8859 Episode Num: 432 Episode T: 15 Reward: 1.975
# Total T: 8869 Episode Num: 433 Episode T: 10 Reward: -0.908
# Total T: 8882 Episode Num: 434 Episode T: 13 Reward: 0.218
# Total T: 8897 Episode Num: 435 Episode T: 15 Reward: 1.497
# Total T: 8916 Episode Num: 436 Episode T: 19 Reward: 4.286
# Total T: 8927 Episode Num: 437 Episode T: 11 Reward: 0.019
# Total T: 8943 Episode Num: 438 Episode T: 16 Reward: -7.732
# Total T: 8962 Episode Num: 439 Episode T: 19 Reward: 1.479
# Total T: 8984 Episode Num: 440 Episode T: 22 Reward: -10.971
# Total T: 9020 Episode Num: 441 Episode T: 36 Reward: 18.181
# Total T: 9031 Episode Num: 442 Episode T: 11 Reward: 2.036
# Total T: 9047 Episode Num: 443 Episode T: 16 Reward: 1.485
# Total T: 9073 Episode Num: 444 Episode T: 26 Reward: 13.226
# Total T: 9104 Episode Num: 445 Episode T: 31 Reward: 6.285
# Total T: 9120 Episode Num: 446 Episode T: 16 Reward: -4.301
# Total T: 9133 Episode Num: 447 Episode T: 13 Reward: -4.138
# Total T: 9142 Episode Num: 448 Episode T: 9 Reward: -2.757
# Total T: 9168 Episode Num: 449 Episode T: 26 Reward: 0.524
# Total T: 9179 Episode Num: 450 Episode T: 11 Reward: -1.564
# Total T: 9209 Episode Num: 451 Episode T: 30 Reward: 0.587
# Total T: 9223 Episode Num: 452 Episode T: 14 Reward: -1.722
# Total T: 9245 Episode Num: 453 Episode T: 22 Reward: 0.039
# Total T: 9258 Episode Num: 454 Episode T: 13 Reward: 2.573
# Total T: 9277 Episode Num: 455 Episode T: 19 Reward: -3.824
# Total T: 9298 Episode Num: 456 Episode T: 21 Reward: 4.368
# Total T: 9309 Episode Num: 457 Episode T: 11 Reward: -0.341
# Total T: 9332 Episode Num: 458 Episode T: 23 Reward: 1.793
# Total T: 9342 Episode Num: 459 Episode T: 10 Reward: -1.141
# Total T: 9383 Episode Num: 460 Episode T: 41 Reward: 11.750
# Total T: 9405 Episode Num: 461 Episode T: 22 Reward: 5.290
# Total T: 9424 Episode Num: 462 Episode T: 19 Reward: 6.478
# Total T: 9444 Episode Num: 463 Episode T: 20 Reward: 9.406
# Total T: 9492 Episode Num: 464 Episode T: 48 Reward: 19.020
# Total T: 9507 Episode Num: 465 Episode T: 15 Reward: -0.857
# Total T: 9536 Episode Num: 466 Episode T: 29 Reward: 8.053
# Total T: 9568 Episode Num: 467 Episode T: 32 Reward: 16.648
# Total T: 9590 Episode Num: 468 Episode T: 22 Reward: -0.972
# Total T: 9604 Episode Num: 469 Episode T: 14 Reward: -1.528
# Total T: 9630 Episode Num: 470 Episode T: 26 Reward: 6.726
# Total T: 9651 Episode Num: 471 Episode T: 21 Reward: 0.653
# Total T: 9670 Episode Num: 472 Episode T: 19 Reward: -1.052
# Total T: 9681 Episode Num: 473 Episode T: 11 Reward: -3.234
# Total T: 9707 Episode Num: 474 Episode T: 26 Reward: 6.919
# Total T: 9721 Episode Num: 475 Episode T: 14 Reward: -0.120
# Total T: 9734 Episode Num: 476 Episode T: 13 Reward: -1.668
# Total T: 9747 Episode Num: 477 Episode T: 13 Reward: 0.644
# Total T: 9774 Episode Num: 478 Episode T: 27 Reward: 1.728
# Total T: 9801 Episode Num: 479 Episode T: 27 Reward: 8.152
# Total T: 9814 Episode Num: 480 Episode T: 13 Reward: 3.321
# Total T: 9844 Episode Num: 481 Episode T: 30 Reward: 9.614
# Total T: 9856 Episode Num: 482 Episode T: 12 Reward: 0.732
# Total T: 9877 Episode Num: 483 Episode T: 21 Reward: 2.059
# Total T: 9903 Episode Num: 484 Episode T: 26 Reward: 2.957
# Total T: 9919 Episode Num: 485 Episode T: 16 Reward: -6.236
# Total T: 9933 Episode Num: 486 Episode T: 14 Reward: 3.031
# Total T: 9949 Episode Num: 487 Episode T: 16 Reward: 3.167
# Total T: 9961 Episode Num: 488 Episode T: 12 Reward: -1.057
# ---------------------------------------
# Evaluation over 10 episodes: 7.883
# ---------------------------------------
# Total T: 10011 Episode Num: 489 Episode T: 50 Reward: 18.726
# Total T: 10028 Episode Num: 490 Episode T: 17 Reward: 4.661
# Total T: 10045 Episode Num: 491 Episode T: 17 Reward: 3.214
# Total T: 10061 Episode Num: 492 Episode T: 16 Reward: 1.529
# Total T: 10081 Episode Num: 493 Episode T: 20 Reward: -2.588
# Total T: 10123 Episode Num: 494 Episode T: 42 Reward: 9.288
# Total T: 10138 Episode Num: 495 Episode T: 15 Reward: -1.146
# Total T: 10163 Episode Num: 496 Episode T: 25 Reward: 16.843
# Total T: 10179 Episode Num: 497 Episode T: 16 Reward: -0.748
# Total T: 10193 Episode Num: 498 Episode T: 14 Reward: 0.112
# Total T: 10212 Episode Num: 499 Episode T: 19 Reward: -2.158
# Total T: 10233 Episode Num: 500 Episode T: 21 Reward: -0.929
# Total T: 10252 Episode Num: 501 Episode T: 19 Reward: 2.585
# Total T: 10279 Episode Num: 502 Episode T: 27 Reward: -0.616
# Total T: 10301 Episode Num: 503 Episode T: 22 Reward: 5.691
# Total T: 10311 Episode Num: 504 Episode T: 10 Reward: -3.081
# Total T: 10326 Episode Num: 505 Episode T: 15 Reward: -3.021
# Total T: 10339 Episode Num: 506 Episode T: 13 Reward: -8.648
# Total T: 10356 Episode Num: 507 Episode T: 17 Reward: 1.056
# Total T: 10373 Episode Num: 508 Episode T: 17 Reward: -3.681
# Total T: 10383 Episode Num: 509 Episode T: 10 Reward: -0.029
# Total T: 10397 Episode Num: 510 Episode T: 14 Reward: 2.615
# Total T: 10412 Episode Num: 511 Episode T: 15 Reward: 1.967
# Total T: 10425 Episode Num: 512 Episode T: 13 Reward: -4.701
# Total T: 10442 Episode Num: 513 Episode T: 17 Reward: 2.412
# Total T: 10462 Episode Num: 514 Episode T: 20 Reward: -8.024
# Total T: 10483 Episode Num: 515 Episode T: 21 Reward: 8.237
# Total T: 10505 Episode Num: 516 Episode T: 22 Reward: -3.648
# Total T: 10540 Episode Num: 517 Episode T: 35 Reward: 12.024
# Total T: 10559 Episode Num: 518 Episode T: 19 Reward: -1.819
# Total T: 10583 Episode Num: 519 Episode T: 24 Reward: 4.157
# Total T: 10600 Episode Num: 520 Episode T: 17 Reward: -0.716
# Total T: 10611 Episode Num: 521 Episode T: 11 Reward: 0.370
# Total T: 10622 Episode Num: 522 Episode T: 11 Reward: -0.775
# Total T: 10632 Episode Num: 523 Episode T: 10 Reward: -2.303
# Total T: 10656 Episode Num: 524 Episode T: 24 Reward: 3.690
# Total T: 10676 Episode Num: 525 Episode T: 20 Reward: 8.681
# Total T: 10698 Episode Num: 526 Episode T: 22 Reward: -0.439
# Total T: 10717 Episode Num: 527 Episode T: 19 Reward: 1.532
# Total T: 10732 Episode Num: 528 Episode T: 15 Reward: 1.777
# Total T: 10755 Episode Num: 529 Episode T: 23 Reward: -2.561
# Total T: 10766 Episode Num: 530 Episode T: 11 Reward: -1.908
# Total T: 10778 Episode Num: 531 Episode T: 12 Reward: -4.829
# Total T: 10794 Episode Num: 532 Episode T: 16 Reward: 2.604
# Total T: 10806 Episode Num: 533 Episode T: 12 Reward: -0.306
# Total T: 10820 Episode Num: 534 Episode T: 14 Reward: -9.002
# Total T: 10853 Episode Num: 535 Episode T: 33 Reward: 7.607
# Total T: 10871 Episode Num: 536 Episode T: 18 Reward: 2.954
# Total T: 10886 Episode Num: 537 Episode T: 15 Reward: -4.590
# Total T: 10901 Episode Num: 538 Episode T: 15 Reward: -6.331
# Total T: 10915 Episode Num: 539 Episode T: 14 Reward: 3.327
# Total T: 10955 Episode Num: 540 Episode T: 40 Reward: 11.524
# Total T: 10972 Episode Num: 541 Episode T: 17 Reward: 0.017
# Total T: 10990 Episode Num: 542 Episode T: 18 Reward: 5.958
# Total T: 11018 Episode Num: 543 Episode T: 28 Reward: -7.164
# Total T: 11052 Episode Num: 544 Episode T: 34 Reward: 8.403
# Total T: 11066 Episode Num: 545 Episode T: 14 Reward: -5.380
# Total T: 11088 Episode Num: 546 Episode T: 22 Reward: -2.266
# Total T: 11096 Episode Num: 547 Episode T: 8 Reward: -3.977
# Total T: 11115 Episode Num: 548 Episode T: 19 Reward: 1.258
# Total T: 11128 Episode Num: 549 Episode T: 13 Reward: 3.163
# Total T: 11166 Episode Num: 550 Episode T: 38 Reward: 11.480
# Total T: 11191 Episode Num: 551 Episode T: 25 Reward: -10.437
# Total T: 11204 Episode Num: 552 Episode T: 13 Reward: -2.633
# Total T: 11224 Episode Num: 553 Episode T: 20 Reward: 8.114
# Total T: 11233 Episode Num: 554 Episode T: 9 Reward: -2.507
# Total T: 11266 Episode Num: 555 Episode T: 33 Reward: 11.064
# Total T: 11285 Episode Num: 556 Episode T: 19 Reward: -0.856
# Total T: 11302 Episode Num: 557 Episode T: 17 Reward: 4.289
# Total T: 11317 Episode Num: 558 Episode T: 15 Reward: -2.102
# Total T: 11341 Episode Num: 559 Episode T: 24 Reward: -1.828
# Total T: 11361 Episode Num: 560 Episode T: 20 Reward: 1.399
# Total T: 11376 Episode Num: 561 Episode T: 15 Reward: 3.854
# Total T: 11391 Episode Num: 562 Episode T: 15 Reward: 1.496
# Total T: 11404 Episode Num: 563 Episode T: 13 Reward: -4.943
# Total T: 11421 Episode Num: 564 Episode T: 17 Reward: 5.138
# Total T: 11441 Episode Num: 565 Episode T: 20 Reward: -5.927
# Total T: 11453 Episode Num: 566 Episode T: 12 Reward: -0.165
# Total T: 11478 Episode Num: 567 Episode T: 25 Reward: 14.339
# Total T: 11494 Episode Num: 568 Episode T: 16 Reward: 4.875
# Total T: 11519 Episode Num: 569 Episode T: 25 Reward: 11.570
# Total T: 11550 Episode Num: 570 Episode T: 31 Reward: 14.996
# Total T: 11565 Episode Num: 571 Episode T: 15 Reward: 0.260
# Total T: 11600 Episode Num: 572 Episode T: 35 Reward: -0.067
# Total T: 11624 Episode Num: 573 Episode T: 24 Reward: -7.191
# Total T: 11672 Episode Num: 574 Episode T: 48 Reward: 12.300
# Total T: 11694 Episode Num: 575 Episode T: 22 Reward: -0.228
# Total T: 11706 Episode Num: 576 Episode T: 12 Reward: 0.147
# Total T: 11719 Episode Num: 577 Episode T: 13 Reward: 0.777
# Total T: 11731 Episode Num: 578 Episode T: 12 Reward: 0.929
# Total T: 11755 Episode Num: 579 Episode T: 24 Reward: 7.555
# Total T: 11767 Episode Num: 580 Episode T: 12 Reward: 0.361
# Total T: 11786 Episode Num: 581 Episode T: 19 Reward: 0.026
# Total T: 11801 Episode Num: 582 Episode T: 15 Reward: -0.794
# Total T: 11813 Episode Num: 583 Episode T: 12 Reward: 2.072
# Total T: 11842 Episode Num: 584 Episode T: 29 Reward: 8.760
# Total T: 11876 Episode Num: 585 Episode T: 34 Reward: 0.351
# Total T: 11889 Episode Num: 586 Episode T: 13 Reward: 3.047
# Total T: 11908 Episode Num: 587 Episode T: 19 Reward: 0.434
# Total T: 11932 Episode Num: 588 Episode T: 24 Reward: -5.447
# Total T: 11946 Episode Num: 589 Episode T: 14 Reward: 0.524
# Total T: 11961 Episode Num: 590 Episode T: 15 Reward: 1.607
# Total T: 11989 Episode Num: 591 Episode T: 28 Reward: 2.508
# Total T: 12013 Episode Num: 592 Episode T: 24 Reward: 10.427
# Total T: 12030 Episode Num: 593 Episode T: 17 Reward: -7.317
# Total T: 12043 Episode Num: 594 Episode T: 13 Reward: 0.323
# Total T: 12058 Episode Num: 595 Episode T: 15 Reward: 0.832
# Total T: 12069 Episode Num: 596 Episode T: 11 Reward: -0.885
# Total T: 12089 Episode Num: 597 Episode T: 20 Reward: 3.122
# Total T: 12112 Episode Num: 598 Episode T: 23 Reward: -0.705
# Total T: 12125 Episode Num: 599 Episode T: 13 Reward: 0.615
# Total T: 12150 Episode Num: 600 Episode T: 25 Reward: -1.197
# Total T: 12165 Episode Num: 601 Episode T: 15 Reward: 1.198
# Total T: 12182 Episode Num: 602 Episode T: 17 Reward: 2.315
# Total T: 12207 Episode Num: 603 Episode T: 25 Reward: -0.184
# Total T: 12232 Episode Num: 604 Episode T: 25 Reward: -8.342
# Total T: 12248 Episode Num: 605 Episode T: 16 Reward: 6.017
# Total T: 12272 Episode Num: 606 Episode T: 24 Reward: 9.390
# Total T: 12281 Episode Num: 607 Episode T: 9 Reward: -3.890
# Total T: 12296 Episode Num: 608 Episode T: 15 Reward: -2.204
# Total T: 12309 Episode Num: 609 Episode T: 13 Reward: -1.365
# Total T: 12338 Episode Num: 610 Episode T: 29 Reward: 3.140
# Total T: 12361 Episode Num: 611 Episode T: 23 Reward: 7.515
# Total T: 12390 Episode Num: 612 Episode T: 29 Reward: 8.411
# Total T: 12422 Episode Num: 613 Episode T: 32 Reward: 5.484
# Total T: 12431 Episode Num: 614 Episode T: 9 Reward: -3.486
# Total T: 12456 Episode Num: 615 Episode T: 25 Reward: -5.952
# Total T: 12474 Episode Num: 616 Episode T: 18 Reward: -2.482
# Total T: 12500 Episode Num: 617 Episode T: 26 Reward: 9.593
# Total T: 12522 Episode Num: 618 Episode T: 22 Reward: 2.759
# Total T: 12554 Episode Num: 619 Episode T: 32 Reward: -3.169
# Total T: 12581 Episode Num: 620 Episode T: 27 Reward: 0.920
# Total T: 12612 Episode Num: 621 Episode T: 31 Reward: 12.254
# Total T: 12627 Episode Num: 622 Episode T: 15 Reward: -1.047
# Total T: 12643 Episode Num: 623 Episode T: 16 Reward: 3.712
# Total T: 12667 Episode Num: 624 Episode T: 24 Reward: 10.184
# Total T: 12685 Episode Num: 625 Episode T: 18 Reward: 5.533
# Total T: 12717 Episode Num: 626 Episode T: 32 Reward: 1.000
# Total T: 12729 Episode Num: 627 Episode T: 12 Reward: 0.356
# Total T: 12742 Episode Num: 628 Episode T: 13 Reward: -1.327
# Total T: 12751 Episode Num: 629 Episode T: 9 Reward: -2.558
# Total T: 12762 Episode Num: 630 Episode T: 11 Reward: -5.045
# Total T: 12783 Episode Num: 631 Episode T: 21 Reward: 3.666
# Total T: 12812 Episode Num: 632 Episode T: 29 Reward: -4.447
# Total T: 12823 Episode Num: 633 Episode T: 11 Reward: -3.353
# Total T: 12851 Episode Num: 634 Episode T: 28 Reward: -8.002
# Total T: 12860 Episode Num: 635 Episode T: 9 Reward: -4.268
# Total T: 12906 Episode Num: 636 Episode T: 46 Reward: 8.706
# Total T: 12924 Episode Num: 637 Episode T: 18 Reward: 2.630
# Total T: 12949 Episode Num: 638 Episode T: 25 Reward: 6.385
# Total T: 12970 Episode Num: 639 Episode T: 21 Reward: 0.419
# Total T: 12985 Episode Num: 640 Episode T: 15 Reward: 5.508
# Total T: 13007 Episode Num: 641 Episode T: 22 Reward: -4.523
# Total T: 13040 Episode Num: 642 Episode T: 33 Reward: 1.135
# Total T: 13074 Episode Num: 643 Episode T: 34 Reward: 13.470
# Total T: 13087 Episode Num: 644 Episode T: 13 Reward: -2.932
# Total T: 13100 Episode Num: 645 Episode T: 13 Reward: 1.857
# Total T: 13119 Episode Num: 646 Episode T: 19 Reward: 6.584
# Total T: 13132 Episode Num: 647 Episode T: 13 Reward: 2.414
# Total T: 13146 Episode Num: 648 Episode T: 14 Reward: -3.950
# Total T: 13171 Episode Num: 649 Episode T: 25 Reward: -5.648
# Total T: 13189 Episode Num: 650 Episode T: 18 Reward: 3.696
# Total T: 13218 Episode Num: 651 Episode T: 29 Reward: -1.848
# Total T: 13232 Episode Num: 652 Episode T: 14 Reward: 2.059
# Total T: 13259 Episode Num: 653 Episode T: 27 Reward: 1.010
# Total T: 13303 Episode Num: 654 Episode T: 44 Reward: 10.580
# Total T: 13338 Episode Num: 655 Episode T: 35 Reward: 9.983
# Total T: 13368 Episode Num: 656 Episode T: 30 Reward: 16.858
# Total T: 13378 Episode Num: 657 Episode T: 10 Reward: -0.833
# Total T: 13394 Episode Num: 658 Episode T: 16 Reward: 2.495
# Total T: 13421 Episode Num: 659 Episode T: 27 Reward: 6.613
# Total T: 13445 Episode Num: 660 Episode T: 24 Reward: 2.558
# Total T: 13489 Episode Num: 661 Episode T: 44 Reward: 21.498
# Total T: 13508 Episode Num: 662 Episode T: 19 Reward: -2.622
# Total T: 13532 Episode Num: 663 Episode T: 24 Reward: 6.663
# Total T: 13547 Episode Num: 664 Episode T: 15 Reward: 0.610
# Total T: 13567 Episode Num: 665 Episode T: 20 Reward: 1.368
# Total T: 13585 Episode Num: 666 Episode T: 18 Reward: 4.664
# Total T: 13614 Episode Num: 667 Episode T: 29 Reward: 7.543
# Total T: 13628 Episode Num: 668 Episode T: 14 Reward: -3.338
# Total T: 13656 Episode Num: 669 Episode T: 28 Reward: -0.737
# Total T: 13672 Episode Num: 670 Episode T: 16 Reward: 2.485
# Total T: 13688 Episode Num: 671 Episode T: 16 Reward: 3.312
# Total T: 13714 Episode Num: 672 Episode T: 26 Reward: -1.753
# Total T: 13738 Episode Num: 673 Episode T: 24 Reward: 3.420
# Total T: 13767 Episode Num: 674 Episode T: 29 Reward: 18.230
# Total T: 13788 Episode Num: 675 Episode T: 21 Reward: -0.573
# Total T: 13800 Episode Num: 676 Episode T: 12 Reward: -0.412
# Total T: 13814 Episode Num: 677 Episode T: 14 Reward: -1.186
# Total T: 13829 Episode Num: 678 Episode T: 15 Reward: -0.315
# Total T: 13846 Episode Num: 679 Episode T: 17 Reward: -0.993
# Total T: 13861 Episode Num: 680 Episode T: 15 Reward: 3.263
# Total T: 13902 Episode Num: 681 Episode T: 41 Reward: 10.666
# Total T: 13917 Episode Num: 682 Episode T: 15 Reward: -2.123
# Total T: 13940 Episode Num: 683 Episode T: 23 Reward: -3.700
# Total T: 13951 Episode Num: 684 Episode T: 11 Reward: -2.189
# Total T: 13966 Episode Num: 685 Episode T: 15 Reward: 4.032
# Total T: 13988 Episode Num: 686 Episode T: 22 Reward: 5.643
# Total T: 14017 Episode Num: 687 Episode T: 29 Reward: 10.296
# Total T: 14040 Episode Num: 688 Episode T: 23 Reward: 1.600
# Total T: 14063 Episode Num: 689 Episode T: 23 Reward: 5.940
# Total T: 14078 Episode Num: 690 Episode T: 15 Reward: -0.302
# Total T: 14089 Episode Num: 691 Episode T: 11 Reward: -1.405
# Total T: 14099 Episode Num: 692 Episode T: 10 Reward: -2.391
# Total T: 14115 Episode Num: 693 Episode T: 16 Reward: 4.702
# Total T: 14139 Episode Num: 694 Episode T: 24 Reward: 10.918
# Total T: 14172 Episode Num: 695 Episode T: 33 Reward: 2.011
# Total T: 14180 Episode Num: 696 Episode T: 8 Reward: -2.995
# Total T: 14195 Episode Num: 697 Episode T: 15 Reward: -4.263
# Total T: 14210 Episode Num: 698 Episode T: 15 Reward: -1.418
# Total T: 14233 Episode Num: 699 Episode T: 23 Reward: 0.208
# Total T: 14258 Episode Num: 700 Episode T: 25 Reward: 4.665
# Total T: 14297 Episode Num: 701 Episode T: 39 Reward: 13.827
# Total T: 14320 Episode Num: 702 Episode T: 23 Reward: -4.615
# Total T: 14342 Episode Num: 703 Episode T: 22 Reward: 7.359
# Total T: 14380 Episode Num: 704 Episode T: 38 Reward: 12.914
# Total T: 14406 Episode Num: 705 Episode T: 26 Reward: -6.024
# Total T: 14432 Episode Num: 706 Episode T: 26 Reward: -0.292
# Total T: 14478 Episode Num: 707 Episode T: 46 Reward: 20.052
# Total T: 14496 Episode Num: 708 Episode T: 18 Reward: 3.736
# Total T: 14512 Episode Num: 709 Episode T: 16 Reward: -1.584
# Total T: 14527 Episode Num: 710 Episode T: 15 Reward: -0.409
# Total T: 14542 Episode Num: 711 Episode T: 15 Reward: -1.683
# Total T: 14573 Episode Num: 712 Episode T: 31 Reward: 3.670
# Total T: 14585 Episode Num: 713 Episode T: 12 Reward: -0.530
# Total T: 14604 Episode Num: 714 Episode T: 19 Reward: -7.320
# Total T: 14621 Episode Num: 715 Episode T: 17 Reward: 6.457
# Total T: 14659 Episode Num: 716 Episode T: 38 Reward: 7.647
# Total T: 14687 Episode Num: 717 Episode T: 28 Reward: 0.272
# Total T: 14708 Episode Num: 718 Episode T: 21 Reward: 7.403
# Total T: 14722 Episode Num: 719 Episode T: 14 Reward: 1.783
# Total T: 14734 Episode Num: 720 Episode T: 12 Reward: 0.669
# Total T: 14744 Episode Num: 721 Episode T: 10 Reward: -3.041
# Total T: 14762 Episode Num: 722 Episode T: 18 Reward: 5.836
# Total T: 14777 Episode Num: 723 Episode T: 15 Reward: -0.019
# Total T: 14791 Episode Num: 724 Episode T: 14 Reward: 2.645
# Total T: 14809 Episode Num: 725 Episode T: 18 Reward: 2.513
# Total T: 14841 Episode Num: 726 Episode T: 32 Reward: 10.874
# Total T: 14858 Episode Num: 727 Episode T: 17 Reward: 4.201
# Total T: 14874 Episode Num: 728 Episode T: 16 Reward: 0.371
# Total T: 14893 Episode Num: 729 Episode T: 19 Reward: -2.508
# Total T: 14905 Episode Num: 730 Episode T: 12 Reward: 0.369
# Total T: 14928 Episode Num: 731 Episode T: 23 Reward: -4.366
# Total T: 14964 Episode Num: 732 Episode T: 36 Reward: 11.417
# Total T: 14979 Episode Num: 733 Episode T: 15 Reward: -0.145
# Total T: 14991 Episode Num: 734 Episode T: 12 Reward: 2.339
# ---------------------------------------
# Evaluation over 10 episodes: 7.883
# ---------------------------------------
# Total T: 15006 Episode Num: 735 Episode T: 15 Reward: 4.892
# Total T: 15021 Episode Num: 736 Episode T: 15 Reward: 3.321
# Total T: 15040 Episode Num: 737 Episode T: 19 Reward: 6.503
# Total T: 15049 Episode Num: 738 Episode T: 9 Reward: -0.194
# Total T: 15085 Episode Num: 739 Episode T: 36 Reward: 2.152
# Total T: 15106 Episode Num: 740 Episode T: 21 Reward: -5.562
# Total T: 15124 Episode Num: 741 Episode T: 18 Reward: -1.325
# Total T: 15145 Episode Num: 742 Episode T: 21 Reward: 0.062
# Total T: 15157 Episode Num: 743 Episode T: 12 Reward: -0.500
# Total T: 15182 Episode Num: 744 Episode T: 25 Reward: -1.218
# Total T: 15210 Episode Num: 745 Episode T: 28 Reward: 16.489
# Total T: 15226 Episode Num: 746 Episode T: 16 Reward: -0.650
# Total T: 15245 Episode Num: 747 Episode T: 19 Reward: 0.849
# Total T: 15274 Episode Num: 748 Episode T: 29 Reward: 1.491
# Total T: 15298 Episode Num: 749 Episode T: 24 Reward: -4.359
# Total T: 15310 Episode Num: 750 Episode T: 12 Reward: -1.875
# Total T: 15350 Episode Num: 751 Episode T: 40 Reward: 14.004
# Total T: 15364 Episode Num: 752 Episode T: 14 Reward: -1.117
# Total T: 15383 Episode Num: 753 Episode T: 19 Reward: 5.188
# Total T: 15399 Episode Num: 754 Episode T: 16 Reward: -12.998
# Total T: 15416 Episode Num: 755 Episode T: 17 Reward: -2.706
# Total T: 15451 Episode Num: 756 Episode T: 35 Reward: 22.486
# Total T: 15461 Episode Num: 757 Episode T: 10 Reward: -3.832
# Total T: 15504 Episode Num: 758 Episode T: 43 Reward: 3.303
# Total T: 15529 Episode Num: 759 Episode T: 25 Reward: 1.234
# Total T: 15541 Episode Num: 760 Episode T: 12 Reward: 0.563
# Total T: 15551 Episode Num: 761 Episode T: 10 Reward: -0.251
# Total T: 15578 Episode Num: 762 Episode T: 27 Reward: 3.242
# Total T: 15596 Episode Num: 763 Episode T: 18 Reward: -6.352
# Total T: 15618 Episode Num: 764 Episode T: 22 Reward: 6.898
# Total T: 15638 Episode Num: 765 Episode T: 20 Reward: -1.007
# Total T: 15650 Episode Num: 766 Episode T: 12 Reward: 0.594
# Total T: 15668 Episode Num: 767 Episode T: 18 Reward: 3.779
# Total T: 15687 Episode Num: 768 Episode T: 19 Reward: 3.971
# Total T: 15702 Episode Num: 769 Episode T: 15 Reward: 4.586
# Total T: 15723 Episode Num: 770 Episode T: 21 Reward: 10.132
# Total T: 15732 Episode Num: 771 Episode T: 9 Reward: -0.563
# Total T: 15753 Episode Num: 772 Episode T: 21 Reward: -3.811
# Total T: 15767 Episode Num: 773 Episode T: 14 Reward: 4.298
# Total T: 15787 Episode Num: 774 Episode T: 20 Reward: 1.488
# Total T: 15815 Episode Num: 775 Episode T: 28 Reward: -3.165
# Total T: 15830 Episode Num: 776 Episode T: 15 Reward: -1.758
# Total T: 15845 Episode Num: 777 Episode T: 15 Reward: 1.464
# Total T: 15864 Episode Num: 778 Episode T: 19 Reward: -3.282
# Total T: 15888 Episode Num: 779 Episode T: 24 Reward: 2.152
# Total T: 15902 Episode Num: 780 Episode T: 14 Reward: 4.543
# Total T: 15920 Episode Num: 781 Episode T: 18 Reward: 7.858
# Total T: 15941 Episode Num: 782 Episode T: 21 Reward: -1.196
# Total T: 15964 Episode Num: 783 Episode T: 23 Reward: -3.464
# Total T: 15982 Episode Num: 784 Episode T: 18 Reward: -5.982
# Total T: 15995 Episode Num: 785 Episode T: 13 Reward: -0.337
# Total T: 16033 Episode Num: 786 Episode T: 38 Reward: 6.660
# Total T: 16056 Episode Num: 787 Episode T: 23 Reward: 0.675
# Total T: 16071 Episode Num: 788 Episode T: 15 Reward: -5.402
# Total T: 16093 Episode Num: 789 Episode T: 22 Reward: -3.381
# Total T: 16121 Episode Num: 790 Episode T: 28 Reward: 7.362
# Total T: 16131 Episode Num: 791 Episode T: 10 Reward: 0.388
# Total T: 16147 Episode Num: 792 Episode T: 16 Reward: 2.652
# Total T: 16166 Episode Num: 793 Episode T: 19 Reward: -1.475
# Total T: 16193 Episode Num: 794 Episode T: 27 Reward: 6.738
# Total T: 16218 Episode Num: 795 Episode T: 25 Reward: 0.889
# ...
# Total T: 826450 Episode Num: 3240 Episode T: 1000 Reward: 4489.093
# Total T: 827387 Episode Num: 3241 Episode T: 937 Reward: 4171.790
# Total T: 828139 Episode Num: 3242 Episode T: 752 Reward: 3363.158
# Total T: 829139 Episode Num: 3243 Episode T: 1000 Reward: 4565.145
# ---------------------------------------
# Evaluation over 10 episodes: 4484.676
# ---------------------------------------
# Total T: 830139 Episode Num: 3244 Episode T: 1000 Reward: 4537.068
# Total T: 831139 Episode Num: 3245 Episode T: 1000 Reward: 4420.983
# Total T: 832139 Episode Num: 3246 Episode T: 1000 Reward: 4301.856
# Total T: 833139 Episode Num: 3247 Episode T: 1000 Reward: 4645.157
# Total T: 833980 Episode Num: 3248 Episode T: 841 Reward: 3691.227
# Total T: 834980 Episode Num: 3249 Episode T: 1000 Reward: 4496.700
# ---------------------------------------
# Evaluation over 10 episodes: 4649.352
# ---------------------------------------
# Total T: 835980 Episode Num: 3250 Episode T: 1000 Reward: 4526.930
# Total T: 836980 Episode Num: 3251 Episode T: 1000 Reward: 4509.872
# Total T: 837980 Episode Num: 3252 Episode T: 1000 Reward: 4542.102
# Total T: 838980 Episode Num: 3253 Episode T: 1000 Reward: 4512.045
# Total T: 839980 Episode Num: 3254 Episode T: 1000 Reward: 4542.690
# ---------------------------------------
# Evaluation over 10 episodes: 4239.115
# ---------------------------------------
# Total T: 840980 Episode Num: 3255 Episode T: 1000 Reward: 4533.661
# Total T: 841980 Episode Num: 3256 Episode T: 1000 Reward: 4413.508
# Total T: 842980 Episode Num: 3257 Episode T: 1000 Reward: 4642.266
# Total T: 843980 Episode Num: 3258 Episode T: 1000 Reward: 4513.760
# Total T: 844980 Episode Num: 3259 Episode T: 1000 Reward: 4483.845
# ---------------------------------------
# Evaluation over 10 episodes: 3834.210
# ---------------------------------------
# Total T: 845196 Episode Num: 3260 Episode T: 216 Reward: 599.859
# Total T: 846196 Episode Num: 3261 Episode T: 1000 Reward: 4323.567
# Total T: 847196 Episode Num: 3262 Episode T: 1000 Reward: 4558.399
# Total T: 848196 Episode Num: 3263 Episode T: 1000 Reward: 4492.251
# Total T: 849196 Episode Num: 3264 Episode T: 1000 Reward: 4389.147
# ---------------------------------------
# Evaluation over 10 episodes: 4434.515
# ---------------------------------------
# Total T: 850196 Episode Num: 3265 Episode T: 1000 Reward: 4430.214
# Total T: 851196 Episode Num: 3266 Episode T: 1000 Reward: 4516.744
# Total T: 852196 Episode Num: 3267 Episode T: 1000 Reward: 4414.749
# Total T: 853196 Episode Num: 3268 Episode T: 1000 Reward: 4464.673
# Total T: 854196 Episode Num: 3269 Episode T: 1000 Reward: 4500.171
# ---------------------------------------
# Evaluation over 10 episodes: 4607.274
# ---------------------------------------
# Total T: 855196 Episode Num: 3270 Episode T: 1000 Reward: 4465.815
# Total T: 856196 Episode Num: 3271 Episode T: 1000 Reward: 4420.649
# Total T: 857196 Episode Num: 3272 Episode T: 1000 Reward: 4533.500
# Total T: 858196 Episode Num: 3273 Episode T: 1000 Reward: 4479.837
# Total T: 859196 Episode Num: 3274 Episode T: 1000 Reward: 4402.876
# ---------------------------------------
# Evaluation over 10 episodes: 4444.162
# ---------------------------------------
# Total T: 860196 Episode Num: 3275 Episode T: 1000 Reward: 4408.361
# Total T: 861196 Episode Num: 3276 Episode T: 1000 Reward: 4483.838
# Total T: 862196 Episode Num: 3277 Episode T: 1000 Reward: 4454.993
# Total T: 863196 Episode Num: 3278 Episode T: 1000 Reward: 4478.724
# Total T: 864196 Episode Num: 3279 Episode T: 1000 Reward: 4460.358
# ---------------------------------------
# Evaluation over 10 episodes: 3212.977
# ---------------------------------------
# Total T: 865196 Episode Num: 3280 Episode T: 1000 Reward: 4463.244
# Total T: 865553 Episode Num: 3281 Episode T: 357 Reward: 1030.872
# Total T: 866553 Episode Num: 3282 Episode T: 1000 Reward: 4374.092
# Total T: 867553 Episode Num: 3283 Episode T: 1000 Reward: 4423.295
# Total T: 868553 Episode Num: 3284 Episode T: 1000 Reward: 4392.947
# Total T: 869553 Episode Num: 3285 Episode T: 1000 Reward: 4535.282
# ---------------------------------------
# Evaluation over 10 episodes: 4565.153
# ---------------------------------------
# Total T: 870553 Episode Num: 3286 Episode T: 1000 Reward: 4434.506
# Total T: 871553 Episode Num: 3287 Episode T: 1000 Reward: 4404.980
# Total T: 872553 Episode Num: 3288 Episode T: 1000 Reward: 4406.021
# Total T: 873553 Episode Num: 3289 Episode T: 1000 Reward: 4437.409
# Total T: 874553 Episode Num: 3290 Episode T: 1000 Reward: 4466.754
# ---------------------------------------
# Evaluation over 10 episodes: 4355.419
# ---------------------------------------
# Total T: 875553 Episode Num: 3291 Episode T: 1000 Reward: 4404.850
# Total T: 876553 Episode Num: 3292 Episode T: 1000 Reward: 4382.637
# Total T: 877553 Episode Num: 3293 Episode T: 1000 Reward: 4399.150
# Total T: 878553 Episode Num: 3294 Episode T: 1000 Reward: 4441.915
# Total T: 879553 Episode Num: 3295 Episode T: 1000 Reward: 4442.687
# ---------------------------------------
# Evaluation over 10 episodes: 4548.546
# ---------------------------------------
# Total T: 880553 Episode Num: 3296 Episode T: 1000 Reward: 4569.862
# Total T: 881553 Episode Num: 3297 Episode T: 1000 Reward: 4467.786
# Total T: 882553 Episode Num: 3298 Episode T: 1000 Reward: 4458.993
# Total T: 882741 Episode Num: 3299 Episode T: 188 Reward: 382.112
# Total T: 883741 Episode Num: 3300 Episode T: 1000 Reward: 4522.410
# Total T: 884741 Episode Num: 3301 Episode T: 1000 Reward: 4489.887
# ---------------------------------------
# Evaluation over 10 episodes: 4152.481
# ---------------------------------------
# Total T: 885741 Episode Num: 3302 Episode T: 1000 Reward: 4474.268
# Total T: 886741 Episode Num: 3303 Episode T: 1000 Reward: 4491.224
# Total T: 887741 Episode Num: 3304 Episode T: 1000 Reward: 4310.862
# Total T: 888741 Episode Num: 3305 Episode T: 1000 Reward: 4338.812
# Total T: 889741 Episode Num: 3306 Episode T: 1000 Reward: 4315.058
# ---------------------------------------
# Evaluation over 10 episodes: 4356.421
# ---------------------------------------
# Total T: 890741 Episode Num: 3307 Episode T: 1000 Reward: 4445.513
# Total T: 891741 Episode Num: 3308 Episode T: 1000 Reward: 4340.091
# Total T: 892741 Episode Num: 3309 Episode T: 1000 Reward: 4395.873
# Total T: 893741 Episode Num: 3310 Episode T: 1000 Reward: 4345.204
# Total T: 894741 Episode Num: 3311 Episode T: 1000 Reward: 4408.968
# ---------------------------------------
# Evaluation over 10 episodes: 4351.894
# ---------------------------------------
# Total T: 895741 Episode Num: 3312 Episode T: 1000 Reward: 4378.850
# Total T: 896741 Episode Num: 3313 Episode T: 1000 Reward: 4343.051
# Total T: 897741 Episode Num: 3314 Episode T: 1000 Reward: 4323.559
# Total T: 898741 Episode Num: 3315 Episode T: 1000 Reward: 4357.220
# Total T: 899741 Episode Num: 3316 Episode T: 1000 Reward: 4353.110
# ---------------------------------------
# Evaluation over 10 episodes: 4380.195
# ---------------------------------------
# Total T: 900741 Episode Num: 3317 Episode T: 1000 Reward: 4312.863
# Total T: 901741 Episode Num: 3318 Episode T: 1000 Reward: 4251.099
# Total T: 902741 Episode Num: 3319 Episode T: 1000 Reward: 4346.339
# Total T: 903741 Episode Num: 3320 Episode T: 1000 Reward: 4409.965
# Total T: 904741 Episode Num: 3321 Episode T: 1000 Reward: 4381.219
# ---------------------------------------
# Evaluation over 10 episodes: 4409.121
# ---------------------------------------
# Total T: 905741 Episode Num: 3322 Episode T: 1000 Reward: 4434.765
# Total T: 906741 Episode Num: 3323 Episode T: 1000 Reward: 4397.271
# Total T: 907741 Episode Num: 3324 Episode T: 1000 Reward: 4362.079
# Total T: 908741 Episode Num: 3325 Episode T: 1000 Reward: 4412.058
# Total T: 909741 Episode Num: 3326 Episode T: 1000 Reward: 4214.954
# ---------------------------------------
# Evaluation over 10 episodes: 4375.963
# ---------------------------------------
# Total T: 910741 Episode Num: 3327 Episode T: 1000 Reward: 4353.184
# Total T: 911741 Episode Num: 3328 Episode T: 1000 Reward: 4380.139
# Total T: 912741 Episode Num: 3329 Episode T: 1000 Reward: 4443.113
# Total T: 913741 Episode Num: 3330 Episode T: 1000 Reward: 4426.890
# Total T: 914741 Episode Num: 3331 Episode T: 1000 Reward: 4457.381
# ---------------------------------------
# Evaluation over 10 episodes: 4395.989
# ---------------------------------------
# Total T: 915741 Episode Num: 3332 Episode T: 1000 Reward: 4386.071
# Total T: 916741 Episode Num: 3333 Episode T: 1000 Reward: 4443.226
# Total T: 917741 Episode Num: 3334 Episode T: 1000 Reward: 4521.336
# Total T: 918741 Episode Num: 3335 Episode T: 1000 Reward: 4537.038
# Total T: 919741 Episode Num: 3336 Episode T: 1000 Reward: 4517.204
# ---------------------------------------
# Evaluation over 10 episodes: 4626.692
# ---------------------------------------
# Total T: 920741 Episode Num: 3337 Episode T: 1000 Reward: 4396.975
# Total T: 921741 Episode Num: 3338 Episode T: 1000 Reward: 4627.299
# Total T: 922741 Episode Num: 3339 Episode T: 1000 Reward: 4220.452
# Total T: 923741 Episode Num: 3340 Episode T: 1000 Reward: 4434.708
# Total T: 924741 Episode Num: 3341 Episode T: 1000 Reward: 4203.968
# ---------------------------------------
# Evaluation over 10 episodes: 4657.787
# ---------------------------------------
# Total T: 925741 Episode Num: 3342 Episode T: 1000 Reward: 4497.817
# Total T: 926741 Episode Num: 3343 Episode T: 1000 Reward: 4587.770
# Total T: 927741 Episode Num: 3344 Episode T: 1000 Reward: 4464.702
# Total T: 928741 Episode Num: 3345 Episode T: 1000 Reward: 4494.457
# Total T: 929741 Episode Num: 3346 Episode T: 1000 Reward: 4464.355
# ---------------------------------------
# Evaluation over 10 episodes: 4462.340
# ---------------------------------------
# Total T: 930741 Episode Num: 3347 Episode T: 1000 Reward: 4443.786
# Total T: 931741 Episode Num: 3348 Episode T: 1000 Reward: 4475.418
# Total T: 932741 Episode Num: 3349 Episode T: 1000 Reward: 4118.783
# Total T: 933741 Episode Num: 3350 Episode T: 1000 Reward: 4331.671
# Total T: 934741 Episode Num: 3351 Episode T: 1000 Reward: 4390.633
# ---------------------------------------
# Evaluation over 10 episodes: 4464.784
# ---------------------------------------
# Total T: 935741 Episode Num: 3352 Episode T: 1000 Reward: 4363.594
# Total T: 936741 Episode Num: 3353 Episode T: 1000 Reward: 4511.466
# Total T: 937741 Episode Num: 3354 Episode T: 1000 Reward: 4615.575
# Total T: 938741 Episode Num: 3355 Episode T: 1000 Reward: 4589.701
# Total T: 939741 Episode Num: 3356 Episode T: 1000 Reward: 4527.187
# ---------------------------------------
# Evaluation over 10 episodes: 4618.407
# ---------------------------------------
# Total T: 940741 Episode Num: 3357 Episode T: 1000 Reward: 4548.570
# Total T: 941741 Episode Num: 3358 Episode T: 1000 Reward: 4224.892
# Total T: 942741 Episode Num: 3359 Episode T: 1000 Reward: 4517.150
# Total T: 943741 Episode Num: 3360 Episode T: 1000 Reward: 4537.666
# Total T: 944741 Episode Num: 3361 Episode T: 1000 Reward: 4553.718
# ---------------------------------------
# Evaluation over 10 episodes: 4569.995
# ---------------------------------------
# Total T: 945741 Episode Num: 3362 Episode T: 1000 Reward: 4318.226
# Total T: 946741 Episode Num: 3363 Episode T: 1000 Reward: 4528.262
# Total T: 947741 Episode Num: 3364 Episode T: 1000 Reward: 4562.247
# Total T: 948741 Episode Num: 3365 Episode T: 1000 Reward: 4523.858
# Total T: 949741 Episode Num: 3366 Episode T: 1000 Reward: 4364.983
# ---------------------------------------
# Evaluation over 10 episodes: 4567.374
# ---------------------------------------
# Total T: 950741 Episode Num: 3367 Episode T: 1000 Reward: 4527.183
# Total T: 951741 Episode Num: 3368 Episode T: 1000 Reward: 4437.565
# Total T: 952741 Episode Num: 3369 Episode T: 1000 Reward: 4416.208
# Total T: 953741 Episode Num: 3370 Episode T: 1000 Reward: 4485.264
# Total T: 954741 Episode Num: 3371 Episode T: 1000 Reward: 4496.282
# ---------------------------------------
# Evaluation over 10 episodes: 4590.104
# ---------------------------------------
# Total T: 955741 Episode Num: 3372 Episode T: 1000 Reward: 4508.260
# Total T: 956741 Episode Num: 3373 Episode T: 1000 Reward: 4427.641
# Total T: 957741 Episode Num: 3374 Episode T: 1000 Reward: 4423.216
# Total T: 958741 Episode Num: 3375 Episode T: 1000 Reward: 4370.814
# Total T: 959741 Episode Num: 3376 Episode T: 1000 Reward: 4267.692
# ---------------------------------------
# Evaluation over 10 episodes: 4539.657
# ---------------------------------------
# Total T: 960741 Episode Num: 3377 Episode T: 1000 Reward: 4440.023
# Total T: 961741 Episode Num: 3378 Episode T: 1000 Reward: 4485.576
# Total T: 962741 Episode Num: 3379 Episode T: 1000 Reward: 4530.078
# Total T: 963741 Episode Num: 3380 Episode T: 1000 Reward: 4463.950
# Total T: 964741 Episode Num: 3381 Episode T: 1000 Reward: 4389.954
# ---------------------------------------
# Evaluation over 10 episodes: 4484.945
# ---------------------------------------
# Total T: 965741 Episode Num: 3382 Episode T: 1000 Reward: 4435.099
# Total T: 966741 Episode Num: 3383 Episode T: 1000 Reward: 4490.616
# Total T: 967741 Episode Num: 3384 Episode T: 1000 Reward: 4453.833
# Total T: 968741 Episode Num: 3385 Episode T: 1000 Reward: 4524.134
# Total T: 969741 Episode Num: 3386 Episode T: 1000 Reward: 4491.606
# ---------------------------------------
# Evaluation over 10 episodes: 4567.093
# ---------------------------------------
# Total T: 970741 Episode Num: 3387 Episode T: 1000 Reward: 4518.052
# Total T: 971005 Episode Num: 3388 Episode T: 264 Reward: 815.511
# Total T: 972005 Episode Num: 3389 Episode T: 1000 Reward: 4576.218
# Total T: 973005 Episode Num: 3390 Episode T: 1000 Reward: 4595.506
# Total T: 974005 Episode Num: 3391 Episode T: 1000 Reward: 4581.956
# ---------------------------------------
# Evaluation over 10 episodes: 4617.684
# ---------------------------------------
# Total T: 975005 Episode Num: 3392 Episode T: 1000 Reward: 4569.614
# Total T: 976005 Episode Num: 3393 Episode T: 1000 Reward: 4549.585
# Total T: 977005 Episode Num: 3394 Episode T: 1000 Reward: 4482.521
# Total T: 978005 Episode Num: 3395 Episode T: 1000 Reward: 4577.317
# Total T: 979005 Episode Num: 3396 Episode T: 1000 Reward: 4586.908
# ---------------------------------------
# Evaluation over 10 episodes: 4638.289
# ---------------------------------------
# Total T: 980005 Episode Num: 3397 Episode T: 1000 Reward: 4538.025
# Total T: 981005 Episode Num: 3398 Episode T: 1000 Reward: 4584.569
# Total T: 982005 Episode Num: 3399 Episode T: 1000 Reward: 4598.772
# Total T: 983005 Episode Num: 3400 Episode T: 1000 Reward: 4585.972
# Total T: 984005 Episode Num: 3401 Episode T: 1000 Reward: 4556.289
# ---------------------------------------
# Evaluation over 10 episodes: 4160.268
# ---------------------------------------
# Total T: 985005 Episode Num: 3402 Episode T: 1000 Reward: 4564.226
# Total T: 986005 Episode Num: 3403 Episode T: 1000 Reward: 4544.293
# Total T: 987005 Episode Num: 3404 Episode T: 1000 Reward: 4448.976
# Total T: 988005 Episode Num: 3405 Episode T: 1000 Reward: 4495.738
# Total T: 989005 Episode Num: 3406 Episode T: 1000 Reward: 4493.017
# ---------------------------------------
# Evaluation over 10 episodes: 4513.698
# ---------------------------------------
# Total T: 990005 Episode Num: 3407 Episode T: 1000 Reward: 4483.452
# Total T: 991005 Episode Num: 3408 Episode T: 1000 Reward: 4483.843
# Total T: 992005 Episode Num: 3409 Episode T: 1000 Reward: 4450.741
# Total T: 993005 Episode Num: 3410 Episode T: 1000 Reward: 4502.575
# Total T: 994005 Episode Num: 3411 Episode T: 1000 Reward: 4420.689
# ---------------------------------------
# Evaluation over 10 episodes: 4543.741
# ---------------------------------------
# Total T: 995005 Episode Num: 3412 Episode T: 1000 Reward: 4496.086
# Total T: 996005 Episode Num: 3413 Episode T: 1000 Reward: 4513.234
# Total T: 997005 Episode Num: 3414 Episode T: 1000 Reward: 4541.839
# Total T: 998005 Episode Num: 3415 Episode T: 1000 Reward: 4609.012
# Total T: 999005 Episode Num: 3416 Episode T: 1000 Reward: 4557.577
# ---------------------------------------
# Evaluation over 10 episodes: 4551.109
# ---------------------------------------

# %%
state_dim
# Out:
# 17
